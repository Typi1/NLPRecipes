# %%
import stanza as st
import numpy as np
import re as reg
from typing import Optional
import transformers as tra
from enum import Enum
from difflib import SequenceMatcher as sm

# pipe = tra.pipeline(model="facebook/bart-large-mnli")
# st.download('en')
# depgram = st.Pipeline('en')#, processors='tokenize,mwt,pos,lemma,depparse,ner')

ingredient_labels = ["ingredient", "slices", "chunks", "quantity"]
tool_labels = ["appliance", "cooking utensil", "container", "bowl", "pan", "board", "measuring tool", "knife", "strainer", "colinder", "spatula"]
separation_labels = ["separate", "remove", "sift", "drain", "disgard", "filter"]
combination_labels = ["add", "combine", "mix", "stir", "blend", "pour"]
# print(pipe("bowl", candidate_labels=["food", "cooking utensil", "appliance", "container"]))

class DetailType(Enum):
    TIME = 0 # an amount of time (or "until...")
    TEMPERATURE = 1 # a temperature
    LOCATION = 2 # where to perform the step (like in a bowl, over a colinder)
    PREP_MANNER = 3 # evenly, 
    MACHINE_SETTING = 4 # non-temperature machine setting (like blender speed)
    OPTIONAL = 5 # if the instruction is optional or at user discretion. usually can be indicated by "IF"
    
    MISC = 10 # if it doesn't fit significantly into any of the other categories. observe this to see if there are any commonalities to make categories

class ListType(Enum):
    AND = 0 # a list of things that all are required
    OR = 1 # a list of things that can be substituted
    UNSPECIFIED = 2 # if the list type cannot be determined

# represents combinations of ingredients like a batter being made of eggs and stuff. uses list detection and dependency parsers to form this
class IngredCombo:
    def __init__(   self, 
                    id: int,            # a unique id for each ingredient combo object 
                    grouping_verb: str, # the verb that applies to the combination of ingredients. ex: "mix", "place X in bowl"/"stir"
                    constituents: list, # list of strings that go into this combination
                    combo_names: Optional[list] = None):
        self.id = id
        self.grouping_verb = grouping_verb
        self.constituents = constituents
        self.combo_names = []
        if combo_names != None:
            self.combo_names += combo_names

    def addComboName(self, name:str):
        self.combo_names.append(name)
    # def determineComboType(self):
    #     options = ["batter", "soup", "stew", "blend", "sauce", "powder", "broth", "mirepoix", "glaze"] # add onto this potentially
    #     test_str = self.makeList()
    #     pipe_results = pipe(test_str, candidate_labels=options)
    #     if pipe_results != None and pipe_results['labels'] != None and pipe_results['labels'] != []:
    #         if all(sc < 0.25 for sc in pipe_results['scores']):
    #             result = "other"
    #         else:
    #             result = pipe_results['labels'][0]

    #     return result
    
    def makeList(self):
        test_str = ""
        for x in self.constituents:
            test_str += x
            test_str += " "
        return test_str.rstrip()
    
    # TODO
    def addConstituent(self, ingr):
        pass

    def __str__(self):
        return "Combination type: " + self.combo_type + "\n\tGrouping verb: " + self.grouping_verb + "\n\tConstituents: " + str(self.constituents)

class protoStep:
    def __init__(   self,
                    id: int = 0, # the number of the step
                    action: str = "", # the root action of the step
                    nouns: dict = None, # the nouns involved in the steps with name as key, 
                    # and a list with its type [0] and then another list of associated strings [1] as values
                    original_text: str = "" # the original text
                    ):
        self.id = id
        self.action = action
        self.nouns = {}
        if nouns != None:
            self.nouns = nouns
        self.original_text = original_text

    

    def __str__(self):
        outputStr = ""
        outputStr = outputStr +  "id: " + str(self.id)
        outputStr = outputStr + "\nOriginal text: " + str(self.original_text)
        outputStr = outputStr + "\n\tRoot action: " + str(self.action)
        outputStr = outputStr + "\n\tNouns: " + str(self.nouns)
        return outputStr

# note when going over ingredients, if there is a verb associated with it (like chopped leeks), make it a step if not already (chop leeks)

class Step:
    def __init__(   self, 
                    id: int = 0, # the number of the step
                    root_action: str = "", # the root verb of the step
                    actions: dict = None, 
                    ingredients: dict = None, # the ingredients required as keys (num/amount [count/mass] and list of qualifiers [adjs] as value)
                        # could also use some ingredient ID instead of using a list of qualifiers on the ingredient [the class referred to by the ID]
                    tools: dict = None, # the tools and/or appliances and/or pots/pans/bowls required
                    details: dict = None, # adverbs and descriptors. key is a numerical ID. value is DetailType enum and substring
                    original_text: str = ""): 
        self.root_action = root_action
        self.actions = {}
        if actions != None:
            self.actions = actions
        self.ingredients = {}
        if ingredients != None:
            self.ingredients = ingredients
        self.tools = {}
        if tools != None:
            self.tools = tools
        self.details = {}
        if details != None:
            self.details = details
        self.id = id 
        self.original_text = original_text



    def __str__(self):
        outputStr = ""
        outputStr = outputStr +  "id: " + str(self.id)
        outputStr = outputStr + "\nOriginal text: " + str(self.original_text)
        outputStr = outputStr + "\n\tRoot action: " + str(self.root_action)
        outputStr = outputStr + "\n\tAll actions: " + str(self.actions)
        outputStr = outputStr + "\n\tIngredients: " + str(self.ingredients)
        outputStr = outputStr + "\n\tTools: " + str(self.tools)
        outputStr = outputStr + "\n\tDetails: " + str(self.details)
        return outputStr
    
# if head_id is -1 or id is 0, this is the root node
class depNode():
    def __init__(self, id:int, head_id:int, text:str, typ: str, deps:dict):
        self.id = id
        self.head_id = head_id
        self.text = text
        self.typ = typ
        self.deps = deps
        if deps == None:
            self.deps = {}

    def addDependent(self, dep_id:int, dep_text:str, rel_type:str):
        if dep_id in self.deps.keys():
            return
        self.deps[dep_id] = (dep_id, dep_text, rel_type)

    def __str__(self):
        outputStr = ""
        outputStr += "ID: " + str(self.id)
        outputStr += "\n\tHead ID: " + str(self.head_id)
        outputStr += "\n\tText: " + self.text
        outputStr += "\n\tType: " + self.typ
        outputStr += "\n\tDependent Words: "
        for x in self.deps.keys():
            outputStr += "\n\t\tDep. ID: " + str(self.deps[x][0])
            outputStr += "\n\t\t\tDep. Text: " + self.deps[x][1]
            outputStr += "\n\t\t\tRelation Type: " + self.deps[x][2]
        return outputStr
            

# returns a easier to traverse dependency tree with word id in the sentence as the key, as well as a dictionary of a word to a list of ids of instances of it
def getDependency(input_dep:list):
    text_to_ids = {} # ex: For the sentence, "cakes are cakes": text_to_ids["cakes"] == [1,3] 
    dependency_dict = {}

    # add a special node for ROOT
    dependency_dict[0] = depNode(0, -1, "ROOT", "N/A", {})

    for entry in input_dep:

        id1 = entry[0].id
        txt1 = entry[0].text.lower()
        id2 = entry[2].id
        txt2 = entry[2].text.lower()
        rel_type = entry[1]

        # if either word id isn't in the dependency dictionary, add it
        if not id1 in dependency_dict.keys():
            dependency_dict[id1] = depNode(id1, entry[0].head, txt1, entry[0].xpos, {})
            if not txt1 in text_to_ids.keys():
                text_to_ids[txt1] = [id1]
            elif txt1 in text_to_ids.keys() and not id1 in text_to_ids[txt1]:
                text_to_ids[txt1] = text_to_ids[txt1] + [id1]

        if not id2 in dependency_dict.keys():
            dependency_dict[id2] = depNode(id2, entry[2].head, txt2, entry[2].xpos, {})
            if not txt2 in text_to_ids.keys():
                text_to_ids[txt2] = [id2]
            elif txt2 in text_to_ids.keys() and not id2 in text_to_ids[txt2]:
                text_to_ids[txt2] = text_to_ids[txt2] + [id2]

        # add a dependency into the head word
        dependency_dict[id1].addDependent(id2, txt2, rel_type)

    return (dependency_dict, text_to_ids)
        


# uses SequenceMatcher to determine whether 2 noun strings refer to the same thing.
# also uses some other checks like if one is a substring of another [might need to adjust if 'teaspoon' matches to an ingredient]
# to be used when checking if something is explicitly in the ingredient list
# try to pass stuff like noun + adjective + DIRECTLY ADJACENT subordinate nouns into here
# text1 should be the string from the defined ingredient list, and text2 should be the input string we are checking against it
def isSameNoun(text1:str, text2:str, seen:dict):
    if not text1 in seen:
        (_, seen) = getNounType(text1, seen)

    if not text2 in seen:
        (_, seen) = getNounType(text2, seen)

    # failsafe for ensuring something like 'teaspoon' the measuring tool doesn't match to 'a teaspoon of sugar'
    if seen[text1]['labels'][0] == 'ingredient' and any(seen[text2]['labels'][0] == x for x in ['measuring tool', 'container']):
        return (False, seen)
    if seen[text2]['labels'][0] == 'ingredient' and any(seen[text1]['labels'][0] == x for x in ['measuring tool', 'container']):
        return (False, seen)
        

# returns whether the input word is an appliance, utensil, measuring tool, etc.
# return is bool of whether tool or not, and (updated) seen dict
def isTool(text:str, seen:dict):
    res = False
    text = text.lower()
    if not text in seen.keys():
        (_, seen) = getNounType(text, seen)
        # print("?")

    if (text in seen.keys()) and seen[text]['labels'][0] in tool_labels:
            if seen[text]['scores'][0] > 0.1:
                res = True

    return (res, seen)

def isIngredient(text:str, seen:dict):
    res = False
    text = text.lower()
    if not text in seen:
        (_, seen) = getNounType(text, seen)
        # print("?")

    if (text in seen) and seen[text]['labels'][0] in ingredient_labels:
            res = True

    return (res, seen)



def getNounType(text:str, seen: dict):
    res = ""
    text = text.lower()
    if text in seen:
        res = seen[text]
    else:
        # add something here which will check if the noun is in the ingredients list
        lst = ["time"] + ingredient_labels + tool_labels
        res = pipe2(text, candidate_labels=lst)
        seen[text] = res

    # print(res)
    # print(seen)
    return (res['labels'][0], seen)

def getAdjType(text:str, seen: dict):
    res = ""
    if text in seen:
        res = seen[text]
    else:
        res = pipe2(text, candidate_labels=["preparation manner", "compliment", "color", "texture", "temperature", "viscosity", "taste", "size"])
        seen[text] = res
    
    return (res['labels'][0], seen)

def getFirstType(children:list, typ: str):
    res = None
    for branch in children:
        if branch.label == typ:
            return branch
        else:
            res = getFirstType(branch.children, typ)
            if res != None and res.label == typ:
                return res
            
    return res

# same as above function, but uses "in" to make it so the general category of word is easier to get. 
# for example, if we are looking for a noun, we would have to find NN, NNS, NNP, NNPS, etc. with the above function.
# With this more broad function, just searching with type NN would get all of those/
def getFirstTypeBroad(children:list, typ: str):
    res = None
    for branch in children:
        if typ in branch.label:
            return branch
        else:
            res = getFirstType(branch.children, typ)
            if res != None and typ in res.label:
                return res
            
    return res
            
def getAllOfTypes(children:list, typs: list):
    res = []

    if len(children) == 1 and children[0].label == str(children[0]):
        return res
    
    for branch in children:
        if "NN" in typs and branch.label == "VP": continue
        if any(branch.label == typ for typ in typs):
            if len(branch.children) == 1 and branch.children[0].label == str(branch.children[0]):
                res.append(branch.children[0].label)
            else:
                res.append(constituency_to_str(branch))
        # special case for collecting compound nouns 
        elif "NN" in typs and branch.label == "NP" and isComboNounPhrase(branch):
            res.append(constituency_to_str(branch))
        else:
            temp = getAllOfTypes(branch.children, typs)
            if temp != []:
                res += temp # res.append(temp)

    return res

def stepsToPara(steps:list):
    res = ""
    for x in steps:
        res += str(x) + " "

    return res.rstrip()
        
def getWordsRecurs(children:list, words:list):
    for branch in children:
        if(branch.label == str(branch)):
            words.append(branch.label)
            continue
        words = getWordsRecurs(branch.children, words)

    return words

def constituency_to_str(tree:st.models.constituency.parse_tree.Tree):
    children = tree.children
    words = []
    # do a Depth First Traversal and add words to the list
    words = getWordsRecurs(children, words)

    res = ""

    for x in words:
        if x == "." or x == "," or x == "'" or x == ";" or x == ":" or x == "-" or x == "/":
            res = res.rstrip()
        res += x
        res += " "

    return res.rstrip()

# determines whether a noun phrase NP is a combination of nouns (ex: "the confectioners' sugar" or "the lemon zest")
def isComboNounPhrase(tree:st.models.constituency.parse_tree.Tree):
    children = tree.children
    return all(not child.label in [",",".",";","CC","VP","VB"] for child in children)


def getAllDepTuples(dependencies:dict, curr_id:int):
    res = [(curr_id, dependencies[curr_id].text)]
    for dp in dependencies[curr_id].deps:
        res += getAllDepTuples(dependencies, dependencies[curr_id].deps[dp][0])
    return res

# returns the phrase that the string of curr_id is in based on dependencies
def getDepPhrase(dependencies:dict, curr_id:int):
    # first, get all the dependent tuple data using DFS
    tuples = getAllDepTuples(dependencies, curr_id)
    # now order them into a phrase string
    tuples.sort(key=(lambda x: x[0]), reverse=False)
    res = ""
    for t in tuples:
        if t[1] == "." or t[1] == "," or t[1] == "'" or t[1] == ";" or t[1] == ":" or t[1] == "-" or t[1] == "/":
            res = res.rstrip()
        res += t[1]
        res += " "

    return res.rstrip()

# gets the head verb for a noun
def getHeadVerb(dependencies:dict, curr_id:int):

    head = dependencies[curr_id].head_id

    # if we somehow get to the root without seeing a verb, there is no head verb
    if head == 0: return None

    # base case returns the first head verb encountered
    if "VB" in dependencies[head].typ: return dependencies[head]

    # if this isn't a position where we can get an answer, recurse to the head node
    return getHeadVerb(dependencies, head)

# returns the number of words and punctuation in the given tree
def getNumIds(tree:st.models.constituency.parse_tree.Tree):
    num = 0
    children = tree.children
    for branch in children:
        if branch.label == str(branch):
            num += 1
        else:
            num += getNumIds(branch)

    return num

# given a tree structure and a target string, get the NP that the string is a noun in
def getNPfromNNx(   tree:st.models.constituency.parse_tree.Tree, 
                    text:str, 
                    noun_found:bool = False, 
                    NP_found:bool = False
                    ):
    label = tree.label
    children = tree.children

    if len(children) == 0:
        return (tree, False, False)

    res_tree = None

    # basically, we want to find the noun first, then return some value saying we found that and are now looking for the
    # smallest NP phrase it is in.
    # then, set a flag to ignore all other NPs when returning that simplest NP phrase
    for branch in children:
        # recurse first
        (temp_tree, noun_found, NP_found) = getNPfromNNx(branch, text, noun_found, NP_found)
        # check if this is the noun
        if not noun_found:
            if branch.label == str(branch) and "NN" in label and branch.label.lower().lstrip().rstrip() == text.lower().lstrip().rstrip():
                return (res_tree, True, NP_found)
        # if the noun has been found, check if this is the NP phrase
        elif not NP_found:
            if branch.label == "NP":
                return (branch, noun_found, True)
        # if both the noun and NP have been found, just make sure res_tree is updated for the return value
        else:
            res_tree = temp_tree
    
    return (res_tree, noun_found, NP_found)
        

def getPhrases(tree:st.models.constituency.parse_tree.Tree, og_text:str, dependencies:dict):
    verb_phrases = {}
    prep_phrases = {}
    noun_lists = {}
    nouns = []
    return getPhrasesRecurs(tree, verb_phrases, prep_phrases, noun_lists, og_text, tree, dependencies, 0, nouns)

def getPhrasesRecurs(   tree:st.models.constituency.parse_tree.Tree, # the stanza-generated constituency tree currently being analyzed (recursively)
                        verb_phrases:dict, # a dictionary of verb phrases: the verb and the phrase it represents
                        prep_phrases:dict, # a dictionary of preposition phrases, will be useful for questions
                        noun_lists:dict, # a dictionary of lists of nouns with the type (AND, OR, UNSPECIFIED) of list, list member nouns, and the verb of the encapsulating verb phrase
                        og_text:str, # the original sentence string
                        og_tree:st.models.constituency.parse_tree.Tree, # the whole tree for the step
                        dependencies:dict, # a dictionary of dependency relations, going from a word id to data where one can find its head or to the words dependent on it
                        num_words_before: int, # the number of words before the current phrase being analyzed. Useful for referencing the dependencies dict
                        nouns_cat: list # a simple list of nouns and compound nouns
                        ):
    # do a search through the consistuency tree to retrieve the prepositional phrase
    # also identify whether it is referring to a location on a food item or an appliance (cookware)

    label = tree.label
    children = tree.children

    num_ids_in_phrase = 0

    # do analysis of thing
    # look for NP, VP, PP

    # look for NP lists and combo nouns

    # first, it must be a Noun phrase for it to contain a list of nouns or a combo noun.
    if label == "NP":
        # first, let's check if this is a compound noun and if so, add it to our list of nouns, ex: lemon zest
        isCN = isComboNounPhrase(tree)
        if isCN and all(not constituency_to_str(tree) in nn[0] for nn in nouns_cat):
            # print("*" + constituency_to_str(tree) + "*")
            head_verb = getHeadVerb(dependencies, num_words_before + num_ids_in_phrase + getNumIds(tree))
            if head_verb != None: head_verb = head_verb.text
            nouns_cat.append((constituency_to_str(tree), head_verb))
            # print(constituency_to_str(tree))

        # now check if it is a list so check for ",", ";", or "and" or "or"
        isList = False
        list_type = None
        for child in children:
            if child.label == ";" or child.label == "," or (child.label == "CC" and (child.children[0].label.lower() == "and" or child.children[0].label.lower() == "or")):
                isList = True
                if child.children[0].label.lower() == "and":
                    list_type = ListType.AND
                elif child.children[0].label.lower() == "or":
                    list_type = ListType.OR

        if list_type == None:
            list_type = ListType.UNSPECIFIED

        # note that there might be sublists like "flour, sugar, and 'apples or oranges'", so just check for "or" and "and" within the NP children directly to determine list type
        if isList:

            # get the list of nouns in the NP
            nouns = []
            temp_noun_list = getAllOfTypes(children, ["NN", "NNS", "NNP", "NNPS"])
            print(temp_noun_list)
            for ii in temp_noun_list:
                nouns.append(ii)
            

            # get the grouping verb based on dependency
            # print(num_words_before + num_ids_in_phrase + getWordsRecurs(children, []).index(getFirstTypeBroad(children, "NN").children[0].label)+1)
            firstNounWordinList = getFirstTypeBroad(children, "NN").children[0].label
            gr_verb = getHeadVerb(dependencies, num_words_before + num_ids_in_phrase + getWordsRecurs(children, []).index(firstNounWordinList)+1)
            if gr_verb != None:
                for dp in gr_verb.deps.keys():
                    if any(xx in gr_verb.text.lower() for xx in separation_labels):
                        break
                    if gr_verb.deps[dp][2] in ["obl", "obj"] and all(not gr_verb.deps[dp][1] in xx for xx in nouns):
                        print(str(gr_verb.deps[dp][1]))
                        NP_res = getNPfromNNx(og_tree, gr_verb.deps[dp][1], False, False)
                        if NP_res[0] == None: continue
                        temp_obj = constituency_to_str(NP_res[0])
                        if all(not temp_obj in yy for yy in nouns) and isIngredient(temp_obj, {}):
                            nouns.append(temp_obj)
                        # print(constituency_to_str(getNPfromNNx(og_tree, gr_verb.deps[dp][1], False, False)[0]))

                # print("LIST:")
                # print(gr_verb)
                # print(nouns)
                if gr_verb != None: gr_verb = gr_verb.text
            noun_lists[len(noun_lists.keys())] = ((list_type, nouns, gr_verb))
        
    # add any straggler nouns to the noun list
    if label in ["NN", "NNS", "NNP", "NNPS"]:
        noun = children[0].label
        if all(not noun.lower() in noun_coll[0].lower() for noun_coll in nouns_cat):
            head_verb = getHeadVerb(dependencies, num_words_before + num_ids_in_phrase + 1)
            if head_verb != None: head_verb = head_verb.text
            nouns_cat.append((noun, head_verb, num_words_before + num_ids_in_phrase + 1))

    # look for VP phrase without sub VP branches
    # later remove the one corresponding to the root verb, so we just have the extraneous instructions
    if label == "VP":
        if all((x.label != "VP") for x in children):
            temp_res = getFirstType(children, "VB")

            if temp_res != None and temp_res.children[0].label.lower() != "let":
                verb_phrases[len(verb_phrases.keys())] = (temp_res.children[0].label, constituency_to_str(tree))
            
    # look for prepositions for certain details (IE "in the oven")
    if label == "PP" or label == "SBAR":
        temp_res = getFirstType(children, "IN")
        if temp_res != None and all(not constituency_to_str(tree) in prep_phrases[pp][1] for pp in prep_phrases):
            head_verb = getHeadVerb(dependencies, num_words_before + num_ids_in_phrase + 1)
            if head_verb != None: head_verb = head_verb.text
            prep_phrases[len(prep_phrases.keys())] = (temp_res.children[0].label, constituency_to_str(tree), head_verb)
    if label == "PRT":
        temp_res = getFirstType(children, "RP")
        if temp_res != None:
            # if we just add like above, we will only get the RP word but we want the object of the VP this PRT is in, so let's get that object
            # first, get the head of this RP
            print(num_words_before + num_ids_in_phrase + 1)
            RP_text = constituency_to_str(tree)
            head_wrd = dependencies[dependencies[num_words_before + num_ids_in_phrase + 1].head_id]
            for dep_id in head_wrd.deps:
                print(head_wrd.deps[dep_id][0])
                if head_wrd.deps[dep_id][2] == "obj":
                    RP_text += " " + getDepPhrase(dependencies, head_wrd.deps[dep_id][0])
            if(all(not RP_text in prep_phrases[pp][1] for pp in prep_phrases)):
                head_verb = getHeadVerb(dependencies, num_words_before + num_ids_in_phrase + 1)
                if head_verb != None: head_verb = head_verb.text
                prep_phrases[len(prep_phrases.keys())] = (temp_res.children[0].label, RP_text, head_verb)
    if "ADV" in label:
        temp_res = getFirstType(children, "RB")
        if temp_res != None:
            head_verb = getHeadVerb(dependencies, num_words_before + num_ids_in_phrase + 1)
            if head_verb != None: head_verb = head_verb.text
            prep_phrases[len(prep_phrases.keys())] = (temp_res.children[0].label, constituency_to_str(tree), head_verb)


    # recurse to children
    
    # print(childr)
    if len(children) == 0 or str(tree) == label: # base case
        return (verb_phrases, prep_phrases, noun_lists, num_ids_in_phrase, nouns_cat)
    else: # go over all child branches
        for branch in children:
            if str(branch) == branch.label:
                num_ids_in_phrase += 1
            if str(branch) != "," and str(branch) != branch.label:
                # print(branch)
                (verb_phrases, prep_phrases, noun_lists, temp_num, nouns) = getPhrasesRecurs(branch, verb_phrases, prep_phrases, noun_lists, og_text, og_tree, dependencies, num_words_before + num_ids_in_phrase, nouns_cat)
                num_ids_in_phrase += temp_num

    return (verb_phrases, prep_phrases, noun_lists, num_ids_in_phrase, nouns_cat)

    






def doParsing(test_phrase:str, ingredient_list:list):

    test_doc = depgram(test_phrase)

    # print(test_doc.depparse)

    # print(test_doc)
    # print(test_doc.entities)
    steps = {}
    protos = {}
    curr_id = 1
    noun_seen = {}
    adj_seen = {}

    # dict of ingredient combinations with integer ids as keys and values:
    #   the list of constituent nouns as tuples with if they are 
    hierarchy = {}

    for sent in test_doc.sentences:
        consti = sent.constituency
        (dep, name_to_dep_ids) = getDependency(sent.dependencies)
        for ti in dep.keys():
            print(dep[ti])
            # print(ti)
        # print(consti)
        # print(consti.label) 
        # print(consti.children) # do some tree traversal to find preposition phrases and add them to details(?) Probably BFS
        # sent.print_dependencies()
        print(consti.children[0]) # the useful data
        # print(type(consti))
        print(sent.text)

        # print(constituency_to_str(consti))
        (verb_phrases, prep_phrases, noun_lists, _, nouns_phr) = getPhrases(consti.children[0], sent.text, dep)
        print("verb phrases: " + str(verb_phrases))
        print("prep phrases: " + str(prep_phrases))
        print("noun lists: " + str(noun_lists))
        print("nouns: " + str(nouns_phr))
        # getPhrases(consti.children[0], sent.text)

        root = ""
        actions = {}
        ingredients = {}
        tools = {}
        details = {}

        nouns_seen = {}

        for wrd in sent.words:

            if wrd.deprel == "punct":
                continue
            
            # print(wrd.text, wrd.lemma)
            # print("\t" + wrd.pos)
            # print("\thead: " + str(wrd.head-1) + " " + head_word.text) # note ID is 1-indexed, NOT 0-indexed
            # print("\t" + wrd.deprel)
            # if wrd.feats != None: 
            #     print("\t" + wrd.feats)

            if wrd.deprel == "root":
                root = wrd.text
                continue


        print("STARTING ZERO SHOT")
        for nn in nouns_phr:
            (res, nouns_seen) = getNounType(nn[0], nouns_seen)
            (ingr, nouns_seen) = isIngredient(nn[0], nouns_seen)
            (tool, nouns_seen) = isTool(nn[0], nouns_seen)
            if ingr:
                ingredients[nn[0]] = (nn[0], nn[1], res) # change later to be something like all the ingredients that make it up
            elif tool:
                # print(tools)
                tools[nn[0]] = (nn[0], nn[1], res) 
        print("END OF ZERO SHOT")
        print(nouns_seen)

        details = prep_phrases
        
        # create hierarchies for noun_lists
        for nn in noun_lists.keys():
            noun_lists[nn]

        # # ok now that we have stuff like object hierarchies established, we should get the direct object and the indirect object of each action
        # for vp in verb_phrases.keys():
        #     # so let's check the dependency graph for the dependent words
        #     poss_ids = name_to_dep_ids[verb_phrases[vp][0].lower()]
        #     for psi in poss_ids:
        #         print(dep[psi])
        #         dir_obj = ""
        #         indir_obj = []
        #         for dp in dep[psi].deps.keys():
        #             current_word = dep[psi].deps[dp]
        #             print(current_word[1])
        #             print(verb_phrases[vp][1])
        #             if not current_word[1] in verb_phrases[vp][1]: continue
        #             if current_word[2] == "obj":
        #                 # first check if it is an ingredient, 
        #                 for xx in ingredients:
                            
        #                     if current_word[1] in xx:
        #                         dir_obj = xx
        #                         # first check if it is part of a combo from this step
        #                         inCombo = False # any(current_word[0] in zz for zz in list(noun_lists[yy][1] for yy in noun_lists.keys()))
        #                         for lst in noun_lists.keys():
        #                             for memb in noun_lists[lst][1]:
        #                                 if current_word[1] in memb:
        #                                     inCombo = True
        #                                     dir_obj = noun_lists[lst][1]
                                
        #                         # TODO: then check if it is an ingredient from a combo from a previous step
        #                         if not inCombo:
        #                             pass
        #                         # then if not, we can just add the corresp. ingredient
        #                         if not inCombo:
        #                             dir_obj = xx
        #                 # if not an ingredient, we can just add this
        #                 if dir_obj == "": 
        #                     dir_obj = current_word[1]
        #             elif current_word[2] == "obl":
        #                 curr_indir_obj = ""
        #                 # first check if it is an ingredient, 
        #                 for xx in ingredients:
        #                     if current_word[1] in xx:
        #                         curr_indir_obj = xx
        #                         # first check if it is part of a combo from this step
        #                         inCombo = False # any(current_word[0] in zz for zz in list(noun_lists[yy][1] for yy in noun_lists.keys()))
        #                         for lst in noun_lists.keys():
        #                             for memb in noun_lists[lst][1]:
        #                                 if current_word[1] in memb:
        #                                     inCombo = True
        #                                     curr_indir_obj = noun_lists[lst][1]
                                
        #                         # TODO: then check if it is an ingredient from a combo from a previous step
        #                         if not inCombo:
        #                             pass
        #                         # then if not, we can just add the corresp. ingredient
        #                         if not inCombo:
        #                             curr_indir_obj = xx
        #                 # if not an ingredient, we can just add this
        #                 if curr_indir_obj == "": 
        #                     curr_indir_obj = current_word[1]
        #                 indir_obj.append(curr_indir_obj)
        #         print(dir_obj)
        #         print(indir_obj)        
        #         actions[vp] = (verb_phrases[vp][0], verb_phrases[vp][1], dir_obj, indir_obj)
        steps[curr_id] = Step(curr_id, root, verb_phrases, ingredients, tools, details, sent.text)
        
        curr_id += 1
    

    return steps
# (ROOT (S (VP (VB Divide) (NP (DT the) (NN batter)) (PP (IN between) (NP (DT the) (VBN prepared) (NNS pans)))) (. .)))



def main():
    test_text = ""
    # test_text = "Blend the sweet strawberry cream in the blender with cinnamon."
    # test_text = "After preparing 20 pounds of batter, insert it into a lovely pan."
    # test_text = "In a medium bowl, evenly whisk the confectioners' sugar with the lemon zest, lemon juice, butter and salt until smooth. Drizzle the glaze over the top of the cake, letting it drip down the sides. Let stand for 20 minutes until the glaze is set. Cut the cake into wedges and serve."
    # test_text = "Here's a list: eggs, flour, sugar, oil, cinnamon, and baking powder. Place the icing and batter in the fridge. Close your fridge, mouth or lips, and eyes and wait 50 hours. Try cakes or cookies."
    # test_text = "Macerate the strawberries with sugar: Put the cut strawberries into a large bowl and sprinkle with sugar. Start with 1/4 cup of sugar and then add up to another 1/4 cup depending on how sweet your strawberries are. Gently stir the strawberries until they are all coated with some sugar. Let sit at room temperature for about 20 minutes, until the berries soften and begin to release their juices."
    test_text = "Prep the strawberries: Cut the stems away from the strawberries and discard. Cut the strawberries in half, and then in either quarters or thick slices. Macerate the strawberries with sugar: Put the cut strawberries into a large bowl and sprinkle with sugar. Start with 1/4 cup of sugar and then add up to another 1/4 cup depending on how sweet your strawberries are. Gently stir the strawberries until they are all coated with some sugar. Let sit at room temperature for about 20 minutes, until the berries soften and begin to release their juices. Mash some of the strawberries: After 20 minutes or so, mash about a quarter of the berries in the bowl with a potato masher and stir to mix. You don't want to mash all the berries, just enough of them for their juices. Let sit while you bake the biscuits. Bake the biscuits: Use the recipe below to bake the biscuits. Make the whipped cream: While the biscuits are baking, whip the cream using an electric mixer, adding a drop or two of vanilla and 2 teaspoons of powdered sugar. Cover with plastic and place in the refrigerator to chill until ready to serve. To serve, break up one biscuit per person into big pieces into a bowl. Ladle strawberries over the biscuit. Add a dollop of whipped cream."
    # test_text = "After 20 minutes or so, mash about a quarter of the berries in the bowl with a potato masher and stir to mix."
    # test_text = "remove the milk from the batter, the dough, and the glaze using a strainer."
    ingredient_list = ["confectioner's sugar", "lemon zest", "lemon juice", "butter", "salt", "glaze"]
    # steps = doParsing(test_text, ingredient_list)

    # for x in steps.keys():
    #     print(steps[x])
    

if __name__ == '__main__':
    main()

# %%
test_text = "Preheat the oven to 375°F (190°C). On a lightly floured surface, roll the pizza dough into a rope 36 inches (1 m) long and ½-inch (13 mm) thick. Arrange the rope around the outer edge of a 12-inch (30.5 cm) nonstick ovenproof skillet and pinch together the ends to form a ring. Cover with a kitchen towel and let stand until the dough is slightly puffed, about 30 minutes. Drizzle 1 tablespoon of olive oil into the center of the skillet. Lightly beat the egg whites, then pour into the center of the skillet. Spoon the pizza sauce over the egg whites, then top with the spinach and mozzarella. Sprinkle the oregano, red pepper flakes, salt, and pepper over everything. Brush some of the remaining tablespoon olive oil over the dough ring, then drizzle any remaining olive oil over the center. Bake the pizza until the dough is golden brown, the cheese has melted, and the egg whites are cooked through, 20–25 minutes. Remove the skillet from the oven and arrange the egg yolks on top of the pizza. Return it to the oven and bake until the yolks are warmed through but still soft, about 5 minutes more (a thin film will develop on top of the yolks). Transfer the skillet to a wire rack. Sprinkle evenly with the Parmesan and let cool for 1 minute. Run a spatula around the edges of the skillet to loosen the pizza, then carefully slide it onto a cutting board and slice into 4 large wedges. Serve hot. Enjoy!"
allsteps = doParsing(test_text, [])
# Out:
# ID: 0
# 	Head ID: -1
# 	Text: ROOT
# 	Type: N/A
# 	Dependent Words:
# 		Dep. ID: 1
# 			Dep. Text: preheat
# 			Relation Type: root
# ID: 1
# 	Head ID: 0
# 	Text: preheat
# 	Type: VB
# 	Dependent Words:
# 		Dep. ID: 3
# 			Dep. Text: oven
# 			Relation Type: obj
# 		Dep. ID: 6
# 			Dep. Text: °f
# 			Relation Type: obl
# 		Dep. ID: 10
# 			Dep. Text: .
# 			Relation Type: punct
# ID: 3
# 	Head ID: 1
# 	Text: oven
# 	Type: NN
# 	Dependent Words:
# 		Dep. ID: 2
# 			Dep. Text: the
# 			Relation Type: det
# ID: 2
# 	Head ID: 3
# 	Text: the
# 	Type: DT
# 	Dependent Words:
# ID: 6
# 	Head ID: 1
# 	Text: °f
# 	Type: NN
# 	Dependent Words:
# 		Dep. ID: 4
# 			Dep. Text: to
# 			Relation Type: case
# 		Dep. ID: 5
# 			Dep. Text: 375
# 			Relation Type: nummod
# 		Dep. ID: 8
# 			Dep. Text: 190°c
# 			Relation Type: appos
# ID: 4
# 	Head ID: 6
# 	Text: to
# 	Type: IN
# 	Dependent Words:
# ID: 5
# 	Head ID: 6
# 	Text: 375
# 	Type: CD
# 	Dependent Words:
# ID: 8
# 	Head ID: 6
# 	Text: 190°c
# 	Type: CD
# 	Dependent Words:
# 		Dep. ID: 7
# 			Dep. Text: (
# 			Relation Type: punct
# 		Dep. ID: 9
# 			Dep. Text: )
# 			Relation Type: punct
# ID: 7
# 	Head ID: 8
# 	Text: (
# 	Type: -LRB-
# 	Dependent Words:
# ID: 9
# 	Head ID: 8
# 	Text: )
# 	Type: -RRB-
# 	Dependent Words:
# ID: 10
# 	Head ID: 1
# 	Text: .
# 	Type: .
# 	Dependent Words:
# (S (VP (VB Preheat) (NP (DT the) (NN oven)) (PP (IN to) (NP (NP (CD 375) (NN °F)) (-LRB- -LRB-) (NP (CD 190°C)) (-RRB- -RRB-)))) (. .))
# Preheat the oven to 375°F (190°C).
# verb phrases: {0: ('Preheat', 'Preheat the oven to 375 °F 190°C')}
# prep phrases: {0: ('to', 'to 375 °F 190°C', 'preheat')}
# noun lists: {}
# nouns: [('the oven', 'preheat'), ('375 °F 190°C', 'preheat')]
# STARTING ZERO SHOT
# END OF ZERO SHOT
# {'the oven': {'sequence': 'the oven', 'labels': ['appliance', 'cooking utensil', 'ingredient', 'quantity', 'measuring tool', 'chunks', 'time', 'pan', 'colinder', 'container', 'bowl', 'spatula', 'board', 'slices', 'strainer', 'knife'], 'scores': [0.6603502035140991, 0.27906009554862976, 0.027269812300801277, 0.009691516868770123, 0.003572797868400812, 0.0034967483952641487, 0.0033186827786266804, 0.0025509619154036045, 0.002304020570591092, 0.0016342448070645332, 0.001343554467894137, 0.0011761094210669398, 0.00115803605876863, 0.0010976584162563086, 0.0010945851681753993, 0.0008809710270725191]}, '375 °f 190°c': {'sequence': '375 °f 190°c', 'labels': ['quantity', 'time', 'measuring tool', 'pan', 'chunks', 'board', 'strainer', 'colinder', 'container', 'appliance', 'bowl', 'ingredient', 'cooking utensil', 'slices', 'spatula', 'knife'], 'scores': [0.22877123951911926, 0.11253749579191208, 0.10127311199903488, 0.08994412422180176, 0.06457801908254623, 0.05504078045487404, 0.05024312809109688, 0.04392832890152931, 0.04159579053521156, 0.040424805134534836, 0.03497263416647911, 0.033653441816568375, 0.03211284056305885, 0.030477525666356087, 0.023296158760786057, 0.017150605097413063]}}
# ID: 0
# 	Head ID: -1
# 	Text: ROOT
# 	Type: N/A
# 	Dependent Words:
# 		Dep. ID: 7
# 			Dep. Text: roll
# 			Relation Type: root
# ID: 5
# 	Head ID: 7
# 	Text: surface
# 	Type: NN
# 	Dependent Words:
# 		Dep. ID: 1
# 			Dep. Text: on
# 			Relation Type: case
# 		Dep. ID: 2
# 			Dep. Text: a
# 			Relation Type: det
# 		Dep. ID: 4
# 			Dep. Text: floured
# 			Relation Type: amod
# 		Dep. ID: 6
# 			Dep. Text: ,
# 			Relation Type: punct
# ID: 1
# 	Head ID: 5
# 	Text: on
# 	Type: IN
# 	Dependent Words:
# ID: 2
# 	Head ID: 5
# 	Text: a
# 	Type: DT
# 	Dependent Words:
# ID: 4
# 	Head ID: 5
# 	Text: floured
# 	Type: VBN
# 	Dependent Words:
# 		Dep. ID: 3
# 			Dep. Text: lightly
# 			Relation Type: advmod
# ID: 3
# 	Head ID: 4
# 	Text: lightly
# 	Type: RB
# 	Dependent Words:
# ID: 7
# 	Head ID: 0
# 	Text: roll
# 	Type: VB
# 	Dependent Words:
# 		Dep. ID: 5
# 			Dep. Text: surface
# 			Relation Type: obl
# 		Dep. ID: 10
# 			Dep. Text: dough
# 			Relation Type: obj
# 		Dep. ID: 13
# 			Dep. Text: rope
# 			Relation Type: obl
# 		Dep. ID: 28
# 			Dep. Text: .
# 			Relation Type: punct
# ID: 6
# 	Head ID: 5
# 	Text: ,
# 	Type: ,
# 	Dependent Words:
# ID: 10
# 	Head ID: 7
# 	Text: dough
# 	Type: NN
# 	Dependent Words:
# 		Dep. ID: 8
# 			Dep. Text: the
# 			Relation Type: det
# 		Dep. ID: 9
# 			Dep. Text: pizza
# 			Relation Type: compound
# ID: 8
# 	Head ID: 10
# 	Text: the
# 	Type: DT
# 	Dependent Words:
# ID: 9
# 	Head ID: 10
# 	Text: pizza
# 	Type: NN
# 	Dependent Words:
# ID: 13
# 	Head ID: 7
# 	Text: rope
# 	Type: NN
# 	Dependent Words:
# 		Dep. ID: 11
# 			Dep. Text: into
# 			Relation Type: case
# 		Dep. ID: 12
# 			Dep. Text: a
# 			Relation Type: det
# 		Dep. ID: 20
# 			Dep. Text: long
# 			Relation Type: amod
# ID: 11
# 	Head ID: 13
# 	Text: into
# 	Type: IN
# 	Dependent Words:
# ID: 12
# 	Head ID: 13
# 	Text: a
# 	Type: DT
# 	Dependent Words:
# ID: 15
# 	Head ID: 20
# 	Text: inches
# 	Type: NNS
# 	Dependent Words:
# 		Dep. ID: 14
# 			Dep. Text: 36
# 			Relation Type: nummod
# 		Dep. ID: 18
# 			Dep. Text: m
# 			Relation Type: appos
# ID: 14
# 	Head ID: 15
# 	Text: 36
# 	Type: CD
# 	Dependent Words:
# ID: 20
# 	Head ID: 13
# 	Text: long
# 	Type: JJ
# 	Dependent Words:
# 		Dep. ID: 15
# 			Dep. Text: inches
# 			Relation Type: obl:npmod
# 		Dep. ID: 27
# 			Dep. Text: thick
# 			Relation Type: conj
# ID: 18
# 	Head ID: 15
# 	Text: m
# 	Type: NNS
# 	Dependent Words:
# 		Dep. ID: 16
# 			Dep. Text: (
# 			Relation Type: punct
# 		Dep. ID: 17
# 			Dep. Text: 1
# 			Relation Type: nummod
# 		Dep. ID: 19
# 			Dep. Text: )
# 			Relation Type: punct
# ID: 16
# 	Head ID: 18
# 	Text: (
# 	Type: -LRB-
# 	Dependent Words:
# ID: 17
# 	Head ID: 18
# 	Text: 1
# 	Type: CD
# 	Dependent Words:
# ID: 19
# 	Head ID: 18
# 	Text: )
# 	Type: -RRB-
# 	Dependent Words:
# ID: 27
# 	Head ID: 20
# 	Text: thick
# 	Type: JJ
# 	Dependent Words:
# 		Dep. ID: 21
# 			Dep. Text: and
# 			Relation Type: cc
# 		Dep. ID: 22
# 			Dep. Text: ½-inch
# 			Relation Type: nsubj
# ID: 21
# 	Head ID: 27
# 	Text: and
# 	Type: CC
# 	Dependent Words:
# ID: 22
# 	Head ID: 27
# 	Text: ½-inch
# 	Type: NN
# 	Dependent Words:
# 		Dep. ID: 25
# 			Dep. Text: mm
# 			Relation Type: appos
# ID: 25
# 	Head ID: 22
# 	Text: mm
# 	Type: NNS
# 	Dependent Words:
# 		Dep. ID: 23
# 			Dep. Text: (
# 			Relation Type: punct
# 		Dep. ID: 24
# 			Dep. Text: 13
# 			Relation Type: nummod
# 		Dep. ID: 26
# 			Dep. Text: )
# 			Relation Type: punct
# ID: 23
# 	Head ID: 25
# 	Text: (
# 	Type: -LRB-
# 	Dependent Words:
# ID: 24
# 	Head ID: 25
# 	Text: 13
# 	Type: CD
# 	Dependent Words:
# ID: 26
# 	Head ID: 25
# 	Text: )
# 	Type: -RRB-
# 	Dependent Words:
# ID: 28
# 	Head ID: 7
# 	Text: .
# 	Type: .
# 	Dependent Words:
# (S (PP (IN On) (NP (DT a) (ADJP (RB lightly) (VBN floured)) (NN surface))) (, ,) (VP (VB roll) (NP (DT the) (NN pizza) (NN dough)) (PP (IN into) (ADJP (NP (NP (NP (DT a) (NN rope)) (ADJP (ADJP (NP (NP (CD 36) (NNS inches)) (-LRB- -LRB-) (NP (CD 1) (NNS m)) (-RRB- -RRB-)) (JJ long)) (CC and) (NML (NN ½-inch)))) (-LRB- -LRB-) (NP (CD 13) (NNS mm)) (-RRB- -RRB-)) (JJ thick)))) (. .))
# On a lightly floured surface, roll the pizza dough into a rope 36 inches (1 m) long and ½-inch (13 mm) thick.
# verb phrases: {0: ('roll', 'roll the pizza dough into a rope 36 inches 1 m long and ½-inch 13 mm thick')}
# prep phrases: {0: ('On', 'On a lightly floured surface', 'roll'), 1: ('into', 'into a rope 36 inches 1 m long and ½-inch 13 mm thick', 'roll')}
# noun lists: {}
# nouns: [('a lightly floured surface', 'roll'), ('the pizza dough', 'roll'), ('a rope 36 inches 1 m long and ½-inch 13 mm', 'roll')]
# STARTING ZERO SHOT
# END OF ZERO SHOT
# {'a lightly floured surface': {'sequence': 'a lightly floured surface', 'labels': ['quantity', 'time', 'pan', 'colinder', 'bowl', 'strainer', 'spatula', 'appliance', 'cooking utensil', 'ingredient', 'chunks', 'board', 'container', 'slices', 'knife', 'measuring tool'], 'scores': [0.16882666945457458, 0.13141758739948273, 0.11637657880783081, 0.09008967131376266, 0.07271580398082733, 0.06423619389533997, 0.057264670729637146, 0.04584641754627228, 0.044280003756284714, 0.04014340788125992, 0.0398978553712368, 0.03884446248412132, 0.029902515932917595, 0.024153627455234528, 0.019025571644306183, 0.016978979110717773]}, 'the pizza dough': {'sequence': 'the pizza dough', 'labels': ['ingredient', 'quantity', 'cooking utensil', 'measuring tool', 'slices', 'chunks', 'strainer', 'container', 'bowl', 'appliance', 'time', 'pan', 'colinder', 'spatula', 'board', 'knife'], 'scores': [0.9001017808914185, 0.030147822573781013, 0.020204046741127968, 0.007871358655393124, 0.0059272125363349915, 0.005164002534002066, 0.004441666416823864, 0.004140532575547695, 0.0038470211438834667, 0.003700756933540106, 0.003305541817098856, 0.0030160427559167147, 0.0025578041095286608, 0.0020152232609689236, 0.0019694289658218622, 0.0015897911507636309]}, 'a rope 36 inches 1 m long and ½-inch 13 mm': {'sequence': 'a rope 36 inches 1 m long and ½-inch 13 mm', 'labels': ['quantity', 'measuring tool', 'time', 'chunks', 'ingredient', 'strainer', 'colinder', 'slices', 'appliance', 'pan', 'container', 'board', 'knife', 'bowl', 'spatula', 'cooking utensil'], 'scores': [0.5617179274559021, 0.16080620884895325, 0.0571751594543457, 0.03328508138656616, 0.02883099392056465, 0.02271116152405739, 0.019209161400794983, 0.01878085732460022, 0.018594764173030853, 0.015039210207760334, 0.014353886246681213, 0.011566349305212498, 0.010892465710639954, 0.010618114843964577, 0.01000954583287239, 0.006409074645489454]}}
# ID: 0
# 	Head ID: -1
# 	Text: ROOT
# 	Type: N/A
# 	Dependent Words:
# 		Dep. ID: 1
# 			Dep. Text: arrange
# 			Relation Type: root
# ID: 1
# 	Head ID: 0
# 	Text: arrange
# 	Type: VB
# 	Dependent Words:
# 		Dep. ID: 3
# 			Dep. Text: rope
# 			Relation Type: obj
# 		Dep. ID: 7
# 			Dep. Text: edge
# 			Relation Type: obl
# 		Dep. ID: 21
# 			Dep. Text: pinch
# 			Relation Type: conj
# 		Dep. ID: 29
# 			Dep. Text: .
# 			Relation Type: punct
# ID: 3
# 	Head ID: 1
# 	Text: rope
# 	Type: NN
# 	Dependent Words:
# 		Dep. ID: 2
# 			Dep. Text: the
# 			Relation Type: det
# ID: 2
# 	Head ID: 3
# 	Text: the
# 	Type: DT
# 	Dependent Words:
# ID: 7
# 	Head ID: 1
# 	Text: edge
# 	Type: NN
# 	Dependent Words:
# 		Dep. ID: 4
# 			Dep. Text: around
# 			Relation Type: case
# 		Dep. ID: 5
# 			Dep. Text: the
# 			Relation Type: det
# 		Dep. ID: 6
# 			Dep. Text: outer
# 			Relation Type: amod
# 		Dep. ID: 19
# 			Dep. Text: skillet
# 			Relation Type: nmod
# ID: 4
# 	Head ID: 7
# 	Text: around
# 	Type: IN
# 	Dependent Words:
# ID: 5
# 	Head ID: 7
# 	Text: the
# 	Type: DT
# 	Dependent Words:
# ID: 6
# 	Head ID: 7
# 	Text: outer
# 	Type: JJ
# 	Dependent Words:
# ID: 19
# 	Head ID: 7
# 	Text: skillet
# 	Type: NN
# 	Dependent Words:
# 		Dep. ID: 8
# 			Dep. Text: of
# 			Relation Type: case
# 		Dep. ID: 9
# 			Dep. Text: a
# 			Relation Type: det
# 		Dep. ID: 12
# 			Dep. Text: inch
# 			Relation Type: compound
# 		Dep. ID: 18
# 			Dep. Text: ovenproof
# 			Relation Type: compound
# ID: 8
# 	Head ID: 19
# 	Text: of
# 	Type: IN
# 	Dependent Words:
# ID: 9
# 	Head ID: 19
# 	Text: a
# 	Type: DT
# 	Dependent Words:
# ID: 12
# 	Head ID: 19
# 	Text: inch
# 	Type: NN
# 	Dependent Words:
# 		Dep. ID: 10
# 			Dep. Text: 12
# 			Relation Type: nummod
# 		Dep. ID: 11
# 			Dep. Text: -
# 			Relation Type: punct
# 		Dep. ID: 15
# 			Dep. Text: cm
# 			Relation Type: appos
# ID: 10
# 	Head ID: 12
# 	Text: 12
# 	Type: CD
# 	Dependent Words:
# ID: 11
# 	Head ID: 12
# 	Text: -
# 	Type: HYPH
# 	Dependent Words:
# ID: 15
# 	Head ID: 12
# 	Text: cm
# 	Type: NN
# 	Dependent Words:
# 		Dep. ID: 13
# 			Dep. Text: (
# 			Relation Type: punct
# 		Dep. ID: 14
# 			Dep. Text: 30.5
# 			Relation Type: nummod
# 		Dep. ID: 16
# 			Dep. Text: )
# 			Relation Type: punct
# ID: 13
# 	Head ID: 15
# 	Text: (
# 	Type: -LRB-
# 	Dependent Words:
# ID: 14
# 	Head ID: 15
# 	Text: 30.5
# 	Type: CD
# 	Dependent Words:
# ID: 16
# 	Head ID: 15
# 	Text: )
# 	Type: -RRB-
# 	Dependent Words:
# ID: 18
# 	Head ID: 19
# 	Text: ovenproof
# 	Type: NN
# 	Dependent Words:
# 		Dep. ID: 17
# 			Dep. Text: nonstick
# 			Relation Type: compound
# ID: 17
# 	Head ID: 18
# 	Text: nonstick
# 	Type: NN
# 	Dependent Words:
# ID: 21
# 	Head ID: 1
# 	Text: pinch
# 	Type: VB
# 	Dependent Words:
# 		Dep. ID: 20
# 			Dep. Text: and
# 			Relation Type: cc
# 		Dep. ID: 22
# 			Dep. Text: together
# 			Relation Type: advmod
# 		Dep. ID: 24
# 			Dep. Text: ends
# 			Relation Type: obj
# 		Dep. ID: 26
# 			Dep. Text: form
# 			Relation Type: advcl
# ID: 20
# 	Head ID: 21
# 	Text: and
# 	Type: CC
# 	Dependent Words:
# ID: 22
# 	Head ID: 21
# 	Text: together
# 	Type: RB
# 	Dependent Words:
# ID: 24
# 	Head ID: 21
# 	Text: ends
# 	Type: NNS
# 	Dependent Words:
# 		Dep. ID: 23
# 			Dep. Text: the
# 			Relation Type: det
# ID: 23
# 	Head ID: 24
# 	Text: the
# 	Type: DT
# 	Dependent Words:
# ID: 26
# 	Head ID: 21
# 	Text: form
# 	Type: VB
# 	Dependent Words:
# 		Dep. ID: 25
# 			Dep. Text: to
# 			Relation Type: mark
# 		Dep. ID: 28
# 			Dep. Text: ring
# 			Relation Type: obj
# ID: 25
# 	Head ID: 26
# 	Text: to
# 	Type: TO
# 	Dependent Words:
# ID: 28
# 	Head ID: 26
# 	Text: ring
# 	Type: NN
# 	Dependent Words:
# 		Dep. ID: 27
# 			Dep. Text: a
# 			Relation Type: det
# ID: 27
# 	Head ID: 28
# 	Text: a
# 	Type: DT
# 	Dependent Words:
# ID: 29
# 	Head ID: 1
# 	Text: .
# 	Type: .
# 	Dependent Words:
# (S (VP (VP (VB Arrange) (NP (DT the) (NN rope)) (PP (IN around) (NP (NP (DT the) (JJ outer) (NN edge)) (PP (IN of) (NP (DT a) (NML (NML (CD 12) (HYPH -) (NN inch)) (-LRB- -LRB-) (NML (CD 30.5) (NN cm)) (-RRB- -RRB-)) (NML (NN nonstick) (NN ovenproof)) (NN skillet)))))) (CC and) (VP (VB pinch) (ADVP (RB together)) (NP (DT the) (NNS ends)) (S (VP (TO to) (VP (VB form) (NP (DT a) (NN ring))))))) (. .))
# Arrange the rope around the outer edge of a 12-inch (30.5 cm) nonstick ovenproof skillet and pinch together the ends to form a ring.
# verb phrases: {0: ('Arrange', 'Arrange the rope around the outer edge of a 12- inch 30.5 cm nonstick ovenproof skillet'), 1: ('pinch', 'pinch together the ends to form a ring'), 2: ('form', 'form a ring')}
# prep phrases: {0: ('around', 'around the outer edge of a 12- inch 30.5 cm nonstick ovenproof skillet', 'arrange'), 1: ('together', 'together', 'pinch')}
# noun lists: {}
# nouns: [('the rope', 'arrange'), ('the outer edge of a 12- inch 30.5 cm nonstick ovenproof skillet', 'arrange'), ('the ends', 'pinch'), ('a ring', 'pinch')]
# STARTING ZERO SHOT
# END OF ZERO SHOT
# {'the rope': {'sequence': 'the rope', 'labels': ['quantity', 'ingredient', 'chunks', 'strainer', 'time', 'appliance', 'measuring tool', 'pan', 'container', 'colinder', 'slices', 'board', 'bowl', 'spatula', 'knife', 'cooking utensil'], 'scores': [0.21200989186763763, 0.13639289140701294, 0.08251728862524033, 0.07536140829324722, 0.07237429171800613, 0.06554734706878662, 0.05861562490463257, 0.05444414168596268, 0.0388580784201622, 0.03856135532259941, 0.03463846072554588, 0.03284982219338417, 0.027982892468571663, 0.026820173487067223, 0.02160278707742691, 0.02142358012497425]}, 'the outer edge of a 12- inch 30.5 cm nonstick ovenproof skillet': {'sequence': 'the outer edge of a 12- inch 30.5 cm nonstick ovenproof skillet', 'labels': ['cooking utensil', 'pan', 'appliance', 'measuring tool', 'ingredient', 'quantity', 'time', 'slices', 'container', 'strainer', 'chunks', 'colinder', 'spatula', 'bowl', 'knife', 'board'], 'scores': [0.5351508855819702, 0.24402020871639252, 0.11395669728517532, 0.023618949577212334, 0.018588261678814888, 0.014743098989129066, 0.011737404391169548, 0.0069084675051271915, 0.006296644452959299, 0.0047749304212629795, 0.004339310340583324, 0.003978153225034475, 0.0035270447842776775, 0.0029165891464799643, 0.002762974938377738, 0.0026803805958479643]}, 'the ends': {'sequence': 'the ends', 'labels': ['chunks', 'pan', 'strainer', 'quantity', 'time', 'colinder', 'board', 'measuring tool', 'slices', 'appliance', 'container', 'ingredient', 'bowl', 'knife', 'cooking utensil', 'spatula'], 'scores': [0.18019238114356995, 0.10436742752790451, 0.09114431589841843, 0.08759801834821701, 0.07380607724189758, 0.057337772101163864, 0.05197270214557648, 0.05055730789899826, 0.04782797023653984, 0.04599503427743912, 0.040411315858364105, 0.0396852008998394, 0.039120227098464966, 0.03507853299379349, 0.02988145500421524, 0.02502429485321045]}, 'a ring': {'sequence': 'a ring', 'labels': ['appliance', 'quantity', 'ingredient', 'measuring tool', 'board', 'time', 'pan', 'chunks', 'container', 'strainer', 'colinder', 'bowl', 'slices', 'spatula', 'knife', 'cooking utensil'], 'scores': [0.27811193466186523, 0.18452949821949005, 0.10106036812067032, 0.08297304064035416, 0.047730300575494766, 0.04469127953052521, 0.040395863354206085, 0.037458255887031555, 0.0355835035443306, 0.033864911645650864, 0.02461640164256096, 0.024170154705643654, 0.020146984606981277, 0.01973060518503189, 0.014186079613864422, 0.010750800371170044]}}
# ID: 0
# 	Head ID: -1
# 	Text: ROOT
# 	Type: N/A
# 	Dependent Words:
# 		Dep. ID: 1
# 			Dep. Text: cover
# 			Relation Type: root
# ID: 1
# 	Head ID: 0
# 	Text: cover
# 	Type: VB
# 	Dependent Words:
# 		Dep. ID: 5
# 			Dep. Text: towel
# 			Relation Type: obl
# 		Dep. ID: 7
# 			Dep. Text: let
# 			Relation Type: conj
# 		Dep. ID: 19
# 			Dep. Text: .
# 			Relation Type: punct
# ID: 5
# 	Head ID: 1
# 	Text: towel
# 	Type: NN
# 	Dependent Words:
# 		Dep. ID: 2
# 			Dep. Text: with
# 			Relation Type: case
# 		Dep. ID: 3
# 			Dep. Text: a
# 			Relation Type: det
# 		Dep. ID: 4
# 			Dep. Text: kitchen
# 			Relation Type: compound
# ID: 2
# 	Head ID: 5
# 	Text: with
# 	Type: IN
# 	Dependent Words:
# ID: 3
# 	Head ID: 5
# 	Text: a
# 	Type: DT
# 	Dependent Words:
# ID: 4
# 	Head ID: 5
# 	Text: kitchen
# 	Type: NN
# 	Dependent Words:
# ID: 7
# 	Head ID: 1
# 	Text: let
# 	Type: VB
# 	Dependent Words:
# 		Dep. ID: 6
# 			Dep. Text: and
# 			Relation Type: cc
# 		Dep. ID: 8
# 			Dep. Text: stand
# 			Relation Type: xcomp
# ID: 6
# 	Head ID: 7
# 	Text: and
# 	Type: CC
# 	Dependent Words:
# ID: 8
# 	Head ID: 7
# 	Text: stand
# 	Type: VB
# 	Dependent Words:
# 		Dep. ID: 14
# 			Dep. Text: puffed
# 			Relation Type: advcl
# ID: 14
# 	Head ID: 8
# 	Text: puffed
# 	Type: VBN
# 	Dependent Words:
# 		Dep. ID: 9
# 			Dep. Text: until
# 			Relation Type: mark
# 		Dep. ID: 11
# 			Dep. Text: dough
# 			Relation Type: nsubj:pass
# 		Dep. ID: 12
# 			Dep. Text: is
# 			Relation Type: aux:pass
# 		Dep. ID: 13
# 			Dep. Text: slightly
# 			Relation Type: advmod
# 		Dep. ID: 18
# 			Dep. Text: minutes
# 			Relation Type: obl:tmod
# ID: 9
# 	Head ID: 14
# 	Text: until
# 	Type: IN
# 	Dependent Words:
# ID: 11
# 	Head ID: 14
# 	Text: dough
# 	Type: NN
# 	Dependent Words:
# 		Dep. ID: 10
# 			Dep. Text: the
# 			Relation Type: det
# ID: 10
# 	Head ID: 11
# 	Text: the
# 	Type: DT
# 	Dependent Words:
# ID: 12
# 	Head ID: 14
# 	Text: is
# 	Type: VBZ
# 	Dependent Words:
# ID: 13
# 	Head ID: 14
# 	Text: slightly
# 	Type: RB
# 	Dependent Words:
# ID: 18
# 	Head ID: 14
# 	Text: minutes
# 	Type: NNS
# 	Dependent Words:
# 		Dep. ID: 15
# 			Dep. Text: ,
# 			Relation Type: punct
# 		Dep. ID: 17
# 			Dep. Text: 30
# 			Relation Type: nummod
# ID: 15
# 	Head ID: 18
# 	Text: ,
# 	Type: ,
# 	Dependent Words:
# ID: 17
# 	Head ID: 18
# 	Text: 30
# 	Type: CD
# 	Dependent Words:
# 		Dep. ID: 16
# 			Dep. Text: about
# 			Relation Type: advmod
# ID: 16
# 	Head ID: 17
# 	Text: about
# 	Type: RB
# 	Dependent Words:
# ID: 19
# 	Head ID: 1
# 	Text: .
# 	Type: .
# 	Dependent Words:
# (S (S (VP (VP (VB Cover) (PP (IN with) (NP (DT a) (NN kitchen) (NN towel)))) (CC and) (VP (VB let) (S (VP (VB stand))) (SBAR (IN until) (S (NP (DT the) (NN dough)) (VP (VBZ is) (ADJP (RB slightly) (VBN puffed)))))))) (, ,) (NP (QP (RB about) (CD 30)) (NNS minutes)) (. .))
# Cover with a kitchen towel and let stand until the dough is slightly puffed, about 30 minutes.
# verb phrases: {0: ('Cover', 'Cover with a kitchen towel'), 1: ('stand', 'stand')}
# prep phrases: {0: ('with', 'with a kitchen towel', 'cover'), 1: ('until', 'until the dough is slightly puffed', 'puffed')}
# noun lists: {}
# nouns: [('a kitchen towel', 'cover'), ('the dough', 'puffed'), ('about 30 minutes', 'puffed')]
# STARTING ZERO SHOT
# END OF ZERO SHOT
# {'a kitchen towel': {'sequence': 'a kitchen towel', 'labels': ['quantity', 'appliance', 'cooking utensil', 'ingredient', 'chunks', 'time', 'slices', 'strainer', 'container', 'pan', 'bowl', 'measuring tool', 'spatula', 'colinder', 'board', 'knife'], 'scores': [0.22939848899841309, 0.14309543371200562, 0.10975272208452225, 0.09358604997396469, 0.06548602133989334, 0.053054943680763245, 0.0436595156788826, 0.04222479090094566, 0.04180517420172691, 0.03319229558110237, 0.03295106068253517, 0.025851702317595482, 0.02429279126226902, 0.02414540946483612, 0.020912088453769684, 0.016591548919677734]}, 'the dough': {'sequence': 'the dough', 'labels': ['ingredient', 'quantity', 'chunks', 'cooking utensil', 'appliance', 'strainer', 'measuring tool', 'colinder', 'bowl', 'time', 'container', 'pan', 'slices', 'board', 'spatula', 'knife'], 'scores': [0.761481761932373, 0.14630386233329773, 0.012084337882697582, 0.010179607197642326, 0.008187456987798214, 0.008120954968035221, 0.0074303545989096165, 0.007223066873848438, 0.006980457808822393, 0.006452539470046759, 0.005962426774203777, 0.005504750646650791, 0.005266898311674595, 0.00395587831735611, 0.0028091869316995144, 0.002056479686871171]}, 'about 30 minutes': {'sequence': 'about 30 minutes', 'labels': ['time', 'chunks', 'quantity', 'pan', 'board', 'measuring tool', 'strainer', 'cooking utensil', 'container', 'bowl', 'appliance', 'slices', 'colinder', 'ingredient', 'spatula', 'knife'], 'scores': [0.6784334182739258, 0.09161940962076187, 0.05131181702017784, 0.031100524589419365, 0.02210904471576214, 0.017924388870596886, 0.01521223783493042, 0.012969591654837132, 0.012790578417479992, 0.01181492768228054, 0.011352973990142345, 0.010954171419143677, 0.010852172039449215, 0.008161041885614395, 0.007847539149224758, 0.005546110682189465]}}
# ID: 0
# 	Head ID: -1
# 	Text: ROOT
# 	Type: N/A
# 	Dependent Words:
# 		Dep. ID: 1
# 			Dep. Text: drizzle
# 			Relation Type: root
# ID: 1
# 	Head ID: 0
# 	Text: drizzle
# 	Type: NN
# 	Dependent Words:
# 		Dep. ID: 3
# 			Dep. Text: tablespoon
# 			Relation Type: appos
# 		Dep. ID: 9
# 			Dep. Text: center
# 			Relation Type: nmod
# 		Dep. ID: 13
# 			Dep. Text: .
# 			Relation Type: punct
# ID: 3
# 	Head ID: 1
# 	Text: tablespoon
# 	Type: NN
# 	Dependent Words:
# 		Dep. ID: 2
# 			Dep. Text: 1
# 			Relation Type: nummod
# 		Dep. ID: 6
# 			Dep. Text: oil
# 			Relation Type: nmod
# ID: 2
# 	Head ID: 3
# 	Text: 1
# 	Type: CD
# 	Dependent Words:
# ID: 6
# 	Head ID: 3
# 	Text: oil
# 	Type: NN
# 	Dependent Words:
# 		Dep. ID: 4
# 			Dep. Text: of
# 			Relation Type: case
# 		Dep. ID: 5
# 			Dep. Text: olive
# 			Relation Type: compound
# ID: 4
# 	Head ID: 6
# 	Text: of
# 	Type: IN
# 	Dependent Words:
# ID: 5
# 	Head ID: 6
# 	Text: olive
# 	Type: NN
# 	Dependent Words:
# ID: 9
# 	Head ID: 1
# 	Text: center
# 	Type: NN
# 	Dependent Words:
# 		Dep. ID: 7
# 			Dep. Text: into
# 			Relation Type: case
# 		Dep. ID: 8
# 			Dep. Text: the
# 			Relation Type: det
# 		Dep. ID: 12
# 			Dep. Text: skillet
# 			Relation Type: nmod
# ID: 7
# 	Head ID: 9
# 	Text: into
# 	Type: IN
# 	Dependent Words:
# ID: 8
# 	Head ID: 9
# 	Text: the
# 	Type: DT
# 	Dependent Words:
# ID: 12
# 	Head ID: 9
# 	Text: skillet
# 	Type: NN
# 	Dependent Words:
# 		Dep. ID: 10
# 			Dep. Text: of
# 			Relation Type: case
# 		Dep. ID: 11
# 			Dep. Text: the
# 			Relation Type: det
# ID: 10
# 	Head ID: 12
# 	Text: of
# 	Type: IN
# 	Dependent Words:
# ID: 11
# 	Head ID: 12
# 	Text: the
# 	Type: DT
# 	Dependent Words:
# ID: 13
# 	Head ID: 1
# 	Text: .
# 	Type: .
# 	Dependent Words:
# (NP (NP (NML (NN Drizzle) (CD 1)) (NN tablespoon)) (PP (IN of) (NP (NN olive) (NN oil))) (PP (IN into) (NP (NP (DT the) (NN center)) (PP (IN of) (NP (DT the) (NN skillet))))) (. .))
# Drizzle 1 tablespoon of olive oil into the center of the skillet.
# verb phrases: {}
# prep phrases: {0: ('of', 'of olive oil', None), 1: ('into', 'into the center of the skillet', None)}
# noun lists: {}
# nouns: [('Drizzle 1 tablespoon', None), ('olive oil', None), ('the center of the skillet', None)]
# STARTING ZERO SHOT
# END OF ZERO SHOT
# {'drizzle 1 tablespoon': {'sequence': 'drizzle 1 tablespoon', 'labels': ['quantity', 'ingredient', 'measuring tool', 'container', 'time', 'pan', 'cooking utensil', 'appliance', 'bowl', 'colinder', 'strainer', 'chunks', 'board', 'spatula', 'slices', 'knife'], 'scores': [0.4583670496940613, 0.30107346177101135, 0.04762304574251175, 0.03218086436390877, 0.022994551807641983, 0.022727368399500847, 0.021494336426258087, 0.015784669667482376, 0.014512102119624615, 0.01402732077986002, 0.01342921145260334, 0.010785629972815514, 0.009571491740643978, 0.00721282372251153, 0.004823070485144854, 0.003392979735508561]}, 'olive oil': {'sequence': 'olive oil', 'labels': ['ingredient', 'quantity', 'chunks', 'pan', 'measuring tool', 'time', 'colinder', 'strainer', 'container', 'bowl', 'cooking utensil', 'board', 'appliance', 'slices', 'spatula', 'knife'], 'scores': [0.6940746903419495, 0.07910855114459991, 0.03741765022277832, 0.032217346131801605, 0.017866382375359535, 0.017476918175816536, 0.016836170107126236, 0.016825441271066666, 0.014767607674002647, 0.013463767245411873, 0.013333383947610855, 0.012936383485794067, 0.01200726069509983, 0.009668583050370216, 0.007608744781464338, 0.00439116545021534]}, 'the center of the skillet': {'sequence': 'the center of the skillet', 'labels': ['cooking utensil', 'pan', 'ingredient', 'colinder', 'appliance', 'container', 'quantity', 'chunks', 'measuring tool', 'time', 'spatula', 'slices', 'strainer', 'bowl', 'board', 'knife'], 'scores': [0.6772363185882568, 0.19581925868988037, 0.04045126587152481, 0.01964372768998146, 0.01383970957249403, 0.007978856563568115, 0.007815183140337467, 0.006476962938904762, 0.0061454204842448235, 0.005795151460915804, 0.004058390855789185, 0.00375863304361701, 0.003442401997745037, 0.0033924472518265247, 0.002293247962370515, 0.0018530507804825902]}}
# ID: 0
# 	Head ID: -1
# 	Text: ROOT
# 	Type: N/A
# 	Dependent Words:
# 		Dep. ID: 2
# 			Dep. Text: beat
# 			Relation Type: root
# ID: 2
# 	Head ID: 0
# 	Text: beat
# 	Type: VB
# 	Dependent Words:
# 		Dep. ID: 1
# 			Dep. Text: lightly
# 			Relation Type: advmod
# 		Dep. ID: 5
# 			Dep. Text: whites
# 			Relation Type: obj
# 		Dep. ID: 8
# 			Dep. Text: pour
# 			Relation Type: conj
# 		Dep. ID: 15
# 			Dep. Text: .
# 			Relation Type: punct
# ID: 1
# 	Head ID: 2
# 	Text: lightly
# 	Type: RB
# 	Dependent Words:
# ID: 5
# 	Head ID: 2
# 	Text: whites
# 	Type: NNS
# 	Dependent Words:
# 		Dep. ID: 3
# 			Dep. Text: the
# 			Relation Type: det
# 		Dep. ID: 4
# 			Dep. Text: egg
# 			Relation Type: compound
# ID: 3
# 	Head ID: 5
# 	Text: the
# 	Type: DT
# 	Dependent Words:
# ID: 4
# 	Head ID: 5
# 	Text: egg
# 	Type: NN
# 	Dependent Words:
# ID: 8
# 	Head ID: 2
# 	Text: pour
# 	Type: VB
# 	Dependent Words:
# 		Dep. ID: 6
# 			Dep. Text: ,
# 			Relation Type: punct
# 		Dep. ID: 7
# 			Dep. Text: then
# 			Relation Type: advmod
# 		Dep. ID: 11
# 			Dep. Text: center
# 			Relation Type: obl
# ID: 6
# 	Head ID: 8
# 	Text: ,
# 	Type: ,
# 	Dependent Words:
# ID: 7
# 	Head ID: 8
# 	Text: then
# 	Type: RB
# 	Dependent Words:
# ID: 11
# 	Head ID: 8
# 	Text: center
# 	Type: NN
# 	Dependent Words:
# 		Dep. ID: 9
# 			Dep. Text: into
# 			Relation Type: case
# 		Dep. ID: 10
# 			Dep. Text: the
# 			Relation Type: det
# 		Dep. ID: 14
# 			Dep. Text: skillet
# 			Relation Type: nmod
# ID: 9
# 	Head ID: 11
# 	Text: into
# 	Type: IN
# 	Dependent Words:
# ID: 10
# 	Head ID: 11
# 	Text: the
# 	Type: DT
# 	Dependent Words:
# ID: 14
# 	Head ID: 11
# 	Text: skillet
# 	Type: NN
# 	Dependent Words:
# 		Dep. ID: 12
# 			Dep. Text: of
# 			Relation Type: case
# 		Dep. ID: 13
# 			Dep. Text: the
# 			Relation Type: det
# ID: 12
# 	Head ID: 14
# 	Text: of
# 	Type: IN
# 	Dependent Words:
# ID: 13
# 	Head ID: 14
# 	Text: the
# 	Type: DT
# 	Dependent Words:
# ID: 15
# 	Head ID: 2
# 	Text: .
# 	Type: .
# 	Dependent Words:
# (S (ADVP (RB Lightly)) (VP (VP (VB beat) (NP (DT the) (NN egg) (NNS whites))) (, ,) (ADVP (RB then)) (VP (VB pour) (PP (IN into) (NP (NP (DT the) (NN center)) (PP (IN of) (NP (DT the) (NN skillet))))))) (. .))
# Lightly beat the egg whites, then pour into the center of the skillet.
# verb phrases: {0: ('beat', 'beat the egg whites'), 1: ('pour', 'pour into the center of the skillet')}
# prep phrases: {0: ('Lightly', 'Lightly', 'beat'), 1: ('then', 'then', 'pour'), 2: ('into', 'into the center of the skillet', 'pour')}
# noun lists: {}
# nouns: [('the egg whites', 'beat'), ('the center of the skillet', 'pour')]
# STARTING ZERO SHOT
# END OF ZERO SHOT
# {'the egg whites': {'sequence': 'the egg whites', 'labels': ['ingredient', 'quantity', 'measuring tool', 'strainer', 'colinder', 'chunks', 'container', 'time', 'cooking utensil', 'pan', 'board', 'bowl', 'appliance', 'slices', 'spatula', 'knife'], 'scores': [0.8253547549247742, 0.056376706808805466, 0.017189761623740196, 0.015286250971257687, 0.014911326579749584, 0.009830639697611332, 0.00976450927555561, 0.008248436264693737, 0.007079354953020811, 0.007067784201353788, 0.0064885881729424, 0.006070418749004602, 0.005018251948058605, 0.004975649528205395, 0.003936536610126495, 0.0024009831249713898]}, 'the center of the skillet': {'sequence': 'the center of the skillet', 'labels': ['cooking utensil', 'pan', 'ingredient', 'colinder', 'appliance', 'container', 'quantity', 'chunks', 'measuring tool', 'time', 'spatula', 'slices', 'strainer', 'bowl', 'board', 'knife'], 'scores': [0.6772363185882568, 0.19581925868988037, 0.04045126587152481, 0.01964372768998146, 0.01383970957249403, 0.007978856563568115, 0.007815183140337467, 0.006476962938904762, 0.0061454204842448235, 0.005795151460915804, 0.004058390855789185, 0.00375863304361701, 0.003442401997745037, 0.0033924472518265247, 0.002293247962370515, 0.0018530507804825902]}}
# ID: 0
# 	Head ID: -1
# 	Text: ROOT
# 	Type: N/A
# 	Dependent Words:
# 		Dep. ID: 1
# 			Dep. Text: spoon
# 			Relation Type: root
# ID: 1
# 	Head ID: 0
# 	Text: spoon
# 	Type: VB
# 	Dependent Words:
# 		Dep. ID: 4
# 			Dep. Text: sauce
# 			Relation Type: obj
# 		Dep. ID: 8
# 			Dep. Text: whites
# 			Relation Type: obl
# 		Dep. ID: 11
# 			Dep. Text: top
# 			Relation Type: conj
# 		Dep. ID: 17
# 			Dep. Text: .
# 			Relation Type: punct
# ID: 4
# 	Head ID: 1
# 	Text: sauce
# 	Type: NN
# 	Dependent Words:
# 		Dep. ID: 2
# 			Dep. Text: the
# 			Relation Type: det
# 		Dep. ID: 3
# 			Dep. Text: pizza
# 			Relation Type: compound
# ID: 2
# 	Head ID: 4
# 	Text: the
# 	Type: DT
# 	Dependent Words:
# ID: 3
# 	Head ID: 4
# 	Text: pizza
# 	Type: NN
# 	Dependent Words:
# ID: 8
# 	Head ID: 1
# 	Text: whites
# 	Type: NNS
# 	Dependent Words:
# 		Dep. ID: 5
# 			Dep. Text: over
# 			Relation Type: case
# 		Dep. ID: 6
# 			Dep. Text: the
# 			Relation Type: det
# 		Dep. ID: 7
# 			Dep. Text: egg
# 			Relation Type: compound
# ID: 5
# 	Head ID: 8
# 	Text: over
# 	Type: IN
# 	Dependent Words:
# ID: 6
# 	Head ID: 8
# 	Text: the
# 	Type: DT
# 	Dependent Words:
# ID: 7
# 	Head ID: 8
# 	Text: egg
# 	Type: NN
# 	Dependent Words:
# ID: 11
# 	Head ID: 1
# 	Text: top
# 	Type: VB
# 	Dependent Words:
# 		Dep. ID: 9
# 			Dep. Text: ,
# 			Relation Type: punct
# 		Dep. ID: 10
# 			Dep. Text: then
# 			Relation Type: advmod
# 		Dep. ID: 14
# 			Dep. Text: spinach
# 			Relation Type: obl
# ID: 9
# 	Head ID: 11
# 	Text: ,
# 	Type: ,
# 	Dependent Words:
# ID: 10
# 	Head ID: 11
# 	Text: then
# 	Type: RB
# 	Dependent Words:
# ID: 14
# 	Head ID: 11
# 	Text: spinach
# 	Type: NN
# 	Dependent Words:
# 		Dep. ID: 12
# 			Dep. Text: with
# 			Relation Type: case
# 		Dep. ID: 13
# 			Dep. Text: the
# 			Relation Type: det
# 		Dep. ID: 16
# 			Dep. Text: mozzarella
# 			Relation Type: conj
# ID: 12
# 	Head ID: 14
# 	Text: with
# 	Type: IN
# 	Dependent Words:
# ID: 13
# 	Head ID: 14
# 	Text: the
# 	Type: DT
# 	Dependent Words:
# ID: 16
# 	Head ID: 14
# 	Text: mozzarella
# 	Type: NN
# 	Dependent Words:
# 		Dep. ID: 15
# 			Dep. Text: and
# 			Relation Type: cc
# ID: 15
# 	Head ID: 16
# 	Text: and
# 	Type: CC
# 	Dependent Words:
# ID: 17
# 	Head ID: 1
# 	Text: .
# 	Type: .
# 	Dependent Words:
# (S (VP (VP (VB Spoon) (NP (DT the) (NN pizza) (NN sauce)) (PP (IN over) (NP (DT the) (NN egg) (NNS whites)))) (, ,) (ADVP (RB then)) (VP (VB top) (PP (IN with) (NP (DT the) (NN spinach) (CC and) (NN mozzarella))))) (. .))
# Spoon the pizza sauce over the egg whites, then top with the spinach and mozzarella.
# ['spinach', 'mozzarella']
# verb phrases: {0: ('Spoon', 'Spoon the pizza sauce over the egg whites'), 1: ('top', 'top with the spinach and mozzarella')}
# prep phrases: {0: ('over', 'over the egg whites', 'spoon'), 1: ('then', 'then', 'top'), 2: ('with', 'with the spinach and mozzarella', 'top')}
# noun lists: {0: (<ListType.AND: 0>, ['spinach', 'mozzarella'], 'top')}
# nouns: [('the pizza sauce', 'spoon'), ('the egg whites', 'spoon'), ('spinach', 'top', 14), ('mozzarella', 'top', 16)]
# STARTING ZERO SHOT
# END OF ZERO SHOT
# {'the pizza sauce': {'sequence': 'the pizza sauce', 'labels': ['ingredient', 'cooking utensil', 'quantity', 'measuring tool', 'strainer', 'chunks', 'container', 'slices', 'appliance', 'time', 'pan', 'bowl', 'spatula', 'board', 'colinder', 'knife'], 'scores': [0.9030979871749878, 0.018474334850907326, 0.01637444645166397, 0.0076566883362829685, 0.00657208077609539, 0.006044876761734486, 0.0059880465269088745, 0.005579870659857988, 0.00549392169341445, 0.0052169025875627995, 0.00443032244220376, 0.00419984245672822, 0.0031307211611419916, 0.0030372925102710724, 0.002853539539501071, 0.0018491968512535095]}, 'the egg whites': {'sequence': 'the egg whites', 'labels': ['ingredient', 'quantity', 'measuring tool', 'strainer', 'colinder', 'chunks', 'container', 'time', 'cooking utensil', 'pan', 'board', 'bowl', 'appliance', 'slices', 'spatula', 'knife'], 'scores': [0.8253547549247742, 0.056376706808805466, 0.017189761623740196, 0.015286250971257687, 0.014911326579749584, 0.009830639697611332, 0.00976450927555561, 0.008248436264693737, 0.007079354953020811, 0.007067784201353788, 0.0064885881729424, 0.006070418749004602, 0.005018251948058605, 0.004975649528205395, 0.003936536610126495, 0.0024009831249713898]}, 'spinach': {'sequence': 'spinach', 'labels': ['ingredient', 'quantity', 'slices', 'chunks', 'measuring tool', 'strainer', 'pan', 'container', 'time', 'colinder', 'cooking utensil', 'bowl', 'board', 'spatula', 'appliance', 'knife'], 'scores': [0.699695885181427, 0.0840950682759285, 0.03663790971040726, 0.03455555438995361, 0.020301204174757004, 0.018573639914393425, 0.014662799425423145, 0.014520800672471523, 0.014404733665287495, 0.012179858051240444, 0.011864222586154938, 0.009681007824838161, 0.008926219306886196, 0.00872522871941328, 0.007573368493467569, 0.003602456534281373]}, 'mozzarella': {'sequence': 'mozzarella', 'labels': ['ingredient', 'quantity', 'chunks', 'slices', 'measuring tool', 'container', 'time', 'bowl', 'strainer', 'pan', 'appliance', 'board', 'cooking utensil', 'colinder', 'spatula', 'knife'], 'scores': [0.7233625650405884, 0.11271809041500092, 0.035185858607292175, 0.02164403349161148, 0.017209218814969063, 0.012441152706742287, 0.012007837183773518, 0.011561688967049122, 0.009729458019137383, 0.009514592587947845, 0.00938439927995205, 0.006991399452090263, 0.006197142880409956, 0.004939337261021137, 0.0038658613339066505, 0.00324731832370162]}}
# ID: 0
# 	Head ID: -1
# 	Text: ROOT
# 	Type: N/A
# 	Dependent Words:
# 		Dep. ID: 1
# 			Dep. Text: sprinkle
# 			Relation Type: root
# ID: 1
# 	Head ID: 0
# 	Text: sprinkle
# 	Type: VB
# 	Dependent Words:
# 		Dep. ID: 3
# 			Dep. Text: oregano
# 			Relation Type: obj
# 		Dep. ID: 14
# 			Dep. Text: everything
# 			Relation Type: obl
# 		Dep. ID: 15
# 			Dep. Text: .
# 			Relation Type: punct
# ID: 3
# 	Head ID: 1
# 	Text: oregano
# 	Type: NN
# 	Dependent Words:
# 		Dep. ID: 2
# 			Dep. Text: the
# 			Relation Type: det
# 		Dep. ID: 7
# 			Dep. Text: flakes
# 			Relation Type: conj
# 		Dep. ID: 9
# 			Dep. Text: salt
# 			Relation Type: conj
# 		Dep. ID: 12
# 			Dep. Text: pepper
# 			Relation Type: conj
# ID: 2
# 	Head ID: 3
# 	Text: the
# 	Type: DT
# 	Dependent Words:
# ID: 7
# 	Head ID: 3
# 	Text: flakes
# 	Type: NNS
# 	Dependent Words:
# 		Dep. ID: 4
# 			Dep. Text: ,
# 			Relation Type: punct
# 		Dep. ID: 6
# 			Dep. Text: pepper
# 			Relation Type: compound
# ID: 4
# 	Head ID: 7
# 	Text: ,
# 	Type: ,
# 	Dependent Words:
# ID: 6
# 	Head ID: 7
# 	Text: pepper
# 	Type: NN
# 	Dependent Words:
# 		Dep. ID: 5
# 			Dep. Text: red
# 			Relation Type: amod
# ID: 5
# 	Head ID: 6
# 	Text: red
# 	Type: JJ
# 	Dependent Words:
# ID: 9
# 	Head ID: 3
# 	Text: salt
# 	Type: NN
# 	Dependent Words:
# 		Dep. ID: 8
# 			Dep. Text: ,
# 			Relation Type: punct
# ID: 8
# 	Head ID: 9
# 	Text: ,
# 	Type: ,
# 	Dependent Words:
# ID: 12
# 	Head ID: 3
# 	Text: pepper
# 	Type: NN
# 	Dependent Words:
# 		Dep. ID: 10
# 			Dep. Text: ,
# 			Relation Type: punct
# 		Dep. ID: 11
# 			Dep. Text: and
# 			Relation Type: cc
# ID: 10
# 	Head ID: 12
# 	Text: ,
# 	Type: ,
# 	Dependent Words:
# ID: 11
# 	Head ID: 12
# 	Text: and
# 	Type: CC
# 	Dependent Words:
# ID: 14
# 	Head ID: 1
# 	Text: everything
# 	Type: NN
# 	Dependent Words:
# 		Dep. ID: 13
# 			Dep. Text: over
# 			Relation Type: case
# ID: 13
# 	Head ID: 14
# 	Text: over
# 	Type: IN
# 	Dependent Words:
# ID: 15
# 	Head ID: 1
# 	Text: .
# 	Type: .
# 	Dependent Words:
# (S (VP (VB Sprinkle) (NP (NP (DT the) (NN oregano)) (, ,) (NP (JJ red) (NN pepper) (NNS flakes)) (, ,) (NP (NN salt)) (, ,) (CC and) (NP (NN pepper))) (PP (IN over) (NP (NN everything)))) (. .))
# Sprinkle the oregano, red pepper flakes, salt, and pepper over everything.
# ['the oregano', 'red pepper flakes', 'salt', 'pepper']
# everything
# verb phrases: {0: ('Sprinkle', 'Sprinkle the oregano, red pepper flakes, salt, and pepper over everything')}
# prep phrases: {0: ('over', 'over everything', 'sprinkle')}
# noun lists: {0: (<ListType.AND: 0>, ['the oregano', 'red pepper flakes', 'salt', 'pepper', 'everything'], 'sprinkle')}
# nouns: [('the oregano', 'sprinkle'), ('red pepper flakes', 'sprinkle'), ('salt', 'sprinkle'), ('everything', 'sprinkle')]
# STARTING ZERO SHOT
# END OF ZERO SHOT
# {'the oregano': {'sequence': 'the oregano', 'labels': ['ingredient', 'quantity', 'chunks', 'strainer', 'time', 'pan', 'measuring tool', 'container', 'bowl', 'slices', 'cooking utensil', 'appliance', 'colinder', 'board', 'spatula', 'knife'], 'scores': [0.8568583130836487, 0.02650419995188713, 0.016683435067534447, 0.013567021116614342, 0.01225193589925766, 0.01052626222372055, 0.010306431911885738, 0.00850077997893095, 0.007550871465355158, 0.007082993630319834, 0.006956333294510841, 0.005798088386654854, 0.005502353422343731, 0.004469010513275862, 0.004138797055929899, 0.0033031438942998648]}, 'red pepper flakes': {'sequence': 'red pepper flakes', 'labels': ['ingredient', 'quantity', 'pan', 'container', 'chunks', 'bowl', 'board', 'measuring tool', 'cooking utensil', 'strainer', 'time', 'appliance', 'slices', 'spatula', 'colinder', 'knife'], 'scores': [0.5736120343208313, 0.11250946670770645, 0.05475620552897453, 0.030802229419350624, 0.030393842607736588, 0.028173234313726425, 0.02801661379635334, 0.025248102843761444, 0.021807735785841942, 0.01857060194015503, 0.01685752347111702, 0.015555888414382935, 0.01466202363371849, 0.010619079694151878, 0.010537708178162575, 0.007877739146351814]}, 'salt': {'sequence': 'salt', 'labels': ['ingredient', 'quantity', 'measuring tool', 'chunks', 'strainer', 'container', 'slices', 'cooking utensil', 'pan', 'colinder', 'time', 'board', 'appliance', 'bowl', 'spatula', 'knife'], 'scores': [0.5995172262191772, 0.15117676556110382, 0.04594683274626732, 0.03402287885546684, 0.02152997814118862, 0.018177440389990807, 0.0164091344922781, 0.016272446140646935, 0.016259904950857162, 0.015932772308588028, 0.015468874014914036, 0.014592953957617283, 0.011353976093232632, 0.00983872264623642, 0.008873239159584045, 0.004626900888979435]}, 'everything': {'sequence': 'everything', 'labels': ['quantity', 'pan', 'ingredient', 'time', 'board', 'measuring tool', 'cooking utensil', 'appliance', 'strainer', 'container', 'chunks', 'bowl', 'colinder', 'slices', 'spatula', 'knife'], 'scores': [0.16632258892059326, 0.09533306211233139, 0.0917079746723175, 0.08635502308607101, 0.07348573207855225, 0.07248696684837341, 0.05984433367848396, 0.0561978854238987, 0.05431678146123886, 0.04697920009493828, 0.039456527680158615, 0.0392630361020565, 0.03482819348573685, 0.03288453072309494, 0.027190223336219788, 0.023347903043031693]}}
# ID: 0
# 	Head ID: -1
# 	Text: ROOT
# 	Type: N/A
# 	Dependent Words:
# 		Dep. ID: 1
# 			Dep. Text: brush
# 			Relation Type: root
# ID: 1
# 	Head ID: 0
# 	Text: brush
# 	Type: VB
# 	Dependent Words:
# 		Dep. ID: 2
# 			Dep. Text: some
# 			Relation Type: obj
# 		Dep. ID: 12
# 			Dep. Text: ring
# 			Relation Type: obl
# 		Dep. ID: 15
# 			Dep. Text: drizzle
# 			Relation Type: conj
# 		Dep. ID: 23
# 			Dep. Text: .
# 			Relation Type: punct
# ID: 2
# 	Head ID: 1
# 	Text: some
# 	Type: DT
# 	Dependent Words:
# 		Dep. ID: 8
# 			Dep. Text: oil
# 			Relation Type: nmod
# ID: 8
# 	Head ID: 2
# 	Text: oil
# 	Type: NN
# 	Dependent Words:
# 		Dep. ID: 3
# 			Dep. Text: of
# 			Relation Type: case
# 		Dep. ID: 4
# 			Dep. Text: the
# 			Relation Type: det
# 		Dep. ID: 6
# 			Dep. Text: tablespoon
# 			Relation Type: compound
# 		Dep. ID: 7
# 			Dep. Text: olive
# 			Relation Type: compound
# ID: 3
# 	Head ID: 8
# 	Text: of
# 	Type: IN
# 	Dependent Words:
# ID: 4
# 	Head ID: 8
# 	Text: the
# 	Type: DT
# 	Dependent Words:
# ID: 6
# 	Head ID: 8
# 	Text: tablespoon
# 	Type: NN
# 	Dependent Words:
# 		Dep. ID: 5
# 			Dep. Text: remaining
# 			Relation Type: amod
# ID: 5
# 	Head ID: 6
# 	Text: remaining
# 	Type: VBG
# 	Dependent Words:
# ID: 7
# 	Head ID: 8
# 	Text: olive
# 	Type: NN
# 	Dependent Words:
# ID: 12
# 	Head ID: 1
# 	Text: ring
# 	Type: NN
# 	Dependent Words:
# 		Dep. ID: 9
# 			Dep. Text: over
# 			Relation Type: case
# 		Dep. ID: 10
# 			Dep. Text: the
# 			Relation Type: det
# 		Dep. ID: 11
# 			Dep. Text: dough
# 			Relation Type: compound
# ID: 9
# 	Head ID: 12
# 	Text: over
# 	Type: IN
# 	Dependent Words:
# ID: 10
# 	Head ID: 12
# 	Text: the
# 	Type: DT
# 	Dependent Words:
# ID: 11
# 	Head ID: 12
# 	Text: dough
# 	Type: NN
# 	Dependent Words:
# ID: 15
# 	Head ID: 1
# 	Text: drizzle
# 	Type: VB
# 	Dependent Words:
# 		Dep. ID: 13
# 			Dep. Text: ,
# 			Relation Type: punct
# 		Dep. ID: 14
# 			Dep. Text: then
# 			Relation Type: advmod
# 		Dep. ID: 19
# 			Dep. Text: oil
# 			Relation Type: obj
# 		Dep. ID: 22
# 			Dep. Text: center
# 			Relation Type: obl
# ID: 13
# 	Head ID: 15
# 	Text: ,
# 	Type: ,
# 	Dependent Words:
# ID: 14
# 	Head ID: 15
# 	Text: then
# 	Type: RB
# 	Dependent Words:
# ID: 19
# 	Head ID: 15
# 	Text: oil
# 	Type: NN
# 	Dependent Words:
# 		Dep. ID: 16
# 			Dep. Text: any
# 			Relation Type: det
# 		Dep. ID: 17
# 			Dep. Text: remaining
# 			Relation Type: amod
# 		Dep. ID: 18
# 			Dep. Text: olive
# 			Relation Type: compound
# ID: 16
# 	Head ID: 19
# 	Text: any
# 	Type: DT
# 	Dependent Words:
# ID: 17
# 	Head ID: 19
# 	Text: remaining
# 	Type: VBG
# 	Dependent Words:
# ID: 18
# 	Head ID: 19
# 	Text: olive
# 	Type: NN
# 	Dependent Words:
# ID: 22
# 	Head ID: 15
# 	Text: center
# 	Type: NN
# 	Dependent Words:
# 		Dep. ID: 20
# 			Dep. Text: over
# 			Relation Type: case
# 		Dep. ID: 21
# 			Dep. Text: the
# 			Relation Type: det
# ID: 20
# 	Head ID: 22
# 	Text: over
# 	Type: IN
# 	Dependent Words:
# ID: 21
# 	Head ID: 22
# 	Text: the
# 	Type: DT
# 	Dependent Words:
# ID: 23
# 	Head ID: 1
# 	Text: .
# 	Type: .
# 	Dependent Words:
# (S (VP (VP (VB Brush) (NP (NP (DT some)) (PP (IN of) (NP (NP (DT the) (VBG remaining) (NN tablespoon) (NN olive) (NN oil)) (PP (IN over) (NP (DT the) (NN dough) (NN ring))))))) (, ,) (ADVP (RB then)) (VP (VB drizzle) (NP (DT any) (VBG remaining) (NN olive) (NN oil)) (PP (IN over) (NP (DT the) (NN center))))) (. .))
# Brush some of the remaining tablespoon olive oil over the dough ring, then drizzle any remaining olive oil over the center.
# verb phrases: {0: ('Brush', 'Brush some of the remaining tablespoon olive oil over the dough ring'), 1: ('drizzle', 'drizzle any remaining olive oil over the center')}
# prep phrases: {0: ('of', 'of the remaining tablespoon olive oil over the dough ring', 'brush'), 1: ('then', 'then', 'drizzle'), 2: ('over', 'over the center', 'drizzle')}
# noun lists: {}
# nouns: [('some of the remaining tablespoon olive oil over the dough ring', 'brush'), ('any remaining olive oil', 'drizzle'), ('the center', 'drizzle')]
# STARTING ZERO SHOT
# END OF ZERO SHOT
# {'some of the remaining tablespoon olive oil over the dough ring': {'sequence': 'some of the remaining tablespoon olive oil over the dough ring', 'labels': ['ingredient', 'quantity', 'cooking utensil', 'container', 'time', 'appliance', 'pan', 'measuring tool', 'strainer', 'bowl', 'chunks', 'slices', 'colinder', 'board', 'spatula', 'knife'], 'scores': [0.40175530314445496, 0.1571797877550125, 0.09185020625591278, 0.06632959097623825, 0.05638465657830238, 0.03266821429133415, 0.027887016534805298, 0.026495549827814102, 0.025648899376392365, 0.024231279268860817, 0.022759996354579926, 0.01805577427148819, 0.01582878828048706, 0.0129358796402812, 0.012381485663354397, 0.007607560604810715]}, 'any remaining olive oil': {'sequence': 'any remaining olive oil', 'labels': ['ingredient', 'quantity', 'board', 'pan', 'container', 'strainer', 'measuring tool', 'chunks', 'bowl', 'time', 'colinder', 'cooking utensil', 'slices', 'appliance', 'spatula', 'knife'], 'scores': [0.5175586938858032, 0.20314089953899384, 0.03560358285903931, 0.03522513061761856, 0.029715780168771744, 0.02852790802717209, 0.02636716328561306, 0.024156110361218452, 0.01937171258032322, 0.01574663631618023, 0.015657996758818626, 0.014874471351504326, 0.01284716371446848, 0.011052089743316174, 0.006403221283107996, 0.0037513754796236753]}, 'the center': {'sequence': 'the center', 'labels': ['colinder', 'time', 'pan', 'bowl', 'ingredient', 'container', 'measuring tool', 'cooking utensil', 'board', 'appliance', 'quantity', 'spatula', 'strainer', 'chunks', 'knife', 'slices'], 'scores': [0.3149016499519348, 0.08747337758541107, 0.07915528863668442, 0.061302416026592255, 0.051629893481731415, 0.04883207380771637, 0.04865621402859688, 0.04778842255473137, 0.045586831867694855, 0.040216896682977676, 0.03863193094730377, 0.03618108481168747, 0.034631215035915375, 0.024696199223399162, 0.024066157639026642, 0.016250424087047577]}}
# ID: 0
# 	Head ID: -1
# 	Text: ROOT
# 	Type: N/A
# 	Dependent Words:
# 		Dep. ID: 1
# 			Dep. Text: bake
# 			Relation Type: root
# ID: 1
# 	Head ID: 0
# 	Text: bake
# 	Type: VB
# 	Dependent Words:
# 		Dep. ID: 3
# 			Dep. Text: pizza
# 			Relation Type: obj
# 		Dep. ID: 9
# 			Dep. Text: brown
# 			Relation Type: advcl
# 		Dep. ID: 14
# 			Dep. Text: melted
# 			Relation Type: parataxis
# 		Dep. ID: 21
# 			Dep. Text: cooked
# 			Relation Type: conj
# 		Dep. ID: 28
# 			Dep. Text: .
# 			Relation Type: punct
# ID: 3
# 	Head ID: 1
# 	Text: pizza
# 	Type: NN
# 	Dependent Words:
# 		Dep. ID: 2
# 			Dep. Text: the
# 			Relation Type: det
# ID: 2
# 	Head ID: 3
# 	Text: the
# 	Type: DT
# 	Dependent Words:
# ID: 9
# 	Head ID: 1
# 	Text: brown
# 	Type: JJ
# 	Dependent Words:
# 		Dep. ID: 4
# 			Dep. Text: until
# 			Relation Type: mark
# 		Dep. ID: 6
# 			Dep. Text: dough
# 			Relation Type: nsubj
# 		Dep. ID: 7
# 			Dep. Text: is
# 			Relation Type: cop
# 		Dep. ID: 8
# 			Dep. Text: golden
# 			Relation Type: amod
# ID: 4
# 	Head ID: 9
# 	Text: until
# 	Type: IN
# 	Dependent Words:
# ID: 6
# 	Head ID: 9
# 	Text: dough
# 	Type: NN
# 	Dependent Words:
# 		Dep. ID: 5
# 			Dep. Text: the
# 			Relation Type: det
# ID: 5
# 	Head ID: 6
# 	Text: the
# 	Type: DT
# 	Dependent Words:
# ID: 7
# 	Head ID: 9
# 	Text: is
# 	Type: VBZ
# 	Dependent Words:
# ID: 8
# 	Head ID: 9
# 	Text: golden
# 	Type: JJ
# 	Dependent Words:
# ID: 14
# 	Head ID: 1
# 	Text: melted
# 	Type: VBN
# 	Dependent Words:
# 		Dep. ID: 10
# 			Dep. Text: ,
# 			Relation Type: punct
# 		Dep. ID: 12
# 			Dep. Text: cheese
# 			Relation Type: nsubj
# 		Dep. ID: 13
# 			Dep. Text: has
# 			Relation Type: aux
# ID: 10
# 	Head ID: 14
# 	Text: ,
# 	Type: ,
# 	Dependent Words:
# ID: 12
# 	Head ID: 14
# 	Text: cheese
# 	Type: NN
# 	Dependent Words:
# 		Dep. ID: 11
# 			Dep. Text: the
# 			Relation Type: det
# ID: 11
# 	Head ID: 12
# 	Text: the
# 	Type: DT
# 	Dependent Words:
# ID: 13
# 	Head ID: 14
# 	Text: has
# 	Type: VBZ
# 	Dependent Words:
# ID: 21
# 	Head ID: 1
# 	Text: cooked
# 	Type: VBN
# 	Dependent Words:
# 		Dep. ID: 15
# 			Dep. Text: ,
# 			Relation Type: punct
# 		Dep. ID: 16
# 			Dep. Text: and
# 			Relation Type: cc
# 		Dep. ID: 19
# 			Dep. Text: whites
# 			Relation Type: nsubj:pass
# 		Dep. ID: 20
# 			Dep. Text: are
# 			Relation Type: aux:pass
# 		Dep. ID: 27
# 			Dep. Text: minutes
# 			Relation Type: obl
# ID: 15
# 	Head ID: 21
# 	Text: ,
# 	Type: ,
# 	Dependent Words:
# ID: 16
# 	Head ID: 21
# 	Text: and
# 	Type: CC
# 	Dependent Words:
# ID: 19
# 	Head ID: 21
# 	Text: whites
# 	Type: NNS
# 	Dependent Words:
# 		Dep. ID: 17
# 			Dep. Text: the
# 			Relation Type: det
# 		Dep. ID: 18
# 			Dep. Text: egg
# 			Relation Type: compound
# ID: 17
# 	Head ID: 19
# 	Text: the
# 	Type: DT
# 	Dependent Words:
# ID: 18
# 	Head ID: 19
# 	Text: egg
# 	Type: NN
# 	Dependent Words:
# ID: 20
# 	Head ID: 21
# 	Text: are
# 	Type: VBP
# 	Dependent Words:
# ID: 27
# 	Head ID: 21
# 	Text: minutes
# 	Type: NNS
# 	Dependent Words:
# 		Dep. ID: 22
# 			Dep. Text: through
# 			Relation Type: case
# 		Dep. ID: 23
# 			Dep. Text: ,
# 			Relation Type: punct
# 		Dep. ID: 24
# 			Dep. Text: 20
# 			Relation Type: nummod
# ID: 22
# 	Head ID: 27
# 	Text: through
# 	Type: IN
# 	Dependent Words:
# ID: 23
# 	Head ID: 27
# 	Text: ,
# 	Type: ,
# 	Dependent Words:
# ID: 24
# 	Head ID: 27
# 	Text: 20
# 	Type: CD
# 	Dependent Words:
# 		Dep. ID: 26
# 			Dep. Text: 25
# 			Relation Type: nmod
# ID: 26
# 	Head ID: 24
# 	Text: 25
# 	Type: CD
# 	Dependent Words:
# 		Dep. ID: 25
# 			Dep. Text: –
# 			Relation Type: case
# ID: 25
# 	Head ID: 26
# 	Text: –
# 	Type: SYM
# 	Dependent Words:
# ID: 28
# 	Head ID: 1
# 	Text: .
# 	Type: .
# 	Dependent Words:
# (S (S (VP (VB Bake) (NP (DT the) (NN pizza)) (SBAR (IN until) (S (NP (DT the) (NN dough)) (VP (VBZ is) (ADJP (JJ golden) (JJ brown))))))) (, ,) (S (NP (DT the) (NN cheese)) (VP (VBZ has) (VP (VBN melted)))) (, ,) (CC and) (S (NP (DT the) (NN egg) (NNS whites)) (VP (VBP are) (VP (VP (VBN cooked) (PP (IN through))) (, ,) (NP (QP (CD 20) (SYM –) (CD 25)) (NNS minutes))))) (. .))
# Bake the pizza until the dough is golden brown, the cheese has melted, and the egg whites are cooked through, 20–25 minutes.
# ...
# ID: 0
# 	Head ID: -1
# 	Text: ROOT
# 	Type: N/A
# 	Dependent Words:
# 		Dep. ID: 1
# 			Dep. Text: transfer
# 			Relation Type: root
# ID: 1
# 	Head ID: 0
# 	Text: transfer
# 	Type: VB
# 	Dependent Words:
# 		Dep. ID: 3
# 			Dep. Text: skillet
# 			Relation Type: obj
# 		Dep. ID: 7
# 			Dep. Text: rack
# 			Relation Type: obl
# 		Dep. ID: 8
# 			Dep. Text: .
# 			Relation Type: punct
# ID: 3
# 	Head ID: 1
# 	Text: skillet
# 	Type: NN
# 	Dependent Words:
# 		Dep. ID: 2
# 			Dep. Text: the
# 			Relation Type: det
# ID: 2
# 	Head ID: 3
# 	Text: the
# 	Type: DT
# 	Dependent Words:
# ID: 7
# 	Head ID: 1
# 	Text: rack
# 	Type: NN
# 	Dependent Words:
# 		Dep. ID: 4
# 			Dep. Text: to
# 			Relation Type: case
# 		Dep. ID: 5
# 			Dep. Text: a
# 			Relation Type: det
# 		Dep. ID: 6
# 			Dep. Text: wire
# 			Relation Type: compound
# ID: 4
# 	Head ID: 7
# 	Text: to
# 	Type: IN
# 	Dependent Words:
# ID: 5
# 	Head ID: 7
# 	Text: a
# 	Type: DT
# 	Dependent Words:
# ID: 6
# 	Head ID: 7
# 	Text: wire
# 	Type: NN
# 	Dependent Words:
# ID: 8
# 	Head ID: 1
# 	Text: .
# 	Type: .
# 	Dependent Words:
# (S (VP (VB Transfer) (NP (DT the) (NN skillet)) (PP (IN to) (NP (DT a) (NN wire) (NN rack)))) (. .))
# Transfer the skillet to a wire rack.
# verb phrases: {0: ('Transfer', 'Transfer the skillet to a wire rack')}
# prep phrases: {0: ('to', 'to a wire rack', 'transfer')}
# noun lists: {}
# nouns: [('the skillet', 'transfer'), ('a wire rack', 'transfer')]
# STARTING ZERO SHOT
# END OF ZERO SHOT
# {'the skillet': {'sequence': 'the skillet', 'labels': ['cooking utensil', 'pan', 'ingredient', 'appliance', 'quantity', 'chunks', 'time', 'measuring tool', 'container', 'spatula', 'slices', 'colinder', 'strainer', 'board', 'bowl', 'knife'], 'scores': [0.7201952338218689, 0.1347857117652893, 0.08588694036006927, 0.028935382142663002, 0.006916466169059277, 0.005202547647058964, 0.0028882878832519054, 0.0028224496636539698, 0.0021820496767759323, 0.0019661884289234877, 0.0019500229973345995, 0.0017324264626950026, 0.0013590218732133508, 0.0012475482653826475, 0.0012316129868850112, 0.0006981259793974459]}, 'a wire rack': {'sequence': 'a wire rack', 'labels': ['appliance', 'container', 'quantity', 'measuring tool', 'chunks', 'time', 'strainer', 'ingredient', 'cooking utensil', 'board', 'colinder', 'slices', 'pan', 'bowl', 'spatula', 'knife'], 'scores': [0.40154826641082764, 0.08460855484008789, 0.08399451524019241, 0.0804532915353775, 0.07907411456108093, 0.04180372878909111, 0.039523895829916, 0.03576795756816864, 0.03170231729745865, 0.02403862774372101, 0.02202587202191353, 0.018677858635783195, 0.01839591935276985, 0.015558194369077682, 0.013100460171699524, 0.009726447984576225]}}
# ID: 0
# 	Head ID: -1
# 	Text: ROOT
# 	Type: N/A
# 	Dependent Words:
# 		Dep. ID: 1
# 			Dep. Text: sprinkle
# 			Relation Type: root
# ID: 1
# 	Head ID: 0
# 	Text: sprinkle
# 	Type: VB
# 	Dependent Words:
# 		Dep. ID: 2
# 			Dep. Text: evenly
# 			Relation Type: advmod
# 		Dep. ID: 5
# 			Dep. Text: parmesan
# 			Relation Type: obl
# 		Dep. ID: 7
# 			Dep. Text: let
# 			Relation Type: conj
# 		Dep. ID: 12
# 			Dep. Text: .
# 			Relation Type: punct
# ID: 2
# 	Head ID: 1
# 	Text: evenly
# 	Type: RB
# 	Dependent Words:
# ID: 5
# 	Head ID: 1
# 	Text: parmesan
# 	Type: NN
# 	Dependent Words:
# 		Dep. ID: 3
# 			Dep. Text: with
# 			Relation Type: case
# 		Dep. ID: 4
# 			Dep. Text: the
# 			Relation Type: det
# ID: 3
# 	Head ID: 5
# 	Text: with
# 	Type: IN
# 	Dependent Words:
# ID: 4
# 	Head ID: 5
# 	Text: the
# 	Type: DT
# 	Dependent Words:
# ID: 7
# 	Head ID: 1
# 	Text: let
# 	Type: VB
# 	Dependent Words:
# 		Dep. ID: 6
# 			Dep. Text: and
# 			Relation Type: cc
# 		Dep. ID: 8
# 			Dep. Text: cool
# 			Relation Type: xcomp
# 		Dep. ID: 11
# 			Dep. Text: minute
# 			Relation Type: obl
# ID: 6
# 	Head ID: 7
# 	Text: and
# 	Type: CC
# 	Dependent Words:
# ID: 8
# 	Head ID: 7
# 	Text: cool
# 	Type: JJ
# 	Dependent Words:
# ID: 11
# 	Head ID: 7
# 	Text: minute
# 	Type: NN
# 	Dependent Words:
# 		Dep. ID: 9
# 			Dep. Text: for
# 			Relation Type: case
# 		Dep. ID: 10
# 			Dep. Text: 1
# 			Relation Type: nummod
# ID: 9
# 	Head ID: 11
# 	Text: for
# 	Type: IN
# 	Dependent Words:
# ID: 10
# 	Head ID: 11
# 	Text: 1
# 	Type: CD
# 	Dependent Words:
# ID: 12
# 	Head ID: 1
# 	Text: .
# 	Type: .
# 	Dependent Words:
# (S (VP (VP (VB Sprinkle) (ADVP (RB evenly)) (PP (IN with) (NP (DT the) (NN Parmesan)))) (CC and) (VP (VB let) (S (ADJP (JJ cool))) (PP (IN for) (NP (CD 1) (NN minute))))) (. .))
# Sprinkle evenly with the Parmesan and let cool for 1 minute.
# verb phrases: {0: ('Sprinkle', 'Sprinkle evenly with the Parmesan')}
# prep phrases: {0: ('evenly', 'evenly', 'sprinkle'), 1: ('with', 'with the Parmesan', 'sprinkle'), 2: ('for', 'for 1 minute', 'let')}
# noun lists: {}
# nouns: [('the Parmesan', 'sprinkle'), ('1 minute', 'let')]
# STARTING ZERO SHOT
# END OF ZERO SHOT
# {'the parmesan': {'sequence': 'the parmesan', 'labels': ['ingredient', 'quantity', 'chunks', 'measuring tool', 'pan', 'time', 'slices', 'appliance', 'container', 'cooking utensil', 'bowl', 'board', 'strainer', 'colinder', 'spatula', 'knife'], 'scores': [0.8605581521987915, 0.04497029259800911, 0.019980113953351974, 0.010417711921036243, 0.010178201831877232, 0.007178277708590031, 0.00699352053925395, 0.005608192645013332, 0.005591986700892448, 0.005576548632234335, 0.005355009809136391, 0.005055960733443499, 0.004907536320388317, 0.002824743278324604, 0.0027976161800324917, 0.0020060844253748655]}, '1 minute': {'sequence': '1 minute', 'labels': ['time', 'quantity', 'chunks', 'pan', 'measuring tool', 'board', 'appliance', 'cooking utensil', 'colinder', 'strainer', 'container', 'bowl', 'slices', 'ingredient', 'spatula', 'knife'], 'scores': [0.6831900477409363, 0.08512834459543228, 0.04551837220788002, 0.029136013239622116, 0.02783096581697464, 0.025180798023939133, 0.013231825083494186, 0.01250353641808033, 0.012353768572211266, 0.011934485286474228, 0.011847360990941525, 0.010301471687853336, 0.009979731403291225, 0.009749925695359707, 0.006556633394211531, 0.005556733347475529]}}
# ID: 0
# 	Head ID: -1
# 	Text: ROOT
# 	Type: N/A
# 	Dependent Words:
# 		Dep. ID: 1
# 			Dep. Text: run
# 			Relation Type: root
# ID: 1
# 	Head ID: 0
# 	Text: run
# 	Type: VB
# 	Dependent Words:
# 		Dep. ID: 3
# 			Dep. Text: spatula
# 			Relation Type: obj
# 		Dep. ID: 6
# 			Dep. Text: edges
# 			Relation Type: obl
# 		Dep. ID: 11
# 			Dep. Text: loosen
# 			Relation Type: advcl
# 		Dep. ID: 17
# 			Dep. Text: slide
# 			Relation Type: conj
# 		Dep. ID: 29
# 			Dep. Text: .
# 			Relation Type: punct
# ID: 3
# 	Head ID: 1
# 	Text: spatula
# 	Type: NN
# 	Dependent Words:
# 		Dep. ID: 2
# 			Dep. Text: a
# 			Relation Type: det
# ID: 2
# 	Head ID: 3
# 	Text: a
# 	Type: DT
# 	Dependent Words:
# ID: 6
# 	Head ID: 1
# 	Text: edges
# 	Type: NNS
# 	Dependent Words:
# 		Dep. ID: 4
# 			Dep. Text: around
# 			Relation Type: case
# 		Dep. ID: 5
# 			Dep. Text: the
# 			Relation Type: det
# 		Dep. ID: 9
# 			Dep. Text: skillet
# 			Relation Type: nmod
# ID: 4
# 	Head ID: 6
# 	Text: around
# 	Type: IN
# 	Dependent Words:
# ID: 5
# 	Head ID: 6
# 	Text: the
# 	Type: DT
# 	Dependent Words:
# ID: 9
# 	Head ID: 6
# 	Text: skillet
# 	Type: NN
# 	Dependent Words:
# 		Dep. ID: 7
# 			Dep. Text: of
# 			Relation Type: case
# 		Dep. ID: 8
# 			Dep. Text: the
# 			Relation Type: det
# ID: 7
# 	Head ID: 9
# 	Text: of
# 	Type: IN
# 	Dependent Words:
# ID: 8
# 	Head ID: 9
# 	Text: the
# 	Type: DT
# 	Dependent Words:
# ID: 11
# 	Head ID: 1
# 	Text: loosen
# 	Type: VB
# 	Dependent Words:
# 		Dep. ID: 10
# 			Dep. Text: to
# 			Relation Type: mark
# 		Dep. ID: 13
# 			Dep. Text: pizza
# 			Relation Type: obj
# ID: 10
# 	Head ID: 11
# 	Text: to
# 	Type: TO
# 	Dependent Words:
# ID: 13
# 	Head ID: 11
# 	Text: pizza
# 	Type: NN
# 	Dependent Words:
# 		Dep. ID: 12
# 			Dep. Text: the
# 			Relation Type: det
# ID: 12
# 	Head ID: 13
# 	Text: the
# 	Type: DT
# 	Dependent Words:
# ID: 17
# 	Head ID: 1
# 	Text: slide
# 	Type: VB
# 	Dependent Words:
# 		Dep. ID: 14
# 			Dep. Text: ,
# 			Relation Type: punct
# 		Dep. ID: 15
# 			Dep. Text: then
# 			Relation Type: advmod
# 		Dep. ID: 16
# 			Dep. Text: carefully
# 			Relation Type: advmod
# 		Dep. ID: 18
# 			Dep. Text: it
# 			Relation Type: obj
# 		Dep. ID: 22
# 			Dep. Text: board
# 			Relation Type: obl
# 		Dep. ID: 24
# 			Dep. Text: slice
# 			Relation Type: conj
# ID: 14
# 	Head ID: 17
# 	Text: ,
# 	Type: ,
# 	Dependent Words:
# ID: 15
# 	Head ID: 17
# 	Text: then
# 	Type: RB
# 	Dependent Words:
# ID: 16
# 	Head ID: 17
# 	Text: carefully
# 	Type: RB
# 	Dependent Words:
# ID: 18
# 	Head ID: 17
# 	Text: it
# 	Type: PRP
# 	Dependent Words:
# ID: 22
# 	Head ID: 17
# 	Text: board
# 	Type: NN
# 	Dependent Words:
# 		Dep. ID: 19
# 			Dep. Text: onto
# 			Relation Type: case
# 		Dep. ID: 20
# 			Dep. Text: a
# 			Relation Type: det
# 		Dep. ID: 21
# 			Dep. Text: cutting
# 			Relation Type: compound
# ID: 19
# 	Head ID: 22
# 	Text: onto
# 	Type: IN
# 	Dependent Words:
# ID: 20
# 	Head ID: 22
# 	Text: a
# 	Type: DT
# 	Dependent Words:
# ID: 21
# 	Head ID: 22
# 	Text: cutting
# 	Type: NN
# 	Dependent Words:
# ID: 24
# 	Head ID: 17
# 	Text: slice
# 	Type: VB
# 	Dependent Words:
# 		Dep. ID: 23
# 			Dep. Text: and
# 			Relation Type: cc
# 		Dep. ID: 28
# 			Dep. Text: wedges
# 			Relation Type: obl
# ID: 23
# 	Head ID: 24
# 	Text: and
# 	Type: CC
# 	Dependent Words:
# ID: 28
# 	Head ID: 24
# 	Text: wedges
# 	Type: NNS
# 	Dependent Words:
# 		Dep. ID: 25
# 			Dep. Text: into
# 			Relation Type: case
# 		Dep. ID: 26
# 			Dep. Text: 4
# 			Relation Type: nummod
# 		Dep. ID: 27
# 			Dep. Text: large
# 			Relation Type: amod
# ID: 25
# 	Head ID: 28
# 	Text: into
# 	Type: IN
# 	Dependent Words:
# ID: 26
# 	Head ID: 28
# 	Text: 4
# 	Type: CD
# 	Dependent Words:
# ID: 27
# 	Head ID: 28
# 	Text: large
# 	Type: JJ
# 	Dependent Words:
# ID: 29
# 	Head ID: 1
# 	Text: .
# 	Type: .
# 	Dependent Words:
# (S (VP (VB Run) (NP (DT a) (NN spatula)) (PP (IN around) (NP (NP (DT the) (NNS edges)) (PP (IN of) (NP (DT the) (NN skillet))))) (S (VP (TO to) (VP (VB loosen) (NP (DT the) (NN pizza)))))) (, ,) (RB then) (ADVP (RB carefully)) (VP (VP (VB slide) (NP (PRP it)) (PP (IN onto) (NP (DT a) (NN cutting) (NN board)))) (CC and) (VP (VB slice) (PP (IN into) (NP (CD 4) (JJ large) (NNS wedges))))) (. .))
# Run a spatula around the edges of the skillet to loosen the pizza, then carefully slide it onto a cutting board and slice into 4 large wedges.
# verb phrases: {0: ('Run', 'Run a spatula around the edges of the skillet to loosen the pizza'), 1: ('loosen', 'loosen the pizza'), 2: ('slide', 'slide it onto a cutting board'), 3: ('slice', 'slice into 4 large wedges')}
# prep phrases: {0: ('around', 'around the edges of the skillet', 'run'), 1: ('carefully', 'carefully', 'slide'), 2: ('onto', 'onto a cutting board', 'slide'), 3: ('into', 'into 4 large wedges', 'slice')}
# noun lists: {}
# nouns: [('a spatula', 'run'), ('the edges of the skillet', 'run'), ('the pizza', 'loosen'), ('it', 'slide'), ('a cutting board', 'slide'), ('4 large wedges', 'slice')]
# STARTING ZERO SHOT
# END OF ZERO SHOT
# {'a spatula': {'sequence': 'a spatula', 'labels': ['cooking utensil', 'spatula', 'appliance', 'measuring tool', 'ingredient', 'strainer', 'quantity', 'pan', 'chunks', 'slices', 'container', 'time', 'colinder', 'board', 'bowl', 'knife'], 'scores': [0.35698777437210083, 0.2976423501968384, 0.29317906498908997, 0.014637499116361141, 0.007947881706058979, 0.006195561029016972, 0.005563845857977867, 0.004306996241211891, 0.002378271659836173, 0.0020436632912606, 0.0019502686336636543, 0.0019447209779173136, 0.0016400659224018455, 0.0013867286033928394, 0.0012950663222000003, 0.0009002969018183649]}, 'the edges of the skillet': {'sequence': 'the edges of the skillet', 'labels': ['cooking utensil', 'pan', 'appliance', 'ingredient', 'chunks', 'slices', 'quantity', 'measuring tool', 'container', 'time', 'colinder', 'spatula', 'strainer', 'bowl', 'knife', 'board'], 'scores': [0.6621336936950684, 0.21311894059181213, 0.026467416435480118, 0.023436831310391426, 0.015622559003531933, 0.0114677669480443, 0.01049837190657854, 0.0061965035274624825, 0.0059422580525279045, 0.005630322266370058, 0.004441482946276665, 0.0040406156331300735, 0.003908447455614805, 0.0030367067083716393, 0.0020902850665152073, 0.001967787044122815]}, 'the pizza': {'sequence': 'the pizza', 'labels': ['ingredient', 'slices', 'quantity', 'cooking utensil', 'chunks', 'measuring tool', 'appliance', 'time', 'container', 'pan', 'bowl', 'strainer', 'board', 'colinder', 'spatula', 'knife'], 'scores': [0.35939300060272217, 0.32168060541152954, 0.10170410573482513, 0.06541423499584198, 0.03783849626779556, 0.020848747342824936, 0.01502319797873497, 0.014452297240495682, 0.011459164321422577, 0.010793396271765232, 0.00911101046949625, 0.008498462848365307, 0.007352030370384455, 0.006031605415046215, 0.005441563669592142, 0.004958147183060646]}, 'it': {'sequence': 'it', 'labels': ['time', 'board', 'pan', 'appliance', 'ingredient', 'measuring tool', 'chunks', 'cooking utensil', 'bowl', 'strainer', 'quantity', 'container', 'colinder', 'slices', 'spatula', 'knife'], 'scores': [0.14000600576400757, 0.10816868394613266, 0.10035629570484161, 0.0797603577375412, 0.07567432522773743, 0.06381553411483765, 0.05969777703285217, 0.055604252964258194, 0.051449004560709, 0.0483025498688221, 0.047438476234674454, 0.04300650954246521, 0.0391085147857666, 0.03866825997829437, 0.027319038286805153, 0.021624421700835228]}, 'a cutting board': {'sequence': 'a cutting board', 'labels': ['board', 'cooking utensil', 'appliance', 'measuring tool', 'slices', 'quantity', 'chunks', 'time', 'pan', 'ingredient', 'colinder', 'strainer', 'bowl', 'spatula', 'container', 'knife'], 'scores': [0.555014967918396, 0.2809656858444214, 0.11913607269525528, 0.007172098383307457, 0.006846847478300333, 0.006837316323071718, 0.0035636741667985916, 0.0029540075920522213, 0.0028077298775315285, 0.002480581868439913, 0.002470968523994088, 0.002443288452923298, 0.0021880725398659706, 0.0020292007829993963, 0.0017353419680148363, 0.001354267238639295]}, '4 large wedges': {'sequence': '4 large wedges', 'labels': ['quantity', 'slices', 'chunks', 'measuring tool', 'time', 'cooking utensil', 'ingredient', 'appliance', 'container', 'colinder', 'strainer', 'bowl', 'pan', 'board', 'knife', 'spatula'], 'scores': [0.47273963689804077, 0.18257172405719757, 0.15542159974575043, 0.02381269261240959, 0.022101281210780144, 0.02171395532786846, 0.021186454221606255, 0.018691865727305412, 0.01663569174706936, 0.014212053269147873, 0.011952119879424572, 0.009773571975529194, 0.008874522522091866, 0.008166736923158169, 0.007208590395748615, 0.004937531892210245]}}
# ID: 0
# 	Head ID: -1
# 	Text: ROOT
# 	Type: N/A
# 	Dependent Words:
# 		Dep. ID: 1
# 			Dep. Text: serve
# 			Relation Type: root
# ID: 1
# 	Head ID: 0
# 	Text: serve
# 	Type: VB
# 	Dependent Words:
# 		Dep. ID: 2
# 			Dep. Text: hot
# 			Relation Type: xcomp
# 		Dep. ID: 3
# 			Dep. Text: .
# 			Relation Type: punct
# ID: 2
# 	Head ID: 1
# 	Text: hot
# 	Type: JJ
# 	Dependent Words:
# ID: 3
# 	Head ID: 1
# 	Text: .
# 	Type: .
# 	Dependent Words:
# (S (VP (VB Serve) (ADJP (JJ hot))) (. .))
# Serve hot.
# verb phrases: {0: ('Serve', 'Serve hot')}
# prep phrases: {}
# noun lists: {}
# nouns: []
# STARTING ZERO SHOT
# END OF ZERO SHOT
# {}
# ID: 0
# 	Head ID: -1
# 	Text: ROOT
# 	Type: N/A
# 	Dependent Words:
# 		Dep. ID: 1
# 			Dep. Text: enjoy
# 			Relation Type: root
# ID: 1
# 	Head ID: 0
# 	Text: enjoy
# 	Type: VB
# 	Dependent Words:
# 		Dep. ID: 2
# 			Dep. Text: !
# 			Relation Type: punct
# ID: 2
# 	Head ID: 1
# 	Text: !
# 	Type: .
# 	Dependent Words:
# (INTJ (VB Enjoy) (. !))
# Enjoy!
# verb phrases: {}
# prep phrases: {}
# noun lists: {}
# nouns: []
# STARTING ZERO SHOT
# END OF ZERO SHOT
# {}

# %%
for step in allsteps:
    print(allsteps[step])
# Out:
# id: 1
# Original text: Preheat the oven to 375°F (190°C).
# 	Root action: Preheat
# 	All actions: {0: ('Preheat', 'Preheat the oven to 375 °F 190°C')}
# 	Ingredients: {('375 °F 190°C', 'preheat', 'quantity'): ('375 °F 190°C', 'preheat')}
# 	Tools: {'the oven': ('the oven', 'preheat', 'appliance')}
# 	Details: {0: ('to', 'to 375 °F 190°C', 'preheat')}
# id: 2
# Original text: On a lightly floured surface, roll the pizza dough into a rope 36 inches (1 m) long and ½-inch (13 mm) thick.
# 	Root action: roll
# 	All actions: {0: ('roll', 'roll the pizza dough into a rope 36 inches 1 m long and ½-inch 13 mm thick')}
# 	Ingredients: {('a lightly floured surface', 'roll', 'quantity'): ('a lightly floured surface', 'roll'), ('the pizza dough', 'roll', 'ingredient'): ('the pizza dough', 'roll'), ('a rope 36 inches 1 m long and ½-inch 13 mm', 'roll', 'quantity'): ('a rope 36 inches 1 m long and ½-inch 13 mm', 'roll')}
# 	Tools: {}
# 	Details: {0: ('On', 'On a lightly floured surface', 'roll'), 1: ('into', 'into a rope 36 inches 1 m long and ½-inch 13 mm thick', 'roll')}
# id: 3
# Original text: Arrange the rope around the outer edge of a 12-inch (30.5 cm) nonstick ovenproof skillet and pinch together the ends to form a ring.
# 	Root action: Arrange
# 	All actions: {0: ('Arrange', 'Arrange the rope around the outer edge of a 12- inch 30.5 cm nonstick ovenproof skillet'), 1: ('pinch', 'pinch together the ends to form a ring'), 2: ('form', 'form a ring')}
# 	Ingredients: {('the rope', 'arrange', 'quantity'): ('the rope', 'arrange'), ('the ends', 'pinch', 'chunks'): ('the ends', 'pinch')}
# 	Tools: {'the outer edge of a 12- inch 30.5 cm nonstick ovenproof skillet': ('the outer edge of a 12- inch 30.5 cm nonstick ovenproof skillet', 'arrange', 'cooking utensil'), 'a ring': ('a ring', 'pinch', 'appliance')}
# 	Details: {0: ('around', 'around the outer edge of a 12- inch 30.5 cm nonstick ovenproof skillet', 'arrange'), 1: ('together', 'together', 'pinch')}
# id: 4
# Original text: Cover with a kitchen towel and let stand until the dough is slightly puffed, about 30 minutes.
# 	Root action: Cover
# 	All actions: {0: ('Cover', 'Cover with a kitchen towel'), 1: ('stand', 'stand')}
# 	Ingredients: {('a kitchen towel', 'cover', 'quantity'): ('a kitchen towel', 'cover'), ('the dough', 'puffed', 'ingredient'): ('the dough', 'puffed')}
# 	Tools: {}
# 	Details: {0: ('with', 'with a kitchen towel', 'cover'), 1: ('until', 'until the dough is slightly puffed', 'puffed')}
# id: 5
# Original text: Drizzle 1 tablespoon of olive oil into the center of the skillet.
# 	Root action: Drizzle
# 	All actions: {}
# 	Ingredients: {('Drizzle 1 tablespoon', None, 'quantity'): ('Drizzle 1 tablespoon', None), ('olive oil', None, 'ingredient'): ('olive oil', None)}
# 	Tools: {'the center of the skillet': ('the center of the skillet', None, 'cooking utensil')}
# 	Details: {0: ('of', 'of olive oil', None), 1: ('into', 'into the center of the skillet', None)}
# id: 6
# Original text: Lightly beat the egg whites, then pour into the center of the skillet.
# 	Root action: beat
# 	All actions: {0: ('beat', 'beat the egg whites'), 1: ('pour', 'pour into the center of the skillet')}
# 	Ingredients: {('the egg whites', 'beat', 'ingredient'): ('the egg whites', 'beat')}
# 	Tools: {'the center of the skillet': ('the center of the skillet', 'pour', 'cooking utensil')}
# 	Details: {0: ('Lightly', 'Lightly', 'beat'), 1: ('then', 'then', 'pour'), 2: ('into', 'into the center of the skillet', 'pour')}
# id: 7
# Original text: Spoon the pizza sauce over the egg whites, then top with the spinach and mozzarella.
# 	Root action: Spoon
# 	All actions: {0: ('Spoon', 'Spoon the pizza sauce over the egg whites'), 1: ('top', 'top with the spinach and mozzarella')}
# 	Ingredients: {('the pizza sauce', 'spoon', 'ingredient'): ('the pizza sauce', 'spoon'), ('the egg whites', 'spoon', 'ingredient'): ('the egg whites', 'spoon'), ('spinach', 'top', 'ingredient'): ('spinach', 'top', 14), ('mozzarella', 'top', 'ingredient'): ('mozzarella', 'top', 16)}
# 	Tools: {}
# 	Details: {0: ('over', 'over the egg whites', 'spoon'), 1: ('then', 'then', 'top'), 2: ('with', 'with the spinach and mozzarella', 'top')}
# id: 8
# Original text: Sprinkle the oregano, red pepper flakes, salt, and pepper over everything.
# 	Root action: Sprinkle
# 	All actions: {0: ('Sprinkle', 'Sprinkle the oregano, red pepper flakes, salt, and pepper over everything')}
# 	Ingredients: {('the oregano', 'sprinkle', 'ingredient'): ('the oregano', 'sprinkle'), ('red pepper flakes', 'sprinkle', 'ingredient'): ('red pepper flakes', 'sprinkle'), ('salt', 'sprinkle', 'ingredient'): ('salt', 'sprinkle'), ('everything', 'sprinkle', 'quantity'): ('everything', 'sprinkle')}
# 	Tools: {}
# 	Details: {0: ('over', 'over everything', 'sprinkle')}
# id: 9
# Original text: Brush some of the remaining tablespoon olive oil over the dough ring, then drizzle any remaining olive oil over the center.
# 	Root action: Brush
# 	All actions: {0: ('Brush', 'Brush some of the remaining tablespoon olive oil over the dough ring'), 1: ('drizzle', 'drizzle any remaining olive oil over the center')}
# 	Ingredients: {('some of the remaining tablespoon olive oil over the dough ring', 'brush', 'ingredient'): ('some of the remaining tablespoon olive oil over the dough ring', 'brush'), ('any remaining olive oil', 'drizzle', 'ingredient'): ('any remaining olive oil', 'drizzle')}
# 	Tools: {'the center': ('the center', 'drizzle', 'colinder')}
# 	Details: {0: ('of', 'of the remaining tablespoon olive oil over the dough ring', 'brush'), 1: ('then', 'then', 'drizzle'), 2: ('over', 'over the center', 'drizzle')}
# id: 10
# Original text: Bake the pizza until the dough is golden brown, the cheese has melted, and the egg whites are cooked through, 20–25 minutes.
# 	Root action: Bake
# 	All actions: {0: ('Bake', 'Bake the pizza until the dough is golden brown')}
# 	Ingredients: {('the pizza', 'bake', 'ingredient'): ('the pizza', 'bake'), ('the dough', 'bake', 'ingredient'): ('the dough', 'bake'), ('the cheese', 'melted', 'ingredient'): ('the cheese', 'melted'), ('the egg whites', 'cooked', 'ingredient'): ('the egg whites', 'cooked')}
# 	Tools: {}
# 	Details: {0: ('until', 'until the dough is golden brown', 'bake'), 1: ('through', 'through', 'cooked')}
# id: 11
# Original text: Remove the skillet from the oven and arrange the egg yolks on top of the pizza.
# 	Root action: Remove
# 	All actions: {0: ('Remove', 'Remove the skillet from the oven'), 1: ('arrange', 'arrange the egg yolks on top of the pizza')}
# 	Ingredients: {('the egg yolks', 'arrange', 'ingredient'): ('the egg yolks', 'arrange'), ('top of the pizza', 'arrange', 'ingredient'): ('top of the pizza', 'arrange')}
# 	Tools: {'the skillet': ('the skillet', 'remove', 'cooking utensil'), 'the oven': ('the oven', 'remove', 'appliance')}
# 	Details: {0: ('from', 'from the oven', 'remove'), 1: ('on', 'on top of the pizza', 'arrange')}
# id: 12
# Original text: Return it to the oven and bake until the yolks are warmed through but still soft, about 5 minutes more (a thin film will develop on top of the yolks).
# 	Root action: Return
# 	All actions: {0: ('Return', 'Return it to the oven and bake until the yolks are warmed through but still soft'), 1: ('develop', 'develop on top of the yolks')}
# 	Ingredients: {('the yolks', 'warmed', 'ingredient'): ('the yolks', 'warmed'), ('top of the yolks', 'develop', 'ingredient'): ('top of the yolks', 'develop')}
# 	Tools: {'oven': ('oven', 'return', 'appliance'), 'a thin film': ('a thin film', 'develop', 'pan')}
# 	Details: {0: ('to', 'to the oven and bake', 'return'), 1: ('until', 'until the yolks are warmed through but still soft', 'warmed'), 2: ('still', 'still', 'warmed'), 3: ('on', 'on top of the yolks', 'return')}
# id: 13
# Original text: Transfer the skillet to a wire rack.
# 	Root action: Transfer
# 	All actions: {0: ('Transfer', 'Transfer the skillet to a wire rack')}
# 	Ingredients: {}
# 	Tools: {'the skillet': ('the skillet', 'transfer', 'cooking utensil'), 'a wire rack': ('a wire rack', 'transfer', 'appliance')}
# 	Details: {0: ('to', 'to a wire rack', 'transfer')}
# id: 14
# Original text: Sprinkle evenly with the Parmesan and let cool for 1 minute.
# 	Root action: Sprinkle
# 	All actions: {0: ('Sprinkle', 'Sprinkle evenly with the Parmesan')}
# 	Ingredients: {('the Parmesan', 'sprinkle', 'ingredient'): ('the Parmesan', 'sprinkle')}
# 	Tools: {}
# 	Details: {0: ('evenly', 'evenly', 'sprinkle'), 1: ('with', 'with the Parmesan', 'sprinkle'), 2: ('for', 'for 1 minute', 'let')}
# id: 15
# Original text: Run a spatula around the edges of the skillet to loosen the pizza, then carefully slide it onto a cutting board and slice into 4 large wedges.
# 	Root action: Run
# 	All actions: {0: ('Run', 'Run a spatula around the edges of the skillet to loosen the pizza'), 1: ('loosen', 'loosen the pizza'), 2: ('slide', 'slide it onto a cutting board'), 3: ('slice', 'slice into 4 large wedges')}
# 	Ingredients: {('the pizza', 'loosen', 'ingredient'): ('the pizza', 'loosen'), ('4 large wedges', 'slice', 'quantity'): ('4 large wedges', 'slice')}
# 	Tools: {'a spatula': ('a spatula', 'run', 'cooking utensil'), 'the edges of the skillet': ('the edges of the skillet', 'run', 'cooking utensil'), 'a cutting board': ('a cutting board', 'slide', 'board')}
# 	Details: {0: ('around', 'around the edges of the skillet', 'run'), 1: ('carefully', 'carefully', 'slide'), 2: ('onto', 'onto a cutting board', 'slide'), 3: ('into', 'into 4 large wedges', 'slice')}
# id: 16
# Original text: Serve hot.
# 	Root action: Serve
# 	All actions: {0: ('Serve', 'Serve hot')}
# 	Ingredients: {}
# 	Tools: {}
# 	Details: {}
# id: 17
# Original text: Enjoy!
# 	Root action: Enjoy
# 	All actions: {}
# 	Ingredients: {}
# 	Tools: {}
# 	Details: {}

# %%
test_text2 = "Bring a large pot of salted water to a boil. Add the linguine and cook as the label directs. Reserve 1 cup cooking water, then drain. Meanwhile, season the shrimp with salt. Heat the olive oil in a large skillet over medium-high heat. Add the garlic and red pepper flakes and cook until the garlic is just golden, 30 seconds to 1 minute. Add the shrimp and cook, stirring occasionally, until pink and just cooked through, 1 to 2 minutes per side. Remove the shrimp to a plate. Add the wine and lemon juice to the skillet and simmer until slightly reduced, 2 minutes.  Return the shrimp and any juices from the plate to the skillet along with the linguine, butter and 1/2 cup of the reserved cooking water. Continue to cook, tossing, until the butter is melted and the shrimp is hot, about 2 minutes, adding more of the reserved cooking water as needed. Season with salt; stir in the parsley. Serve with lemon wedges."
allsteps2 = doParsing(test_text2, [])
# Out:
# ID: 0
# 	Head ID: -1
# 	Text: ROOT
# 	Type: N/A
# 	Dependent Words:
# 		Dep. ID: 1
# 			Dep. Text: bring
# 			Relation Type: root
# ID: 1
# 	Head ID: 0
# 	Text: bring
# 	Type: VB
# 	Dependent Words:
# 		Dep. ID: 4
# 			Dep. Text: pot
# 			Relation Type: obj
# 		Dep. ID: 10
# 			Dep. Text: boil
# 			Relation Type: obl
# 		Dep. ID: 11
# 			Dep. Text: .
# 			Relation Type: punct
# ID: 4
# 	Head ID: 1
# 	Text: pot
# 	Type: NN
# 	Dependent Words:
# 		Dep. ID: 2
# 			Dep. Text: a
# 			Relation Type: det
# 		Dep. ID: 3
# 			Dep. Text: large
# 			Relation Type: amod
# 		Dep. ID: 7
# 			Dep. Text: water
# 			Relation Type: nmod
# ID: 2
# 	Head ID: 4
# 	Text: a
# 	Type: DT
# 	Dependent Words:
# ID: 3
# 	Head ID: 4
# 	Text: large
# 	Type: JJ
# 	Dependent Words:
# ID: 7
# 	Head ID: 4
# 	Text: water
# 	Type: NN
# 	Dependent Words:
# 		Dep. ID: 5
# 			Dep. Text: of
# 			Relation Type: case
# 		Dep. ID: 6
# 			Dep. Text: salted
# 			Relation Type: amod
# ID: 5
# 	Head ID: 7
# 	Text: of
# 	Type: IN
# 	Dependent Words:
# ID: 6
# 	Head ID: 7
# 	Text: salted
# 	Type: VBN
# 	Dependent Words:
# ID: 10
# 	Head ID: 1
# 	Text: boil
# 	Type: NN
# 	Dependent Words:
# 		Dep. ID: 8
# 			Dep. Text: to
# 			Relation Type: case
# 		Dep. ID: 9
# 			Dep. Text: a
# 			Relation Type: det
# ID: 8
# 	Head ID: 10
# 	Text: to
# 	Type: IN
# 	Dependent Words:
# ID: 9
# 	Head ID: 10
# 	Text: a
# 	Type: DT
# 	Dependent Words:
# ID: 11
# 	Head ID: 1
# 	Text: .
# 	Type: .
# 	Dependent Words:
# (S (VP (VB Bring) (NP (NP (DT a) (JJ large) (NN pot)) (PP (IN of) (NP (VBN salted) (NN water)))) (PP (IN to) (NP (DT a) (NN boil)))) (. .))
# Bring a large pot of salted water to a boil.
# verb phrases: {0: ('Bring', 'Bring a large pot of salted water to a boil')}
# prep phrases: {0: ('of', 'of salted water', 'bring'), 1: ('to', 'to a boil', 'bring')}
# noun lists: {}
# nouns: [('a large pot of salted water', 'bring'), ('a boil', 'bring')]
# STARTING ZERO SHOT
# END OF ZERO SHOT
# {'a large pot of salted water': {'sequence': 'a large pot of salted water', 'labels': ['quantity', 'ingredient', 'container', 'appliance', 'cooking utensil', 'time', 'strainer', 'chunks', 'colinder', 'pan', 'measuring tool', 'bowl', 'spatula', 'board', 'slices', 'knife'], 'scores': [0.30993056297302246, 0.27166035771369934, 0.17501424252986908, 0.0668003037571907, 0.03997534513473511, 0.02165275812149048, 0.018369480967521667, 0.015613730996847153, 0.014428732916712761, 0.014335460029542446, 0.012272029183804989, 0.011036044918000698, 0.01004593726247549, 0.006672549061477184, 0.0064249285496771336, 0.00576752657070756]}, 'a boil': {'sequence': 'a boil', 'labels': ['appliance', 'ingredient', 'quantity', 'cooking utensil', 'colinder', 'chunks', 'pan', 'board', 'time', 'strainer', 'measuring tool', 'container', 'bowl', 'spatula', 'slices', 'knife'], 'scores': [0.24619446694850922, 0.21540507674217224, 0.15944528579711914, 0.09472710639238358, 0.08094845712184906, 0.057261958718299866, 0.04403459653258324, 0.02623812109231949, 0.015450533479452133, 0.013967764563858509, 0.013673595152795315, 0.0136708440259099, 0.008088022470474243, 0.004045519512146711, 0.003966826479882002, 0.0028817730490118265]}}
# ID: 0
# 	Head ID: -1
# 	Text: ROOT
# 	Type: N/A
# 	Dependent Words:
# 		Dep. ID: 1
# 			Dep. Text: add
# 			Relation Type: root
# ID: 1
# 	Head ID: 0
# 	Text: add
# 	Type: VB
# 	Dependent Words:
# 		Dep. ID: 3
# 			Dep. Text: linguine
# 			Relation Type: obj
# 		Dep. ID: 5
# 			Dep. Text: cook
# 			Relation Type: conj
# 		Dep. ID: 10
# 			Dep. Text: .
# 			Relation Type: punct
# ID: 3
# 	Head ID: 1
# 	Text: linguine
# 	Type: NN
# 	Dependent Words:
# 		Dep. ID: 2
# 			Dep. Text: the
# 			Relation Type: det
# ID: 2
# 	Head ID: 3
# 	Text: the
# 	Type: DT
# 	Dependent Words:
# ID: 5
# 	Head ID: 1
# 	Text: cook
# 	Type: VB
# 	Dependent Words:
# 		Dep. ID: 4
# 			Dep. Text: and
# 			Relation Type: cc
# 		Dep. ID: 9
# 			Dep. Text: directs
# 			Relation Type: advcl
# ID: 4
# 	Head ID: 5
# 	Text: and
# 	Type: CC
# 	Dependent Words:
# ID: 9
# 	Head ID: 5
# 	Text: directs
# 	Type: VBZ
# 	Dependent Words:
# 		Dep. ID: 6
# 			Dep. Text: as
# 			Relation Type: mark
# 		Dep. ID: 8
# 			Dep. Text: label
# 			Relation Type: nsubj
# ID: 6
# 	Head ID: 9
# 	Text: as
# 	Type: IN
# 	Dependent Words:
# ID: 8
# 	Head ID: 9
# 	Text: label
# 	Type: NN
# 	Dependent Words:
# 		Dep. ID: 7
# 			Dep. Text: the
# 			Relation Type: det
# ID: 7
# 	Head ID: 8
# 	Text: the
# 	Type: DT
# 	Dependent Words:
# ID: 10
# 	Head ID: 1
# 	Text: .
# 	Type: .
# 	Dependent Words:
# (S (VP (VB Add) (NP (DT the) (NN linguine) (CC and) (VB cook)) (SBAR (IN as) (S (NP (DT the) (NN label)) (VP (VBZ directs))))) (. .))
# Add the linguine and cook as the label directs.
# ['linguine']
# verb phrases: {0: ('Add', 'Add the linguine and cook as the label directs')}
# prep phrases: {0: ('as', 'as the label directs', 'directs')}
# noun lists: {0: (<ListType.AND: 0>, ['linguine'], 'add')}
# nouns: [('linguine', 'add', 3), ('the label', 'directs')]
# STARTING ZERO SHOT
# END OF ZERO SHOT
# {'linguine': {'sequence': 'linguine', 'labels': ['ingredient', 'quantity', 'board', 'time', 'chunks', 'pan', 'measuring tool', 'strainer', 'appliance', 'container', 'cooking utensil', 'colinder', 'bowl', 'slices', 'spatula', 'knife'], 'scores': [0.383821964263916, 0.07583790272474289, 0.06901561468839645, 0.06216080114245415, 0.06101150065660477, 0.05169309675693512, 0.045446302741765976, 0.04261612892150879, 0.0357491597533226, 0.03421151638031006, 0.028639061376452446, 0.027367299422621727, 0.02696230635046959, 0.025690287351608276, 0.016873033717274666, 0.012904061935842037]}, 'the label': {'sequence': 'the label', 'labels': ['pan', 'board', 'appliance', 'time', 'chunks', 'container', 'quantity', 'cooking utensil', 'ingredient', 'strainer', 'colinder', 'bowl', 'measuring tool', 'slices', 'spatula', 'knife'], 'scores': [0.11203701794147491, 0.09296748787164688, 0.08444548398256302, 0.07913507521152496, 0.07769493758678436, 0.07526106387376785, 0.06890998780727386, 0.06269019097089767, 0.06178469955921173, 0.0518999844789505, 0.05116022750735283, 0.050505928695201874, 0.03863789141178131, 0.031877551227808, 0.031813085079193115, 0.029179347679018974]}}
# ID: 0
# 	Head ID: -1
# 	Text: ROOT
# 	Type: N/A
# 	Dependent Words:
# 		Dep. ID: 5
# 			Dep. Text: water
# 			Relation Type: root
# ID: 3
# 	Head ID: 5
# 	Text: cup
# 	Type: NN
# 	Dependent Words:
# 		Dep. ID: 1
# 			Dep. Text: reserve
# 			Relation Type: compound
# 		Dep. ID: 2
# 			Dep. Text: 1
# 			Relation Type: nummod
# ID: 1
# 	Head ID: 3
# 	Text: reserve
# 	Type: NN
# 	Dependent Words:
# ID: 2
# 	Head ID: 3
# 	Text: 1
# 	Type: CD
# 	Dependent Words:
# ID: 5
# 	Head ID: 0
# 	Text: water
# 	Type: NN
# 	Dependent Words:
# 		Dep. ID: 3
# 			Dep. Text: cup
# 			Relation Type: nmod:npmod
# 		Dep. ID: 4
# 			Dep. Text: cooking
# 			Relation Type: compound
# 		Dep. ID: 8
# 			Dep. Text: drain
# 			Relation Type: parataxis
# ID: 4
# 	Head ID: 5
# 	Text: cooking
# 	Type: NN
# 	Dependent Words:
# ID: 8
# 	Head ID: 5
# 	Text: drain
# 	Type: VB
# 	Dependent Words:
# 		Dep. ID: 6
# 			Dep. Text: ,
# 			Relation Type: punct
# 		Dep. ID: 7
# 			Dep. Text: then
# 			Relation Type: advmod
# 		Dep. ID: 9
# 			Dep. Text: .
# 			Relation Type: punct
# ID: 6
# 	Head ID: 8
# 	Text: ,
# 	Type: ,
# 	Dependent Words:
# ID: 7
# 	Head ID: 8
# 	Text: then
# 	Type: RB
# 	Dependent Words:
# ID: 9
# 	Head ID: 8
# 	Text: .
# 	Type: .
# 	Dependent Words:
# (NP (NP (NML (NN Reserve) (CD 1)) (NN cup) (NN cooking) (NN water)) (, ,) (ADVP (RB then)) (VP (VB drain)) (. .))
# Reserve 1 cup cooking water, then drain.
# ['Reserve 1 cup cooking water']
# verb phrases: {0: ('drain', 'drain')}
# prep phrases: {0: ('then', 'then', 'drain')}
# noun lists: {0: (<ListType.UNSPECIFIED: 2>, ['Reserve 1 cup cooking water'], None)}
# nouns: [('Reserve 1 cup cooking water', None)]
# STARTING ZERO SHOT
# END OF ZERO SHOT
# {'reserve 1 cup cooking water': {'sequence': 'reserve 1 cup cooking water', 'labels': ['quantity', 'container', 'ingredient', 'measuring tool', 'time', 'appliance', 'cooking utensil', 'pan', 'bowl', 'strainer', 'colinder', 'board', 'chunks', 'spatula', 'knife', 'slices'], 'scores': [0.47262778878211975, 0.10999889671802521, 0.09165652841329575, 0.06596332788467407, 0.0566745288670063, 0.03315522521734238, 0.032977305352687836, 0.025160066783428192, 0.024619074538350105, 0.024065736681222916, 0.017756687477231026, 0.0175302866846323, 0.009745617397129536, 0.0077931806445121765, 0.005646024830639362, 0.004629694391041994]}}
# ID: 0
# 	Head ID: -1
# 	Text: ROOT
# 	Type: N/A
# 	Dependent Words:
# 		Dep. ID: 3
# 			Dep. Text: season
# 			Relation Type: root
# ID: 3
# 	Head ID: 0
# 	Text: season
# 	Type: NN
# 	Dependent Words:
# 		Dep. ID: 1
# 			Dep. Text: meanwhile
# 			Relation Type: advmod
# 		Dep. ID: 2
# 			Dep. Text: ,
# 			Relation Type: punct
# 		Dep. ID: 5
# 			Dep. Text: shrimp
# 			Relation Type: appos
# 		Dep. ID: 8
# 			Dep. Text: .
# 			Relation Type: punct
# ID: 1
# 	Head ID: 3
# 	Text: meanwhile
# 	Type: RB
# 	Dependent Words:
# ID: 2
# 	Head ID: 3
# 	Text: ,
# 	Type: ,
# 	Dependent Words:
# ID: 5
# 	Head ID: 3
# 	Text: shrimp
# 	Type: NN
# 	Dependent Words:
# 		Dep. ID: 4
# 			Dep. Text: the
# 			Relation Type: det
# 		Dep. ID: 7
# 			Dep. Text: salt
# 			Relation Type: nmod
# ID: 4
# 	Head ID: 5
# 	Text: the
# 	Type: DT
# 	Dependent Words:
# ID: 7
# 	Head ID: 5
# 	Text: salt
# 	Type: NN
# 	Dependent Words:
# 		Dep. ID: 6
# 			Dep. Text: with
# 			Relation Type: case
# ID: 6
# 	Head ID: 7
# 	Text: with
# 	Type: IN
# 	Dependent Words:
# ID: 8
# 	Head ID: 3
# 	Text: .
# 	Type: .
# 	Dependent Words:
# (S (ADVP (RB Meanwhile)) (, ,) (NP (NP (NN season)) (NP (DT the) (NN shrimp)) (PP (IN with) (NP (NN salt)))) (. .))
# Meanwhile, season the shrimp with salt.
# verb phrases: {}
# prep phrases: {0: ('Meanwhile', 'Meanwhile', None), 1: ('with', 'with salt', None)}
# noun lists: {}
# nouns: [('season the shrimp with salt', None)]
# STARTING ZERO SHOT
# END OF ZERO SHOT
# {'season the shrimp with salt': {'sequence': 'season the shrimp with salt', 'labels': ['ingredient', 'quantity', 'time', 'cooking utensil', 'container', 'board', 'bowl', 'appliance', 'pan', 'strainer', 'measuring tool', 'colinder', 'slices', 'chunks', 'spatula', 'knife'], 'scores': [0.5854472517967224, 0.11550247669219971, 0.04223440960049629, 0.03552503138780594, 0.029229063540697098, 0.02886662259697914, 0.028107119724154472, 0.026993609964847565, 0.02466714382171631, 0.02182638831436634, 0.01491832546889782, 0.013204434886574745, 0.01250448077917099, 0.010651618242263794, 0.006630951538681984, 0.0036910632625222206]}}
# ID: 0
# 	Head ID: -1
# 	Text: ROOT
# 	Type: N/A
# 	Dependent Words:
# 		Dep. ID: 1
# 			Dep. Text: heat
# 			Relation Type: root
# ID: 1
# 	Head ID: 0
# 	Text: heat
# 	Type: VB
# 	Dependent Words:
# 		Dep. ID: 4
# 			Dep. Text: oil
# 			Relation Type: obj
# 		Dep. ID: 8
# 			Dep. Text: skillet
# 			Relation Type: obl
# 		Dep. ID: 13
# 			Dep. Text: heat
# 			Relation Type: obl
# 		Dep. ID: 14
# 			Dep. Text: .
# 			Relation Type: punct
# ID: 4
# 	Head ID: 1
# 	Text: oil
# 	Type: NN
# 	Dependent Words:
# 		Dep. ID: 2
# 			Dep. Text: the
# 			Relation Type: det
# 		Dep. ID: 3
# 			Dep. Text: olive
# 			Relation Type: compound
# ID: 2
# 	Head ID: 4
# 	Text: the
# 	Type: DT
# 	Dependent Words:
# ID: 3
# 	Head ID: 4
# 	Text: olive
# 	Type: NN
# 	Dependent Words:
# ID: 8
# 	Head ID: 1
# 	Text: skillet
# 	Type: NN
# 	Dependent Words:
# 		Dep. ID: 5
# 			Dep. Text: in
# 			Relation Type: case
# 		Dep. ID: 6
# 			Dep. Text: a
# 			Relation Type: det
# 		Dep. ID: 7
# 			Dep. Text: large
# 			Relation Type: amod
# ID: 5
# 	Head ID: 8
# 	Text: in
# 	Type: IN
# 	Dependent Words:
# ID: 6
# 	Head ID: 8
# 	Text: a
# 	Type: DT
# 	Dependent Words:
# ID: 7
# 	Head ID: 8
# 	Text: large
# 	Type: JJ
# 	Dependent Words:
# ID: 13
# 	Head ID: 1
# 	Text: heat
# 	Type: NN
# 	Dependent Words:
# 		Dep. ID: 9
# 			Dep. Text: over
# 			Relation Type: case
# 		Dep. ID: 12
# 			Dep. Text: high
# 			Relation Type: amod
# ID: 9
# 	Head ID: 13
# 	Text: over
# 	Type: IN
# 	Dependent Words:
# ID: 12
# 	Head ID: 13
# 	Text: high
# 	Type: JJ
# 	Dependent Words:
# 		Dep. ID: 10
# 			Dep. Text: medium
# 			Relation Type: amod
# ID: 10
# 	Head ID: 12
# 	Text: medium
# 	Type: JJ
# 	Dependent Words:
# 		Dep. ID: 11
# 			Dep. Text: -
# 			Relation Type: punct
# ID: 11
# 	Head ID: 10
# 	Text: -
# 	Type: HYPH
# 	Dependent Words:
# ID: 14
# 	Head ID: 1
# 	Text: .
# 	Type: .
# 	Dependent Words:
# (S (VP (VB Heat) (NP (DT the) (NN olive) (NN oil)) (PP (IN in) (NP (NP (DT a) (JJ large) (NN skillet)) (PP (IN over) (NP (ADJP (JJ medium) (HYPH -) (JJ high)) (NN heat)))))) (. .))
# Heat the olive oil in a large skillet over medium-high heat.
# verb phrases: {0: ('Heat', 'Heat the olive oil in a large skillet over medium- high heat')}
# prep phrases: {0: ('in', 'in a large skillet over medium- high heat', 'heat')}
# noun lists: {}
# nouns: [('the olive oil', 'heat'), ('a large skillet over medium- high heat', 'heat')]
# STARTING ZERO SHOT
# END OF ZERO SHOT
# {'the olive oil': {'sequence': 'the olive oil', 'labels': ['ingredient', 'quantity', 'board', 'chunks', 'container', 'cooking utensil', 'strainer', 'measuring tool', 'pan', 'time', 'slices', 'bowl', 'appliance', 'colinder', 'spatula', 'knife'], 'scores': [0.834115207195282, 0.03906158730387688, 0.014711772091686726, 0.013350795954465866, 0.012897788546979427, 0.011957919225096703, 0.01168808713555336, 0.010379024781286716, 0.009989500977098942, 0.009404853917658329, 0.007531360257416964, 0.0067963870242238045, 0.006269162520766258, 0.004466090351343155, 0.004410371650010347, 0.0029700302984565496]}, 'a large skillet over medium- high heat': {'sequence': 'a large skillet over medium- high heat', 'labels': ['pan', 'cooking utensil', 'appliance', 'quantity', 'ingredient', 'time', 'colinder', 'chunks', 'container', 'slices', 'spatula', 'strainer', 'bowl', 'board', 'measuring tool', 'knife'], 'scores': [0.46642839908599854, 0.40018391609191895, 0.06744629889726639, 0.015745146200060844, 0.01362775918096304, 0.005569090135395527, 0.004204737953841686, 0.004077875521034002, 0.0038247895427048206, 0.00376055552624166, 0.003405687864869833, 0.003399805398657918, 0.002618322614580393, 0.0020520510151982307, 0.0018547079525887966, 0.0018008716870099306]}}
# ID: 0
# 	Head ID: -1
# 	Text: ROOT
# 	Type: N/A
# 	Dependent Words:
# 		Dep. ID: 1
# 			Dep. Text: add
# 			Relation Type: root
# ID: 1
# 	Head ID: 0
# 	Text: add
# 	Type: VB
# 	Dependent Words:
# 		Dep. ID: 3
# 			Dep. Text: garlic
# 			Relation Type: obj
# 		Dep. ID: 9
# 			Dep. Text: cook
# 			Relation Type: conj
# 		Dep. ID: 22
# 			Dep. Text: .
# 			Relation Type: punct
# ID: 3
# 	Head ID: 1
# 	Text: garlic
# 	Type: NN
# 	Dependent Words:
# 		Dep. ID: 2
# 			Dep. Text: the
# 			Relation Type: det
# 		Dep. ID: 7
# 			Dep. Text: flakes
# 			Relation Type: conj
# ID: 2
# 	Head ID: 3
# 	Text: the
# 	Type: DT
# 	Dependent Words:
# ID: 7
# 	Head ID: 3
# 	Text: flakes
# 	Type: NNS
# 	Dependent Words:
# 		Dep. ID: 4
# 			Dep. Text: and
# 			Relation Type: cc
# 		Dep. ID: 6
# 			Dep. Text: pepper
# 			Relation Type: compound
# ID: 4
# 	Head ID: 7
# 	Text: and
# 	Type: CC
# 	Dependent Words:
# ID: 6
# 	Head ID: 7
# 	Text: pepper
# 	Type: NN
# 	Dependent Words:
# 		Dep. ID: 5
# 			Dep. Text: red
# 			Relation Type: amod
# ID: 5
# 	Head ID: 6
# 	Text: red
# 	Type: JJ
# 	Dependent Words:
# ID: 9
# 	Head ID: 1
# 	Text: cook
# 	Type: VB
# 	Dependent Words:
# 		Dep. ID: 8
# 			Dep. Text: and
# 			Relation Type: cc
# 		Dep. ID: 15
# 			Dep. Text: golden
# 			Relation Type: advcl
# ID: 8
# 	Head ID: 9
# 	Text: and
# 	Type: CC
# 	Dependent Words:
# ID: 15
# 	Head ID: 9
# 	Text: golden
# 	Type: JJ
# 	Dependent Words:
# 		Dep. ID: 10
# 			Dep. Text: until
# 			Relation Type: mark
# 		Dep. ID: 12
# 			Dep. Text: garlic
# 			Relation Type: nsubj
# 		Dep. ID: 13
# 			Dep. Text: is
# 			Relation Type: cop
# 		Dep. ID: 14
# 			Dep. Text: just
# 			Relation Type: advmod
# 		Dep. ID: 18
# 			Dep. Text: seconds
# 			Relation Type: conj
# 		Dep. ID: 21
# 			Dep. Text: minute
# 			Relation Type: obl
# ID: 10
# 	Head ID: 15
# 	Text: until
# 	Type: IN
# 	Dependent Words:
# ID: 12
# 	Head ID: 15
# 	Text: garlic
# 	Type: NN
# 	Dependent Words:
# 		Dep. ID: 11
# 			Dep. Text: the
# 			Relation Type: det
# ID: 11
# 	Head ID: 12
# 	Text: the
# 	Type: DT
# 	Dependent Words:
# ID: 13
# 	Head ID: 15
# 	Text: is
# 	Type: VBZ
# 	Dependent Words:
# ID: 14
# 	Head ID: 15
# 	Text: just
# 	Type: RB
# 	Dependent Words:
# ID: 18
# 	Head ID: 15
# 	Text: seconds
# 	Type: NNS
# 	Dependent Words:
# 		Dep. ID: 16
# 			Dep. Text: ,
# 			Relation Type: punct
# 		Dep. ID: 17
# 			Dep. Text: 30
# 			Relation Type: nummod
# ID: 16
# 	Head ID: 18
# 	Text: ,
# 	Type: ,
# 	Dependent Words:
# ID: 17
# 	Head ID: 18
# 	Text: 30
# 	Type: CD
# 	Dependent Words:
# ID: 21
# 	Head ID: 15
# 	Text: minute
# 	Type: NN
# 	Dependent Words:
# 		Dep. ID: 19
# 			Dep. Text: to
# 			Relation Type: case
# 		Dep. ID: 20
# 			Dep. Text: 1
# 			Relation Type: nummod
# ID: 19
# 	Head ID: 21
# 	Text: to
# 	Type: IN
# 	Dependent Words:
# ID: 20
# 	Head ID: 21
# 	Text: 1
# 	Type: CD
# 	Dependent Words:
# ID: 22
# 	Head ID: 1
# 	Text: .
# 	Type: .
# 	Dependent Words:
# (S (S (VP (VP (VB Add) (NP (DT the) (NML (NML (NN garlic)) (CC and) (NML (JJ red) (NN pepper))) (NNS flakes))) (CC and) (VP (VB cook) (SBAR (IN until) (S (NP (DT the) (NN garlic)) (VP (VBZ is) (ADJP (RB just) (JJ golden)))))))) (, ,) (NP (NP (CD 30) (NNS seconds)) (PP (IN to) (NP (CD 1) (NN minute)))) (. .))
# Add the garlic and red pepper flakes and cook until the garlic is just golden, 30 seconds to 1 minute.
# verb phrases: {0: ('Add', 'Add the garlic and red pepper flakes'), 1: ('cook', 'cook until the garlic is just golden')}
# prep phrases: {0: ('until', 'until the garlic is just golden', 'cook'), 1: ('to', 'to 1 minute', 'cook')}
# noun lists: {}
# nouns: [('the garlic and red pepper flakes', 'add'), ('30 seconds to 1 minute', 'cook')]
# STARTING ZERO SHOT
# END OF ZERO SHOT
# {'the garlic and red pepper flakes': {'sequence': 'the garlic and red pepper flakes', 'labels': ['ingredient', 'quantity', 'pan', 'board', 'container', 'colinder', 'chunks', 'slices', 'cooking utensil', 'bowl', 'time', 'strainer', 'measuring tool', 'appliance', 'spatula', 'knife'], 'scores': [0.8575307130813599, 0.027074212208390236, 0.013276753947138786, 0.011409295722842216, 0.010592717677354813, 0.010424993000924587, 0.00944865308701992, 0.009229150600731373, 0.008825784549117088, 0.008700083009898663, 0.0071028294041752815, 0.007041676435619593, 0.006298798602074385, 0.005528373643755913, 0.003930541221052408, 0.0035854685120284557]}, '30 seconds to 1 minute': {'sequence': '30 seconds to 1 minute', 'labels': ['time', 'chunks', 'quantity', 'measuring tool', 'pan', 'board', 'strainer', 'appliance', 'container', 'cooking utensil', 'colinder', 'slices', 'bowl', 'ingredient', 'spatula', 'knife'], 'scores': [0.5200285315513611, 0.15455128252506256, 0.13187389075756073, 0.04204457625746727, 0.0279972143471241, 0.018472610041499138, 0.015826785936951637, 0.013131646439433098, 0.01223283726722002, 0.01215608324855566, 0.011694787070155144, 0.01087004505097866, 0.009550299495458603, 0.007442783564329147, 0.007134388200938702, 0.004992277827113867]}}
# ID: 0
# 	Head ID: -1
# 	Text: ROOT
# 	Type: N/A
# 	Dependent Words:
# 		Dep. ID: 1
# 			Dep. Text: add
# 			Relation Type: root
# ID: 1
# 	Head ID: 0
# 	Text: add
# 	Type: VB
# 	Dependent Words:
# 		Dep. ID: 3
# 			Dep. Text: shrimp
# 			Relation Type: obj
# 		Dep. ID: 5
# 			Dep. Text: cook
# 			Relation Type: conj
# 		Dep. ID: 23
# 			Dep. Text: .
# 			Relation Type: punct
# ID: 3
# 	Head ID: 1
# 	Text: shrimp
# 	Type: NN
# 	Dependent Words:
# 		Dep. ID: 2
# 			Dep. Text: the
# 			Relation Type: det
# ID: 2
# 	Head ID: 3
# 	Text: the
# 	Type: DT
# 	Dependent Words:
# ID: 5
# 	Head ID: 1
# 	Text: cook
# 	Type: VB
# 	Dependent Words:
# 		Dep. ID: 4
# 			Dep. Text: and
# 			Relation Type: cc
# 		Dep. ID: 7
# 			Dep. Text: stirring
# 			Relation Type: advcl
# ID: 4
# 	Head ID: 5
# 	Text: and
# 	Type: CC
# 	Dependent Words:
# ID: 7
# 	Head ID: 5
# 	Text: stirring
# 	Type: VBG
# 	Dependent Words:
# 		Dep. ID: 6
# 			Dep. Text: ,
# 			Relation Type: punct
# 		Dep. ID: 8
# 			Dep. Text: occasionally
# 			Relation Type: advmod
# 		Dep. ID: 11
# 			Dep. Text: pink
# 			Relation Type: obl
# 		Dep. ID: 14
# 			Dep. Text: cooked
# 			Relation Type: conj
# ID: 6
# 	Head ID: 7
# 	Text: ,
# 	Type: ,
# 	Dependent Words:
# ID: 8
# 	Head ID: 7
# 	Text: occasionally
# 	Type: RB
# 	Dependent Words:
# ID: 11
# 	Head ID: 7
# 	Text: pink
# 	Type: JJ
# 	Dependent Words:
# 		Dep. ID: 9
# 			Dep. Text: ,
# 			Relation Type: punct
# 		Dep. ID: 10
# 			Dep. Text: until
# 			Relation Type: case
# ID: 9
# 	Head ID: 11
# 	Text: ,
# 	Type: ,
# 	Dependent Words:
# ID: 10
# 	Head ID: 11
# 	Text: until
# 	Type: IN
# 	Dependent Words:
# ID: 14
# 	Head ID: 7
# 	Text: cooked
# 	Type: VBN
# 	Dependent Words:
# 		Dep. ID: 12
# 			Dep. Text: and
# 			Relation Type: cc
# 		Dep. ID: 13
# 			Dep. Text: just
# 			Relation Type: advmod
# 		Dep. ID: 15
# 			Dep. Text: through
# 			Relation Type: compound:prt
# 		Dep. ID: 20
# 			Dep. Text: minutes
# 			Relation Type: obl
# ID: 12
# 	Head ID: 14
# 	Text: and
# 	Type: CC
# 	Dependent Words:
# ID: 13
# 	Head ID: 14
# 	Text: just
# 	Type: RB
# 	Dependent Words:
# ID: 15
# 	Head ID: 14
# 	Text: through
# 	Type: RP
# 	Dependent Words:
# ID: 20
# 	Head ID: 14
# 	Text: minutes
# 	Type: NNS
# 	Dependent Words:
# 		Dep. ID: 16
# 			Dep. Text: ,
# 			Relation Type: punct
# 		Dep. ID: 17
# 			Dep. Text: 1
# 			Relation Type: nummod
# 		Dep. ID: 22
# 			Dep. Text: side
# 			Relation Type: nmod
# ID: 16
# 	Head ID: 20
# 	Text: ,
# 	Type: ,
# 	Dependent Words:
# ID: 17
# 	Head ID: 20
# 	Text: 1
# 	Type: CD
# 	Dependent Words:
# 		Dep. ID: 19
# 			Dep. Text: 2
# 			Relation Type: nmod
# ID: 19
# 	Head ID: 17
# 	Text: 2
# 	Type: CD
# 	Dependent Words:
# 		Dep. ID: 18
# 			Dep. Text: to
# 			Relation Type: case
# ID: 18
# 	Head ID: 19
# 	Text: to
# 	Type: IN
# 	Dependent Words:
# ID: 22
# 	Head ID: 20
# 	Text: side
# 	Type: NN
# 	Dependent Words:
# 		Dep. ID: 21
# 			Dep. Text: per
# 			Relation Type: case
# ID: 21
# 	Head ID: 22
# 	Text: per
# 	Type: IN
# 	Dependent Words:
# ID: 23
# 	Head ID: 1
# 	Text: .
# 	Type: .
# 	Dependent Words:
# (S (VP (VP (VB Add) (NP (DT the) (NN shrimp))) (CC and) (VP (VB cook)) (, ,) (VP (VP (VBG stirring) (ADVP (RB occasionally)) (, ,) (PP (IN until) (ADJP (JJ pink)))) (CC and) (ADVP (RB just)) (VP (VBN cooked) (PRT (RP through)))) (, ,) (NP (NP (QP (CD 1) (IN to) (CD 2)) (NNS minutes)) (PP (IN per) (NP (NN side))))) (. .))
# Add the shrimp and cook, stirring occasionally, until pink and just cooked through, 1 to 2 minutes per side.
# 15
# 12
# 13
# 15
# 20
# verb phrases: {0: ('Add', 'Add the shrimp'), 1: ('cook', 'cook')}
# prep phrases: {0: ('occasionally', 'occasionally', 'stirring'), 1: ('until', 'until pink', 'stirring'), 2: ('just', 'just', 'cooked'), 3: ('through', 'through', 'cooked'), 4: ('per', 'per side', 'cooked')}
# noun lists: {}
# nouns: [('the shrimp', 'add'), ('1 to 2 minutes per side', 'cooked')]
# STARTING ZERO SHOT
# END OF ZERO SHOT
# {'the shrimp': {'sequence': 'the shrimp', 'labels': ['ingredient', 'quantity', 'chunks', 'cooking utensil', 'strainer', 'measuring tool', 'time', 'pan', 'bowl', 'container', 'slices', 'appliance', 'colinder', 'board', 'spatula', 'knife'], 'scores': [0.4633963108062744, 0.1854594200849533, 0.06639949232339859, 0.04306885227560997, 0.03340837359428406, 0.030005669221282005, 0.02852402813732624, 0.02090994082391262, 0.020268280059099197, 0.020260201767086983, 0.020259875804185867, 0.018682826310396194, 0.01489298976957798, 0.014038490131497383, 0.011764475144445896, 0.008660733699798584]}, '1 to 2 minutes per side': {'sequence': '1 to 2 minutes per side', 'labels': ['time', 'chunks', 'quantity', 'measuring tool', 'pan', 'board', 'strainer', 'colinder', 'cooking utensil', 'slices', 'container', 'appliance', 'bowl', 'spatula', 'ingredient', 'knife'], 'scores': [0.43587493896484375, 0.17106708884239197, 0.12544678151607513, 0.04427729919552803, 0.040154147893190384, 0.03453243151307106, 0.021721502766013145, 0.018494002521038055, 0.018110143020749092, 0.01752103492617607, 0.014555531553924084, 0.013535898178815842, 0.01338275521993637, 0.0127254668623209, 0.010955046862363815, 0.007645876612514257]}}
# ID: 0
# 	Head ID: -1
# 	Text: ROOT
# 	Type: N/A
# 	Dependent Words:
# 		Dep. ID: 1
# 			Dep. Text: remove
# 			Relation Type: root
# ID: 1
# 	Head ID: 0
# 	Text: remove
# 	Type: VB
# 	Dependent Words:
# 		Dep. ID: 3
# 			Dep. Text: shrimp
# 			Relation Type: obj
# 		Dep. ID: 6
# 			Dep. Text: plate
# 			Relation Type: obl
# 		Dep. ID: 7
# 			Dep. Text: .
# 			Relation Type: punct
# ID: 3
# 	Head ID: 1
# 	Text: shrimp
# 	Type: NN
# 	Dependent Words:
# 		Dep. ID: 2
# 			Dep. Text: the
# 			Relation Type: det
# ID: 2
# 	Head ID: 3
# 	Text: the
# 	Type: DT
# 	Dependent Words:
# ID: 6
# 	Head ID: 1
# 	Text: plate
# 	Type: NN
# 	Dependent Words:
# 		Dep. ID: 4
# 			Dep. Text: to
# 			Relation Type: case
# 		Dep. ID: 5
# 			Dep. Text: a
# 			Relation Type: det
# ID: 4
# 	Head ID: 6
# 	Text: to
# 	Type: IN
# 	Dependent Words:
# ID: 5
# 	Head ID: 6
# 	Text: a
# 	Type: DT
# 	Dependent Words:
# ID: 7
# 	Head ID: 1
# 	Text: .
# 	Type: .
# 	Dependent Words:
# (S (VP (VB Remove) (NP (DT the) (NN shrimp)) (PP (IN to) (NP (DT a) (NN plate)))) (. .))
# Remove the shrimp to a plate.
# verb phrases: {0: ('Remove', 'Remove the shrimp to a plate')}
# prep phrases: {0: ('to', 'to a plate', 'remove')}
# noun lists: {}
# nouns: [('the shrimp', 'remove'), ('a plate', 'remove')]
# STARTING ZERO SHOT
# END OF ZERO SHOT
# {'the shrimp': {'sequence': 'the shrimp', 'labels': ['ingredient', 'quantity', 'chunks', 'cooking utensil', 'strainer', 'measuring tool', 'time', 'pan', 'bowl', 'container', 'slices', 'appliance', 'colinder', 'board', 'spatula', 'knife'], 'scores': [0.4633963108062744, 0.1854594200849533, 0.06639949232339859, 0.04306885227560997, 0.03340837359428406, 0.030005669221282005, 0.02852402813732624, 0.02090994082391262, 0.020268280059099197, 0.020260201767086983, 0.020259875804185867, 0.018682826310396194, 0.01489298976957798, 0.014038490131497383, 0.011764475144445896, 0.008660733699798584]}, 'a plate': {'sequence': 'a plate', 'labels': ['cooking utensil', 'quantity', 'appliance', 'ingredient', 'time', 'pan', 'container', 'slices', 'chunks', 'bowl', 'measuring tool', 'colinder', 'board', 'strainer', 'spatula', 'knife'], 'scores': [0.44913333654403687, 0.11484883725643158, 0.07492775470018387, 0.061380501836538315, 0.03703196719288826, 0.03597957268357277, 0.03251584991812706, 0.02749372459948063, 0.02632083185017109, 0.025584040209650993, 0.02398364059627056, 0.022480163723230362, 0.021987056359648705, 0.0201315525919199, 0.016338691115379333, 0.009862526319921017]}}
# ID: 0
# 	Head ID: -1
# 	Text: ROOT
# 	Type: N/A
# 	Dependent Words:
# 		Dep. ID: 1
# 			Dep. Text: add
# 			Relation Type: root
# ID: 1
# 	Head ID: 0
# 	Text: add
# 	Type: VB
# 	Dependent Words:
# 		Dep. ID: 3
# 			Dep. Text: wine
# 			Relation Type: obj
# 		Dep. ID: 9
# 			Dep. Text: skillet
# 			Relation Type: obl
# 		Dep. ID: 11
# 			Dep. Text: simmer
# 			Relation Type: conj
# 		Dep. ID: 18
# 			Dep. Text: .
# 			Relation Type: punct
# ID: 3
# 	Head ID: 1
# 	Text: wine
# 	Type: NN
# 	Dependent Words:
# 		Dep. ID: 2
# 			Dep. Text: the
# 			Relation Type: det
# 		Dep. ID: 6
# 			Dep. Text: juice
# 			Relation Type: conj
# ID: 2
# 	Head ID: 3
# 	Text: the
# 	Type: DT
# 	Dependent Words:
# ID: 6
# 	Head ID: 3
# 	Text: juice
# 	Type: NN
# 	Dependent Words:
# 		Dep. ID: 4
# 			Dep. Text: and
# 			Relation Type: cc
# 		Dep. ID: 5
# 			Dep. Text: lemon
# 			Relation Type: compound
# ID: 4
# 	Head ID: 6
# 	Text: and
# 	Type: CC
# 	Dependent Words:
# ID: 5
# 	Head ID: 6
# 	Text: lemon
# 	Type: NN
# 	Dependent Words:
# ID: 9
# 	Head ID: 1
# 	Text: skillet
# 	Type: NN
# 	Dependent Words:
# 		Dep. ID: 7
# 			Dep. Text: to
# 			Relation Type: case
# 		Dep. ID: 8
# 			Dep. Text: the
# 			Relation Type: det
# ID: 7
# 	Head ID: 9
# 	Text: to
# 	Type: IN
# 	Dependent Words:
# ID: 8
# 	Head ID: 9
# 	Text: the
# 	Type: DT
# 	Dependent Words:
# ID: 11
# 	Head ID: 1
# 	Text: simmer
# 	Type: VB
# 	Dependent Words:
# 		Dep. ID: 10
# 			Dep. Text: and
# 			Relation Type: cc
# 		Dep. ID: 14
# 			Dep. Text: reduced
# 			Relation Type: advcl
# 		Dep. ID: 17
# 			Dep. Text: minutes
# 			Relation Type: obl:tmod
# ID: 10
# 	Head ID: 11
# 	Text: and
# 	Type: CC
# 	Dependent Words:
# ID: 14
# 	Head ID: 11
# 	Text: reduced
# 	Type: VBN
# 	Dependent Words:
# 		Dep. ID: 12
# 			Dep. Text: until
# 			Relation Type: mark
# 		Dep. ID: 13
# 			Dep. Text: slightly
# 			Relation Type: advmod
# ID: 12
# 	Head ID: 14
# 	Text: until
# 	Type: IN
# 	Dependent Words:
# ID: 13
# 	Head ID: 14
# 	Text: slightly
# 	Type: RB
# 	Dependent Words:
# ID: 17
# 	Head ID: 11
# 	Text: minutes
# 	Type: NNS
# 	Dependent Words:
# 		Dep. ID: 15
# 			Dep. Text: ,
# 			Relation Type: punct
# 		Dep. ID: 16
# 			Dep. Text: 2
# 			Relation Type: nummod
# ID: 15
# 	Head ID: 17
# 	Text: ,
# 	Type: ,
# 	Dependent Words:
# ID: 16
# 	Head ID: 17
# 	Text: 2
# 	Type: CD
# 	Dependent Words:
# ID: 18
# 	Head ID: 1
# 	Text: .
# 	Type: .
# 	Dependent Words:
# (S (S (VP (VP (VB Add) (NP (DT the) (NML (NML (NN wine)) (CC and) (NML (NN lemon) (NN juice)))) (PP (IN to) (NP (DT the) (NN skillet)))) (CC and) (VP (VB simmer) (SBAR (IN until) (S (ADJP (RB slightly) (VBN reduced))))))) (, ,) (NP (CD 2) (NNS minutes)) (. .))
# Add the wine and lemon juice to the skillet and simmer until slightly reduced, 2 minutes.
# verb phrases: {0: ('Add', 'Add the wine and lemon juice to the skillet'), 1: ('simmer', 'simmer until slightly reduced')}
# prep phrases: {0: ('to', 'to the skillet', 'add'), 1: ('until', 'until slightly reduced', 'reduced')}
# noun lists: {}
# nouns: [('the wine and lemon juice', 'add'), ('the skillet', 'add'), ('2 minutes', 'simmer')]
# STARTING ZERO SHOT
# END OF ZERO SHOT
# {'the wine and lemon juice': {'sequence': 'the wine and lemon juice', 'labels': ['ingredient', 'quantity', 'container', 'board', 'strainer', 'chunks', 'slices', 'bowl', 'cooking utensil', 'pan', 'measuring tool', 'colinder', 'time', 'appliance', 'spatula', 'knife'], 'scores': [0.8674467206001282, 0.02547372691333294, 0.019701456651091576, 0.011838261038064957, 0.011389326304197311, 0.009464116767048836, 0.007969480007886887, 0.007096605841070414, 0.006906060967594385, 0.00650788564234972, 0.0064871786162257195, 0.005850018467754126, 0.005240482743829489, 0.003740309039130807, 0.0031138446647673845, 0.0017744945362210274]}, 'the skillet': {'sequence': 'the skillet', 'labels': ['cooking utensil', 'pan', 'ingredient', 'appliance', 'quantity', 'chunks', 'time', 'measuring tool', 'container', 'spatula', 'slices', 'colinder', 'strainer', 'board', 'bowl', 'knife'], 'scores': [0.7201952338218689, 0.1347857117652893, 0.08588694036006927, 0.028935382142663002, 0.006916466169059277, 0.005202547647058964, 0.0028882878832519054, 0.0028224496636539698, 0.0021820496767759323, 0.0019661884289234877, 0.0019500229973345995, 0.0017324264626950026, 0.0013590218732133508, 0.0012475482653826475, 0.0012316129868850112, 0.0006981259793974459]}, '2 minutes': {'sequence': '2 minutes', 'labels': ['time', 'quantity', 'chunks', 'pan', 'measuring tool', 'board', 'colinder', 'strainer', 'cooking utensil', 'appliance', 'container', 'slices', 'bowl', 'ingredient', 'spatula', 'knife'], 'scores': [0.6676828265190125, 0.08501464128494263, 0.054656706750392914, 0.03061475232243538, 0.025951340794563293, 0.024056451395154, 0.01536297332495451, 0.01390626560896635, 0.01371634192764759, 0.013405120931565762, 0.011158835142850876, 0.010961605235934258, 0.01043990720063448, 0.010153749957680702, 0.007221160922199488, 0.005697381682693958]}}
# ID: 0
# 	Head ID: -1
# 	Text: ROOT
# 	Type: N/A
# 	Dependent Words:
# 		Dep. ID: 1
# 			Dep. Text: return
# 			Relation Type: root
# ID: 1
# 	Head ID: 0
# 	Text: return
# 	Type: VB
# 	Dependent Words:
# 		Dep. ID: 3
# 			Dep. Text: shrimp
# 			Relation Type: obj
# 		Dep. ID: 12
# 			Dep. Text: skillet
# 			Relation Type: obl
# 		Dep. ID: 27
# 			Dep. Text: .
# 			Relation Type: punct
# ID: 3
# 	Head ID: 1
# 	Text: shrimp
# 	Type: NN
# 	Dependent Words:
# 		Dep. ID: 2
# 			Dep. Text: the
# 			Relation Type: det
# 		Dep. ID: 6
# 			Dep. Text: juices
# 			Relation Type: conj
# ID: 2
# 	Head ID: 3
# 	Text: the
# 	Type: DT
# 	Dependent Words:
# ID: 6
# 	Head ID: 3
# 	Text: juices
# 	Type: NNS
# 	Dependent Words:
# 		Dep. ID: 4
# 			Dep. Text: and
# 			Relation Type: cc
# 		Dep. ID: 5
# 			Dep. Text: any
# 			Relation Type: det
# 		Dep. ID: 9
# 			Dep. Text: plate
# 			Relation Type: nmod
# ID: 4
# 	Head ID: 6
# 	Text: and
# 	Type: CC
# 	Dependent Words:
# ID: 5
# 	Head ID: 6
# 	Text: any
# 	Type: DT
# 	Dependent Words:
# ID: 9
# 	Head ID: 6
# 	Text: plate
# 	Type: NN
# 	Dependent Words:
# 		Dep. ID: 7
# 			Dep. Text: from
# 			Relation Type: case
# 		Dep. ID: 8
# 			Dep. Text: the
# 			Relation Type: det
# ID: 7
# 	Head ID: 9
# 	Text: from
# 	Type: IN
# 	Dependent Words:
# ID: 8
# 	Head ID: 9
# 	Text: the
# 	Type: DT
# 	Dependent Words:
# ID: 12
# 	Head ID: 1
# 	Text: skillet
# 	Type: NN
# 	Dependent Words:
# 		Dep. ID: 10
# 			Dep. Text: to
# 			Relation Type: case
# 		Dep. ID: 11
# 			Dep. Text: the
# 			Relation Type: det
# 		Dep. ID: 16
# 			Dep. Text: linguine
# 			Relation Type: nmod
# ID: 10
# 	Head ID: 12
# 	Text: to
# 	Type: IN
# 	Dependent Words:
# ID: 11
# 	Head ID: 12
# 	Text: the
# 	Type: DT
# 	Dependent Words:
# ID: 16
# 	Head ID: 12
# 	Text: linguine
# 	Type: NN
# 	Dependent Words:
# 		Dep. ID: 13
# 			Dep. Text: along
# 			Relation Type: case
# 		Dep. ID: 14
# 			Dep. Text: with
# 			Relation Type: case
# 		Dep. ID: 15
# 			Dep. Text: the
# 			Relation Type: det
# 		Dep. ID: 18
# 			Dep. Text: butter
# 			Relation Type: conj
# 		Dep. ID: 21
# 			Dep. Text: cup
# 			Relation Type: conj
# ID: 13
# 	Head ID: 16
# 	Text: along
# 	Type: IN
# 	Dependent Words:
# ID: 14
# 	Head ID: 16
# 	Text: with
# 	Type: IN
# 	Dependent Words:
# ID: 15
# 	Head ID: 16
# 	Text: the
# 	Type: DT
# 	Dependent Words:
# ID: 18
# 	Head ID: 16
# 	Text: butter
# 	Type: NN
# 	Dependent Words:
# 		Dep. ID: 17
# 			Dep. Text: ,
# 			Relation Type: punct
# ID: 17
# 	Head ID: 18
# 	Text: ,
# 	Type: ,
# 	Dependent Words:
# ID: 21
# 	Head ID: 16
# 	Text: cup
# 	Type: NN
# 	Dependent Words:
# 		Dep. ID: 19
# 			Dep. Text: and
# 			Relation Type: cc
# 		Dep. ID: 20
# 			Dep. Text: 1/2
# 			Relation Type: nummod
# 		Dep. ID: 26
# 			Dep. Text: water
# 			Relation Type: nmod
# ID: 19
# 	Head ID: 21
# 	Text: and
# 	Type: CC
# 	Dependent Words:
# ID: 20
# 	Head ID: 21
# 	Text: 1/2
# 	Type: CD
# 	Dependent Words:
# ID: 26
# 	Head ID: 21
# 	Text: water
# 	Type: NN
# 	Dependent Words:
# 		Dep. ID: 22
# 			Dep. Text: of
# 			Relation Type: case
# 		Dep. ID: 23
# 			Dep. Text: the
# 			Relation Type: det
# 		Dep. ID: 24
# 			Dep. Text: reserved
# 			Relation Type: amod
# 		Dep. ID: 25
# 			Dep. Text: cooking
# 			Relation Type: compound
# ID: 22
# 	Head ID: 26
# 	Text: of
# 	Type: IN
# 	Dependent Words:
# ID: 23
# 	Head ID: 26
# 	Text: the
# 	Type: DT
# 	Dependent Words:
# ID: 24
# 	Head ID: 26
# 	Text: reserved
# 	Type: VBN
# 	Dependent Words:
# ID: 25
# 	Head ID: 26
# 	Text: cooking
# 	Type: NN
# 	Dependent Words:
# ID: 27
# 	Head ID: 1
# 	Text: .
# 	Type: .
# 	Dependent Words:
# (S (VP (VB Return) (NP (NP (DT the) (NN shrimp)) (CC and) (NP (NP (DT any) (NNS juices)) (PP (IN from) (NP (DT the) (NN plate))))) (PP (IN to) (NP (NP (DT the) (NN skillet)) (PP (IN along) (PP (IN with) (NP (NP (DT the) (NML (NML (NN linguine)) (, ,) (NML (NN butter)) (CC and) (NML (CD 1/2) (NN cup)))) (PP (IN of) (NP (DT the) (VBN reserved) (NN cooking) (NN water))))))))) (. .))
# Return the shrimp and any juices from the plate to the skillet along with the linguine, butter and 1/2 cup of the reserved cooking water.
# ['the shrimp', 'any juices from the plate']
# skillet
# ?
# verb phrases: {0: ('Return', 'Return the shrimp and any juices from the plate to the skillet along with the linguine, butter and 1/2 cup of the reserved cooking water')}
# prep phrases: {0: ('from', 'from the plate', 'return'), 1: ('to', 'to the skillet along with the linguine, butter and 1/2 cup of the reserved cooking water', 'return')}
# noun lists: {0: (<ListType.AND: 0>, ['the shrimp', 'any juices from the plate', 'the skillet'], 'return')}
# nouns: [('the shrimp', 'return'), ('any juices from the plate', 'return'), ('the skillet along with the linguine, butter and 1/2 cup of the reserved cooking water', 'return')]
# STARTING ZERO SHOT
# END OF ZERO SHOT
# {'the shrimp': {'sequence': 'the shrimp', 'labels': ['ingredient', 'quantity', 'chunks', 'cooking utensil', 'strainer', 'measuring tool', 'time', 'pan', 'bowl', 'container', 'slices', 'appliance', 'colinder', 'board', 'spatula', 'knife'], 'scores': [0.4633963108062744, 0.1854594200849533, 0.06639949232339859, 0.04306885227560997, 0.03340837359428406, 0.030005669221282005, 0.02852402813732624, 0.02090994082391262, 0.020268280059099197, 0.020260201767086983, 0.020259875804185867, 0.018682826310396194, 0.01489298976957798, 0.014038490131497383, 0.011764475144445896, 0.008660733699798584]}, 'any juices from the plate': {'sequence': 'any juices from the plate', 'labels': ['ingredient', 'cooking utensil', 'quantity', 'chunks', 'strainer', 'slices', 'container', 'pan', 'appliance', 'colinder', 'measuring tool', 'bowl', 'time', 'board', 'spatula', 'knife'], 'scores': [0.34338366985321045, 0.22064299881458282, 0.11972088366746902, 0.0498204305768013, 0.03859187290072441, 0.036210283637046814, 0.03617788851261139, 0.026595082134008408, 0.022470667958259583, 0.020888319239020348, 0.018509559333324432, 0.0177965946495533, 0.01613585650920868, 0.013645387254655361, 0.012696810998022556, 0.006713702343404293]}, 'the skillet along with the linguine, butter and 1/2 cup of the reserved cooking water': {'sequence': 'the skillet along with the linguine, butter and 1/2 cup of the reserved cooking water', 'labels': ['cooking utensil', 'ingredient', 'pan', 'appliance', 'quantity', 'time', 'measuring tool', 'colinder', 'container', 'board', 'chunks', 'slices', 'strainer', 'bowl', 'spatula', 'knife'], 'scores': [0.3684200644493103, 0.272289514541626, 0.24975675344467163, 0.038764920085668564, 0.021603375673294067, 0.0109473317861557, 0.0077845072373747826, 0.007758532650768757, 0.006114047486335039, 0.004727723076939583, 0.003921404015272856, 0.003465431509539485, 0.001374630955979228, 0.0013285991735756397, 0.0008878628723323345, 0.0008553120424039662]}}
# ID: 0
# 	Head ID: -1
# 	Text: ROOT
# 	Type: N/A
# 	Dependent Words:
# 		Dep. ID: 1
# 			Dep. Text: continue
# 			Relation Type: root
# ID: 1
# 	Head ID: 0
# 	Text: continue
# 	Type: VB
# 	Dependent Words:
# 		Dep. ID: 3
# 			Dep. Text: cook
# 			Relation Type: xcomp
# 		Dep. ID: 16
# 			Dep. Text: hot
# 			Relation Type: conj
# 		Dep. ID: 31
# 			Dep. Text: .
# 			Relation Type: punct
# ID: 3
# 	Head ID: 1
# 	Text: cook
# 	Type: VB
# 	Dependent Words:
# 		Dep. ID: 2
# 			Dep. Text: to
# 			Relation Type: mark
# 		Dep. ID: 5
# 			Dep. Text: tossing
# 			Relation Type: conj
# 		Dep. ID: 11
# 			Dep. Text: melted
# 			Relation Type: advcl
# ID: 2
# 	Head ID: 3
# 	Text: to
# 	Type: TO
# 	Dependent Words:
# ID: 5
# 	Head ID: 3
# 	Text: tossing
# 	Type: VBG
# 	Dependent Words:
# 		Dep. ID: 4
# 			Dep. Text: ,
# 			Relation Type: punct
# ID: 4
# 	Head ID: 5
# 	Text: ,
# 	Type: ,
# 	Dependent Words:
# ID: 11
# 	Head ID: 3
# 	Text: melted
# 	Type: VBN
# 	Dependent Words:
# 		Dep. ID: 6
# 			Dep. Text: ,
# 			Relation Type: punct
# 		Dep. ID: 7
# 			Dep. Text: until
# 			Relation Type: mark
# 		Dep. ID: 9
# 			Dep. Text: butter
# 			Relation Type: nsubj:pass
# 		Dep. ID: 10
# 			Dep. Text: is
# 			Relation Type: aux:pass
# ID: 6
# 	Head ID: 11
# 	Text: ,
# 	Type: ,
# 	Dependent Words:
# ID: 7
# 	Head ID: 11
# 	Text: until
# 	Type: IN
# 	Dependent Words:
# ID: 9
# 	Head ID: 11
# 	Text: butter
# 	Type: NN
# 	Dependent Words:
# 		Dep. ID: 8
# 			Dep. Text: the
# 			Relation Type: det
# ID: 8
# 	Head ID: 9
# 	Text: the
# 	Type: DT
# 	Dependent Words:
# ID: 10
# 	Head ID: 11
# 	Text: is
# 	Type: VBZ
# 	Dependent Words:
# ID: 16
# 	Head ID: 1
# 	Text: hot
# 	Type: JJ
# 	Dependent Words:
# 		Dep. ID: 12
# 			Dep. Text: and
# 			Relation Type: cc
# 		Dep. ID: 14
# 			Dep. Text: shrimp
# 			Relation Type: nsubj
# 		Dep. ID: 15
# 			Dep. Text: is
# 			Relation Type: cop
# 		Dep. ID: 20
# 			Dep. Text: minutes
# 			Relation Type: obl:tmod
# 		Dep. ID: 22
# 			Dep. Text: adding
# 			Relation Type: advcl
# ID: 12
# 	Head ID: 16
# 	Text: and
# 	Type: CC
# 	Dependent Words:
# ID: 14
# 	Head ID: 16
# 	Text: shrimp
# 	Type: NN
# 	Dependent Words:
# 		Dep. ID: 13
# 			Dep. Text: the
# 			Relation Type: det
# ID: 13
# 	Head ID: 14
# 	Text: the
# 	Type: DT
# 	Dependent Words:
# ID: 15
# 	Head ID: 16
# 	Text: is
# 	Type: VBZ
# 	Dependent Words:
# ID: 20
# 	Head ID: 16
# 	Text: minutes
# 	Type: NNS
# 	Dependent Words:
# 		Dep. ID: 17
# 			Dep. Text: ,
# 			Relation Type: punct
# 		Dep. ID: 19
# 			Dep. Text: 2
# 			Relation Type: nummod
# ID: 17
# 	Head ID: 20
# 	Text: ,
# 	Type: ,
# 	Dependent Words:
# ID: 19
# 	Head ID: 20
# 	Text: 2
# 	Type: CD
# 	Dependent Words:
# 		Dep. ID: 18
# 			Dep. Text: about
# 			Relation Type: advmod
# ID: 18
# 	Head ID: 19
# 	Text: about
# 	Type: RB
# 	Dependent Words:
# ID: 22
# 	Head ID: 16
# 	Text: adding
# 	Type: VBG
# 	Dependent Words:
# 		Dep. ID: 21
# 			Dep. Text: ,
# 			Relation Type: punct
# 		Dep. ID: 23
# 			Dep. Text: more
# 			Relation Type: obj
# 		Dep. ID: 30
# 			Dep. Text: needed
# 			Relation Type: advcl
# ID: 21
# 	Head ID: 22
# 	Text: ,
# 	Type: ,
# 	Dependent Words:
# ID: 23
# 	Head ID: 22
# 	Text: more
# 	Type: JJR
# 	Dependent Words:
# 		Dep. ID: 28
# 			Dep. Text: water
# 			Relation Type: obl
# ID: 28
# 	Head ID: 23
# 	Text: water
# 	Type: NN
# 	Dependent Words:
# 		Dep. ID: 24
# 			Dep. Text: of
# 			Relation Type: case
# 		Dep. ID: 25
# 			Dep. Text: the
# 			Relation Type: det
# 		Dep. ID: 26
# 			Dep. Text: reserved
# 			Relation Type: amod
# 		Dep. ID: 27
# 			Dep. Text: cooking
# 			Relation Type: compound
# ID: 24
# 	Head ID: 28
# 	Text: of
# 	Type: IN
# 	Dependent Words:
# ID: 25
# 	Head ID: 28
# 	Text: the
# 	Type: DT
# 	Dependent Words:
# ID: 26
# 	Head ID: 28
# 	Text: reserved
# 	Type: VBN
# 	Dependent Words:
# ID: 27
# 	Head ID: 28
# 	Text: cooking
# 	Type: NN
# 	Dependent Words:
# ID: 30
# 	Head ID: 22
# 	Text: needed
# 	Type: VBN
# 	Dependent Words:
# 		Dep. ID: 29
# 			Dep. Text: as
# 			Relation Type: mark
# ID: 29
# 	Head ID: 30
# 	Text: as
# 	Type: IN
# 	Dependent Words:
# ID: 31
# 	Head ID: 1
# 	Text: .
# 	Type: .
# 	Dependent Words:
# (S (S (VP (VB Continue) (S (VP (TO to) (VP (VB cook) (, ,) (S (VP (VBG tossing))) (, ,) (SBAR (IN until) (S (S (NP (DT the) (NN butter)) (VP (VBZ is) (VP (VBN melted)))) (CC and) (S (NP (DT the) (NN shrimp)) (VP (VBZ is) (ADJP (JJ hot))))))))))) (, ,) (NP (QP (RB about) (CD 2)) (NNS minutes)) (, ,) (S (VP (VBG adding) (NP (NP (JJR more)) (PP (IN of) (NP (DT the) (VBN reserved) (NN cooking) (NN water)))) (SBAR (IN as) (S (VP (VBN needed)))))) (. .))
# Continue to cook, tossing, until the butter is melted and the shrimp is hot, about 2 minutes, adding more of the reserved cooking water as needed.
# verb phrases: {0: ('Continue', 'Continue to cook, tossing, until the butter is melted and the shrimp is hot'), 1: ('cook', 'cook, tossing, until the butter is melted and the shrimp is hot')}
# prep phrases: {0: ('until', 'until the butter is melted and the shrimp is hot', 'melted'), 1: ('of', 'of the reserved cooking water', 'adding'), 2: ('as', 'as needed', 'needed')}
# noun lists: {}
# nouns: [('the butter', 'melted'), ('the shrimp', 'continue'), ('about 2 minutes', 'continue'), ('more of the reserved cooking water', 'adding')]
# STARTING ZERO SHOT
# END OF ZERO SHOT
# {'the butter': {'sequence': 'the butter', 'labels': ['ingredient', 'cooking utensil', 'quantity', 'appliance', 'pan', 'time', 'measuring tool', 'chunks', 'strainer', 'container', 'bowl', 'slices', 'spatula', 'colinder', 'knife', 'board'], 'scores': [0.8651270866394043, 0.031090429052710533, 0.02323765866458416, 0.008699257858097553, 0.008639550767838955, 0.008009293116629124, 0.007824407890439034, 0.007354084402322769, 0.007289042696356773, 0.0066923280246555805, 0.005047346465289593, 0.0048681641928851604, 0.004336630925536156, 0.004171944689005613, 0.004076431039720774, 0.0035363337956368923]}, 'the shrimp': {'sequence': 'the shrimp', 'labels': ['ingredient', 'quantity', 'chunks', 'cooking utensil', 'strainer', 'measuring tool', 'time', 'pan', 'bowl', 'container', 'slices', 'appliance', 'colinder', 'board', 'spatula', 'knife'], 'scores': [0.4633963108062744, 0.1854594200849533, 0.06639949232339859, 0.04306885227560997, 0.03340837359428406, 0.030005669221282005, 0.02852402813732624, 0.02090994082391262, 0.020268280059099197, 0.020260201767086983, 0.020259875804185867, 0.018682826310396194, 0.01489298976957798, 0.014038490131497383, 0.011764475144445896, 0.008660733699798584]}, 'about 2 minutes': {'sequence': 'about 2 minutes', 'labels': ['time', 'chunks', 'quantity', 'pan', 'board', 'measuring tool', 'cooking utensil', 'strainer', 'appliance', 'bowl', 'container', 'slices', 'colinder', 'ingredient', 'spatula', 'knife'], 'scores': [0.6517713069915771, 0.08162280917167664, 0.04890097677707672, 0.03779866173863411, 0.026537541300058365, 0.02272617444396019, 0.01768338307738304, 0.016814107075333595, 0.01530858688056469, 0.013759550638496876, 0.013757606968283653, 0.013201180845499039, 0.012953998520970345, 0.010386412963271141, 0.00956020038574934, 0.007217560429126024]}, 'more of the reserved cooking water': {'sequence': 'more of the reserved cooking water', 'labels': ['quantity', 'ingredient', 'container', 'time', 'cooking utensil', 'pan', 'appliance', 'strainer', 'measuring tool', 'bowl', 'colinder', 'board', 'chunks', 'spatula', 'slices', 'knife'], 'scores': [0.45247581601142883, 0.14003713428974152, 0.06832127273082733, 0.05364326015114784, 0.042706165462732315, 0.037675339728593826, 0.036991018801927567, 0.029874207451939583, 0.029666660353541374, 0.02531406842172146, 0.023196224123239517, 0.022931214421987534, 0.0170731320977211, 0.008625647984445095, 0.006952245254069567, 0.0045166173949837685]}}
# ID: 0
# 	Head ID: -1
# 	Text: ROOT
# 	Type: N/A
# 	Dependent Words:
# 		Dep. ID: 1
# 			Dep. Text: season
# 			Relation Type: root
# ID: 1
# 	Head ID: 0
# 	Text: season
# 	Type: NN
# 	Dependent Words:
# 		Dep. ID: 3
# 			Dep. Text: salt
# 			Relation Type: nmod
# 		Dep. ID: 4
# 			Dep. Text: ;
# 			Relation Type: punct
# 		Dep. ID: 5
# 			Dep. Text: stir
# 			Relation Type: parataxis
# 		Dep. ID: 9
# 			Dep. Text: .
# 			Relation Type: punct
# ID: 3
# 	Head ID: 1
# 	Text: salt
# 	Type: NN
# 	Dependent Words:
# 		Dep. ID: 2
# 			Dep. Text: with
# 			Relation Type: case
# ID: 2
# 	Head ID: 3
# 	Text: with
# 	Type: IN
# 	Dependent Words:
# ID: 4
# 	Head ID: 1
# 	Text: ;
# 	Type: ,
# 	Dependent Words:
# ID: 5
# 	Head ID: 1
# 	Text: stir
# 	Type: VB
# 	Dependent Words:
# 		Dep. ID: 8
# 			Dep. Text: parsley
# 			Relation Type: obl
# ID: 8
# 	Head ID: 5
# 	Text: parsley
# 	Type: NN
# 	Dependent Words:
# 		Dep. ID: 6
# 			Dep. Text: in
# 			Relation Type: case
# 		Dep. ID: 7
# 			Dep. Text: the
# 			Relation Type: det
# ID: 6
# 	Head ID: 8
# 	Text: in
# 	Type: IN
# 	Dependent Words:
# ID: 7
# 	Head ID: 8
# 	Text: the
# 	Type: DT
# 	Dependent Words:
# ID: 9
# 	Head ID: 1
# 	Text: .
# 	Type: .
# 	Dependent Words:
# (NP (NP (NP (NN Season)) (PP (IN with) (NP (NN salt)))) (, ;) (S (VP (VB stir) (PP (IN in) (NP (DT the) (NN parsley))))) (. .))
# Season with salt; stir in the parsley.
# ['Season with salt']
# verb phrases: {0: ('stir', 'stir in the parsley')}
# prep phrases: {0: ('with', 'with salt', None), 1: ('in', 'in the parsley', 'stir')}
# noun lists: {0: (<ListType.UNSPECIFIED: 2>, ['Season with salt'], None)}
# nouns: [('Season with salt', None), ('the parsley', 'stir')]
# STARTING ZERO SHOT
# END OF ZERO SHOT
# {'season with salt': {'sequence': 'season with salt', 'labels': ['ingredient', 'quantity', 'pan', 'time', 'container', 'measuring tool', 'bowl', 'board', 'appliance', 'strainer', 'cooking utensil', 'colinder', 'chunks', 'slices', 'spatula', 'knife'], 'scores': [0.4476131200790405, 0.24719269573688507, 0.03917689248919487, 0.03900451958179474, 0.03284522891044617, 0.025307297706604004, 0.025212056934833527, 0.024898236617445946, 0.021408457309007645, 0.020939866080880165, 0.01947903260588646, 0.01624567247927189, 0.01578909531235695, 0.009630415588617325, 0.00929197110235691, 0.005965452641248703]}, 'the parsley': {'sequence': 'the parsley', 'labels': ['ingredient', 'quantity', 'chunks', 'strainer', 'measuring tool', 'pan', 'container', 'bowl', 'time', 'slices', 'appliance', 'cooking utensil', 'spatula', 'board', 'colinder', 'knife'], 'scores': [0.8013136386871338, 0.03181668743491173, 0.028034407645463943, 0.019859464839100838, 0.01901797018945217, 0.015691233798861504, 0.013598661869764328, 0.013594805262982845, 0.010950872674584389, 0.009657928720116615, 0.008348464034497738, 0.007891804911196232, 0.006441482342779636, 0.005092480685561895, 0.00466880202293396, 0.0040212357416749]}}
# ID: 0
# 	Head ID: -1
# 	Text: ROOT
# 	Type: N/A
# 	Dependent Words:
# 		Dep. ID: 1
# 			Dep. Text: serve
# 			Relation Type: root
# ID: 1
# 	Head ID: 0
# 	Text: serve
# 	Type: VB
# 	Dependent Words:
# 		Dep. ID: 4
# 			Dep. Text: wedges
# 			Relation Type: obl
# 		Dep. ID: 5
# 			Dep. Text: .
# 			Relation Type: punct
# ID: 4
# 	Head ID: 1
# 	Text: wedges
# 	Type: NNS
# 	Dependent Words:
# 		Dep. ID: 2
# 			Dep. Text: with
# 			Relation Type: case
# 		Dep. ID: 3
# 			Dep. Text: lemon
# 			Relation Type: compound
# ID: 2
# 	Head ID: 4
# 	Text: with
# 	Type: IN
# 	Dependent Words:
# ID: 3
# 	Head ID: 4
# 	Text: lemon
# 	Type: NN
# 	Dependent Words:
# ID: 5
# 	Head ID: 1
# 	Text: .
# 	Type: .
# 	Dependent Words:
# (S (VP (VB Serve) (PP (IN with) (NP (NN lemon) (NNS wedges)))) (. .))
# Serve with lemon wedges.
# verb phrases: {0: ('Serve', 'Serve with lemon wedges')}
# prep phrases: {0: ('with', 'with lemon wedges', 'serve')}
# noun lists: {}
# nouns: [('lemon wedges', 'serve')]
# STARTING ZERO SHOT
# END OF ZERO SHOT
# {'lemon wedges': {'sequence': 'lemon wedges', 'labels': ['slices', 'ingredient', 'quantity', 'chunks', 'measuring tool', 'time', 'bowl', 'container', 'appliance', 'strainer', 'pan', 'cooking utensil', 'colinder', 'board', 'spatula', 'knife'], 'scores': [0.5028496384620667, 0.3319513201713562, 0.054248590022325516, 0.030556803569197655, 0.013564788736402988, 0.010875241830945015, 0.008247483521699905, 0.007715669460594654, 0.007685953751206398, 0.007247039582580328, 0.0065864864736795425, 0.006228819023817778, 0.003211101284250617, 0.0031906382646411657, 0.002964315004646778, 0.0028761280700564384]}}

# %%
test_text3 = "Prep the strawberries: Cut the stems away from the strawberries and discard. Cut the strawberries in half, and then in either quarters or thick slices. Macerate the strawberries with sugar: Put the cut strawberries into a large bowl and sprinkle with sugar. Start with 1/4 cup of sugar and then add up to another 1/4 cup depending on how sweet your strawberries are. Gently stir the strawberries until they are all coated with some sugar. Let sit at room temperature for about 20 minutes, until the berries soften and begin to release their juices. Mash some of the strawberries: After 20 minutes or so, mash about a quarter of the berries in the bowl with a potato masher and stir to mix. You don't want to mash all the berries, just enough of them for their juices. Let sit while you bake the biscuits. Bake the biscuits: Use the recipe below to bake the biscuits. Make the whipped cream: While the biscuits are baking, whip the cream using an electric mixer, adding a drop or two of vanilla and 2 teaspoons of powdered sugar. Cover with plastic and place in the refrigerator to chill until ready to serve. To serve, break up one biscuit per person into big pieces into a bowl. Ladle strawberries over the biscuit. Add a dollop of whipped cream."
allsteps3 = doParsing(test_text3, [])
# Out:
# ID: 0
# 	Head ID: -1
# 	Text: ROOT
# 	Type: N/A
# 	Dependent Words:
# 		Dep. ID: 1
# 			Dep. Text: prep
# 			Relation Type: root
# ID: 1
# 	Head ID: 0
# 	Text: prep
# 	Type: VB
# 	Dependent Words:
# 		Dep. ID: 3
# 			Dep. Text: strawberries
# 			Relation Type: obj
# 		Dep. ID: 4
# 			Dep. Text: :
# 			Relation Type: punct
# ID: 3
# 	Head ID: 1
# 	Text: strawberries
# 	Type: NNS
# 	Dependent Words:
# 		Dep. ID: 2
# 			Dep. Text: the
# 			Relation Type: det
# ID: 2
# 	Head ID: 3
# 	Text: the
# 	Type: DT
# 	Dependent Words:
# ID: 4
# 	Head ID: 1
# 	Text: :
# 	Type: :
# 	Dependent Words:
# (S (VP (VB Prep) (NP (DT the) (NNS strawberries))) (: :))
# Prep the strawberries:
# verb phrases: {0: ('Prep', 'Prep the strawberries')}
# prep phrases: {}
# noun lists: {}
# nouns: [('the strawberries', 'prep')]
# STARTING ZERO SHOT
# END OF ZERO SHOT
# {'the strawberries': {'sequence': 'the strawberries', 'labels': ['ingredient', 'quantity', 'chunks', 'measuring tool', 'time', 'container', 'slices', 'strainer', 'pan', 'bowl', 'appliance', 'cooking utensil', 'board', 'spatula', 'knife', 'colinder'], 'scores': [0.7387148141860962, 0.07632656395435333, 0.0276961512863636, 0.022419296205043793, 0.017511693760752678, 0.016102710738778114, 0.01589713804423809, 0.013840129598975182, 0.012496796436607838, 0.010766137391328812, 0.010694287717342377, 0.010454935021698475, 0.008146790787577629, 0.0073899272829294205, 0.0060728201642632484, 0.005469804629683495]}}
# ID: 0
# 	Head ID: -1
# 	Text: ROOT
# 	Type: N/A
# 	Dependent Words:
# 		Dep. ID: 1
# 			Dep. Text: cut
# 			Relation Type: root
# ID: 1
# 	Head ID: 0
# 	Text: cut
# 	Type: VB
# 	Dependent Words:
# 		Dep. ID: 3
# 			Dep. Text: stems
# 			Relation Type: obj
# 		Dep. ID: 4
# 			Dep. Text: away
# 			Relation Type: advmod
# 		Dep. ID: 7
# 			Dep. Text: strawberries
# 			Relation Type: obl
# 		Dep. ID: 9
# 			Dep. Text: discard
# 			Relation Type: conj
# 		Dep. ID: 10
# 			Dep. Text: .
# 			Relation Type: punct
# ID: 3
# 	Head ID: 1
# 	Text: stems
# 	Type: NNS
# 	Dependent Words:
# 		Dep. ID: 2
# 			Dep. Text: the
# 			Relation Type: det
# ID: 2
# 	Head ID: 3
# 	Text: the
# 	Type: DT
# 	Dependent Words:
# ID: 4
# 	Head ID: 1
# 	Text: away
# 	Type: RB
# 	Dependent Words:
# ID: 7
# 	Head ID: 1
# 	Text: strawberries
# 	Type: NNS
# 	Dependent Words:
# 		Dep. ID: 5
# 			Dep. Text: from
# 			Relation Type: case
# 		Dep. ID: 6
# 			Dep. Text: the
# 			Relation Type: det
# ID: 5
# 	Head ID: 7
# 	Text: from
# 	Type: IN
# 	Dependent Words:
# ID: 6
# 	Head ID: 7
# 	Text: the
# 	Type: DT
# 	Dependent Words:
# ID: 9
# 	Head ID: 1
# 	Text: discard
# 	Type: VB
# 	Dependent Words:
# 		Dep. ID: 8
# 			Dep. Text: and
# 			Relation Type: cc
# ID: 8
# 	Head ID: 9
# 	Text: and
# 	Type: CC
# 	Dependent Words:
# ID: 10
# 	Head ID: 1
# 	Text: .
# 	Type: .
# 	Dependent Words:
# (S (VP (VP (VB Cut) (NP (DT the) (NNS stems)) (ADVP (RB away) (PP (IN from) (NP (DT the) (NNS strawberries))))) (CC and) (VP (VB discard))) (. .))
# Cut the stems away from the strawberries and discard.
# verb phrases: {0: ('Cut', 'Cut the stems away from the strawberries'), 1: ('discard', 'discard')}
# prep phrases: {0: ('away', 'away from the strawberries', 'cut')}
# noun lists: {}
# nouns: [('the stems', 'cut'), ('the strawberries', 'cut')]
# STARTING ZERO SHOT
# END OF ZERO SHOT
# {'the stems': {'sequence': 'the stems', 'labels': ['ingredient', 'quantity', 'chunks', 'strainer', 'pan', 'time', 'appliance', 'measuring tool', 'container', 'slices', 'colinder', 'board', 'bowl', 'spatula', 'knife', 'cooking utensil'], 'scores': [0.17023678123950958, 0.12960423529148102, 0.09041047096252441, 0.07276291400194168, 0.07207875698804855, 0.06776881963014603, 0.05770406872034073, 0.0572567880153656, 0.04419846087694168, 0.0431690439581871, 0.04067009314894676, 0.03656366840004921, 0.034781474620103836, 0.030778657644987106, 0.02603348344564438, 0.025982331484556198]}, 'the strawberries': {'sequence': 'the strawberries', 'labels': ['ingredient', 'quantity', 'chunks', 'measuring tool', 'time', 'container', 'slices', 'strainer', 'pan', 'bowl', 'appliance', 'cooking utensil', 'board', 'spatula', 'knife', 'colinder'], 'scores': [0.7387148141860962, 0.07632656395435333, 0.0276961512863636, 0.022419296205043793, 0.017511693760752678, 0.016102710738778114, 0.01589713804423809, 0.013840129598975182, 0.012496796436607838, 0.010766137391328812, 0.010694287717342377, 0.010454935021698475, 0.008146790787577629, 0.0073899272829294205, 0.0060728201642632484, 0.005469804629683495]}}
# ID: 0
# 	Head ID: -1
# 	Text: ROOT
# 	Type: N/A
# 	Dependent Words:
# 		Dep. ID: 1
# 			Dep. Text: cut
# 			Relation Type: root
# ID: 1
# 	Head ID: 0
# 	Text: cut
# 	Type: VB
# 	Dependent Words:
# 		Dep. ID: 3
# 			Dep. Text: strawberries
# 			Relation Type: obj
# 		Dep. ID: 5
# 			Dep. Text: half
# 			Relation Type: obl
# 		Dep. ID: 11
# 			Dep. Text: quarters
# 			Relation Type: conj
# 		Dep. ID: 15
# 			Dep. Text: .
# 			Relation Type: punct
# ID: 3
# 	Head ID: 1
# 	Text: strawberries
# 	Type: NNS
# 	Dependent Words:
# 		Dep. ID: 2
# 			Dep. Text: the
# 			Relation Type: det
# ID: 2
# 	Head ID: 3
# 	Text: the
# 	Type: DT
# 	Dependent Words:
# ID: 5
# 	Head ID: 1
# 	Text: half
# 	Type: NN
# 	Dependent Words:
# 		Dep. ID: 4
# 			Dep. Text: in
# 			Relation Type: case
# ID: 4
# 	Head ID: 5
# 	Text: in
# 	Type: IN
# 	Dependent Words:
# ID: 11
# 	Head ID: 1
# 	Text: quarters
# 	Type: NNS
# 	Dependent Words:
# 		Dep. ID: 6
# 			Dep. Text: ,
# 			Relation Type: punct
# 		Dep. ID: 7
# 			Dep. Text: and
# 			Relation Type: cc
# 		Dep. ID: 8
# 			Dep. Text: then
# 			Relation Type: advmod
# 		Dep. ID: 9
# 			Dep. Text: in
# 			Relation Type: case
# 		Dep. ID: 10
# 			Dep. Text: either
# 			Relation Type: cc:preconj
# 		Dep. ID: 14
# 			Dep. Text: slices
# 			Relation Type: conj
# ID: 6
# 	Head ID: 11
# 	Text: ,
# 	Type: ,
# 	Dependent Words:
# ID: 7
# 	Head ID: 11
# 	Text: and
# 	Type: CC
# 	Dependent Words:
# ID: 8
# 	Head ID: 11
# 	Text: then
# 	Type: RB
# 	Dependent Words:
# ID: 9
# 	Head ID: 11
# 	Text: in
# 	Type: IN
# 	Dependent Words:
# ID: 10
# 	Head ID: 11
# 	Text: either
# 	Type: CC
# 	Dependent Words:
# ID: 14
# 	Head ID: 11
# 	Text: slices
# 	Type: NNS
# 	Dependent Words:
# 		Dep. ID: 12
# 			Dep. Text: or
# 			Relation Type: cc
# 		Dep. ID: 13
# 			Dep. Text: thick
# 			Relation Type: amod
# ID: 12
# 	Head ID: 14
# 	Text: or
# 	Type: CC
# 	Dependent Words:
# ID: 13
# 	Head ID: 14
# 	Text: thick
# 	Type: JJ
# 	Dependent Words:
# ID: 15
# 	Head ID: 1
# 	Text: .
# 	Type: .
# 	Dependent Words:
# (S (VP (VB Cut) (NP (DT the) (NNS strawberries)) (PP (PP (IN in) (NP (NN half))) (, ,) (CC and) (ADVP (RB then)) (PP (IN in) (NP (CC either) (NNS quarters) (CC or) (NP (JJ thick) (NNS slices)))))) (. .))
# Cut the strawberries in half, and then in either quarters or thick slices.
# ['quarters', 'thick slices']
# strawberries
# half
# verb phrases: {0: ('Cut', 'Cut the strawberries in half, and then in either quarters or thick slices')}
# prep phrases: {0: ('in', 'in half, and then in either quarters or thick slices', 'cut'), 1: ('then', 'then', 'cut')}
# noun lists: {0: (<ListType.OR: 1>, ['quarters', 'thick slices', 'the strawberries'], 'cut')}
# nouns: [('the strawberries', 'cut'), ('half', 'cut'), ('quarters', 'cut', 11), ('thick slices', 'cut')]
# STARTING ZERO SHOT
# END OF ZERO SHOT
# {'the strawberries': {'sequence': 'the strawberries', 'labels': ['ingredient', 'quantity', 'chunks', 'measuring tool', 'time', 'container', 'slices', 'strainer', 'pan', 'bowl', 'appliance', 'cooking utensil', 'board', 'spatula', 'knife', 'colinder'], 'scores': [0.7387148141860962, 0.07632656395435333, 0.0276961512863636, 0.022419296205043793, 0.017511693760752678, 0.016102710738778114, 0.01589713804423809, 0.013840129598975182, 0.012496796436607838, 0.010766137391328812, 0.010694287717342377, 0.010454935021698475, 0.008146790787577629, 0.0073899272829294205, 0.0060728201642632484, 0.005469804629683495]}, 'half': {'sequence': 'half', 'labels': ['chunks', 'quantity', 'pan', 'time', 'board', 'slices', 'colinder', 'measuring tool', 'appliance', 'container', 'strainer', 'bowl', 'cooking utensil', 'ingredient', 'spatula', 'knife'], 'scores': [0.2668587267398834, 0.14894349873065948, 0.0798792913556099, 0.07696487009525299, 0.07456881552934647, 0.05192774161696434, 0.04758533462882042, 0.047154102474451065, 0.031022144481539726, 0.030560588464140892, 0.02983058989048004, 0.028422022238373756, 0.02781173586845398, 0.02496454119682312, 0.01899188943207264, 0.014514094218611717]}, 'quarters': {'sequence': 'quarters', 'labels': ['quantity', 'chunks', 'colinder', 'board', 'time', 'measuring tool', 'container', 'pan', 'ingredient', 'strainer', 'bowl', 'appliance', 'cooking utensil', 'slices', 'spatula', 'knife'], 'scores': [0.46733084321022034, 0.17177347838878632, 0.05356309190392494, 0.052112605422735214, 0.04344303160905838, 0.03781857341527939, 0.03738541901111603, 0.035096026957035065, 0.02212996408343315, 0.01870567724108696, 0.01683211140334606, 0.013758307322859764, 0.012010717764496803, 0.006833771709352732, 0.006111010909080505, 0.0050953752361238]}, 'thick slices': {'sequence': 'thick slices', 'labels': ['slices', 'chunks', 'quantity', 'pan', 'knife', 'ingredient', 'measuring tool', 'board', 'time', 'appliance', 'colinder', 'cooking utensil', 'container', 'strainer', 'bowl', 'spatula'], 'scores': [0.5016658306121826, 0.2199508249759674, 0.13974407315254211, 0.020063120871782303, 0.016604572534561157, 0.015585174784064293, 0.01164223998785019, 0.010326409712433815, 0.010294176638126373, 0.009192309342324734, 0.008913488127291203, 0.007815254852175713, 0.0078076585195958614, 0.0077076382003724575, 0.007273081224411726, 0.005414203274995089]}}
# ID: 0
# 	Head ID: -1
# 	Text: ROOT
# 	Type: N/A
# 	Dependent Words:
# 		Dep. ID: 1
# 			Dep. Text: macerate
# 			Relation Type: root
# ID: 1
# 	Head ID: 0
# 	Text: macerate
# 	Type: VB
# 	Dependent Words:
# 		Dep. ID: 3
# 			Dep. Text: strawberries
# 			Relation Type: obj
# 		Dep. ID: 5
# 			Dep. Text: sugar
# 			Relation Type: obl
# 		Dep. ID: 6
# 			Dep. Text: :
# 			Relation Type: punct
# ID: 3
# 	Head ID: 1
# 	Text: strawberries
# 	Type: NNS
# 	Dependent Words:
# 		Dep. ID: 2
# 			Dep. Text: the
# 			Relation Type: det
# ID: 2
# 	Head ID: 3
# 	Text: the
# 	Type: DT
# 	Dependent Words:
# ID: 5
# 	Head ID: 1
# 	Text: sugar
# 	Type: NN
# 	Dependent Words:
# 		Dep. ID: 4
# 			Dep. Text: with
# 			Relation Type: case
# ID: 4
# 	Head ID: 5
# 	Text: with
# 	Type: IN
# 	Dependent Words:
# ID: 6
# 	Head ID: 1
# 	Text: :
# 	Type: :
# 	Dependent Words:
# (S (VP (VB Macerate) (NP (DT the) (NNS strawberries)) (PP (IN with) (NP (NN sugar)))) (: :))
# Macerate the strawberries with sugar:
# verb phrases: {0: ('Macerate', 'Macerate the strawberries with sugar')}
# prep phrases: {0: ('with', 'with sugar', 'macerate')}
# noun lists: {}
# nouns: [('the strawberries', 'macerate'), ('sugar', 'macerate')]
# STARTING ZERO SHOT
# END OF ZERO SHOT
# {'the strawberries': {'sequence': 'the strawberries', 'labels': ['ingredient', 'quantity', 'chunks', 'measuring tool', 'time', 'container', 'slices', 'strainer', 'pan', 'bowl', 'appliance', 'cooking utensil', 'board', 'spatula', 'knife', 'colinder'], 'scores': [0.7387148141860962, 0.07632656395435333, 0.0276961512863636, 0.022419296205043793, 0.017511693760752678, 0.016102710738778114, 0.01589713804423809, 0.013840129598975182, 0.012496796436607838, 0.010766137391328812, 0.010694287717342377, 0.010454935021698475, 0.008146790787577629, 0.0073899272829294205, 0.0060728201642632484, 0.005469804629683495]}, 'sugar': {'sequence': 'sugar', 'labels': ['ingredient', 'quantity', 'chunks', 'measuring tool', 'slices', 'pan', 'strainer', 'board', 'colinder', 'appliance', 'container', 'bowl', 'time', 'cooking utensil', 'spatula', 'knife'], 'scores': [0.7623720169067383, 0.043718092143535614, 0.03338371589779854, 0.018423382192850113, 0.016225572675466537, 0.016176728531718254, 0.014430459588766098, 0.0141109898686409, 0.012896318919956684, 0.01289371494203806, 0.012469308450818062, 0.012387579306960106, 0.012274385429918766, 0.008147554472088814, 0.006057579070329666, 0.004032570403069258]}}
# ID: 0
# 	Head ID: -1
# 	Text: ROOT
# 	Type: N/A
# 	Dependent Words:
# 		Dep. ID: 1
# 			Dep. Text: put
# 			Relation Type: root
# ID: 1
# 	Head ID: 0
# 	Text: put
# 	Type: VB
# 	Dependent Words:
# 		Dep. ID: 4
# 			Dep. Text: strawberries
# 			Relation Type: obj
# 		Dep. ID: 8
# 			Dep. Text: bowl
# 			Relation Type: obl
# 		Dep. ID: 10
# 			Dep. Text: sprinkle
# 			Relation Type: conj
# 		Dep. ID: 13
# 			Dep. Text: .
# 			Relation Type: punct
# ID: 4
# 	Head ID: 1
# 	Text: strawberries
# 	Type: NNS
# 	Dependent Words:
# 		Dep. ID: 2
# 			Dep. Text: the
# 			Relation Type: det
# 		Dep. ID: 3
# 			Dep. Text: cut
# 			Relation Type: compound
# ID: 2
# 	Head ID: 4
# 	Text: the
# 	Type: DT
# 	Dependent Words:
# ID: 3
# 	Head ID: 4
# 	Text: cut
# 	Type: NN
# 	Dependent Words:
# ID: 8
# 	Head ID: 1
# 	Text: bowl
# 	Type: NN
# 	Dependent Words:
# 		Dep. ID: 5
# 			Dep. Text: into
# 			Relation Type: case
# 		Dep. ID: 6
# 			Dep. Text: a
# 			Relation Type: det
# 		Dep. ID: 7
# 			Dep. Text: large
# 			Relation Type: amod
# ID: 5
# 	Head ID: 8
# 	Text: into
# 	Type: IN
# 	Dependent Words:
# ID: 6
# 	Head ID: 8
# 	Text: a
# 	Type: DT
# 	Dependent Words:
# ID: 7
# 	Head ID: 8
# 	Text: large
# 	Type: JJ
# 	Dependent Words:
# ID: 10
# 	Head ID: 1
# 	Text: sprinkle
# 	Type: VB
# 	Dependent Words:
# 		Dep. ID: 9
# 			Dep. Text: and
# 			Relation Type: cc
# 		Dep. ID: 12
# 			Dep. Text: sugar
# 			Relation Type: obl
# ID: 9
# 	Head ID: 10
# 	Text: and
# 	Type: CC
# 	Dependent Words:
# ID: 12
# 	Head ID: 10
# 	Text: sugar
# 	Type: NN
# 	Dependent Words:
# 		Dep. ID: 11
# 			Dep. Text: with
# 			Relation Type: case
# ID: 11
# 	Head ID: 12
# 	Text: with
# 	Type: IN
# 	Dependent Words:
# ID: 13
# 	Head ID: 1
# 	Text: .
# 	Type: .
# 	Dependent Words:
# (S (VP (VP (VB Put) (NP (DT the) (NN cut) (NNS strawberries)) (PP (IN into) (NP (DT a) (JJ large) (NN bowl)))) (CC and) (VP (VB sprinkle) (PP (IN with) (NP (NN sugar))))) (. .))
# Put the cut strawberries into a large bowl and sprinkle with sugar.
# verb phrases: {0: ('Put', 'Put the cut strawberries into a large bowl'), 1: ('sprinkle', 'sprinkle with sugar')}
# prep phrases: {0: ('into', 'into a large bowl', 'put'), 1: ('with', 'with sugar', 'sprinkle')}
# noun lists: {}
# nouns: [('the cut strawberries', 'put'), ('a large bowl', 'put'), ('sugar', 'sprinkle')]
# STARTING ZERO SHOT
# END OF ZERO SHOT
# {'the cut strawberries': {'sequence': 'the cut strawberries', 'labels': ['slices', 'ingredient', 'chunks', 'quantity', 'time', 'measuring tool', 'strainer', 'container', 'knife', 'pan', 'bowl', 'appliance', 'cooking utensil', 'spatula', 'colinder', 'board'], 'scores': [0.3562009930610657, 0.29097500443458557, 0.18172527849674225, 0.05121174827218056, 0.017001552507281303, 0.014152717776596546, 0.013224640861153603, 0.010676397010684013, 0.010578389279544353, 0.009775340557098389, 0.009468338452279568, 0.009150144644081593, 0.008607670664787292, 0.006142482161521912, 0.006038636434823275, 0.005070600192993879]}, 'a large bowl': {'sequence': 'a large bowl', 'labels': ['bowl', 'quantity', 'container', 'appliance', 'cooking utensil', 'colinder', 'ingredient', 'chunks', 'board', 'pan', 'time', 'strainer', 'measuring tool', 'spatula', 'slices', 'knife'], 'scores': [0.4903443455696106, 0.16607117652893066, 0.1607927531003952, 0.07729736715555191, 0.039705343544483185, 0.019355731084942818, 0.008037013933062553, 0.00733695225790143, 0.007155001163482666, 0.004699291195720434, 0.004641656298190355, 0.004578904714435339, 0.003235605778172612, 0.002873142482712865, 0.0023387118708342314, 0.0015369728207588196]}, 'sugar': {'sequence': 'sugar', 'labels': ['ingredient', 'quantity', 'chunks', 'measuring tool', 'slices', 'pan', 'strainer', 'board', 'colinder', 'appliance', 'container', 'bowl', 'time', 'cooking utensil', 'spatula', 'knife'], 'scores': [0.7623720169067383, 0.043718092143535614, 0.03338371589779854, 0.018423382192850113, 0.016225572675466537, 0.016176728531718254, 0.014430459588766098, 0.0141109898686409, 0.012896318919956684, 0.01289371494203806, 0.012469308450818062, 0.012387579306960106, 0.012274385429918766, 0.008147554472088814, 0.006057579070329666, 0.004032570403069258]}}
# ID: 0
# 	Head ID: -1
# 	Text: ROOT
# 	Type: N/A
# 	Dependent Words:
# 		Dep. ID: 1
# 			Dep. Text: start
# 			Relation Type: root
# ID: 1
# 	Head ID: 0
# 	Text: start
# 	Type: VB
# 	Dependent Words:
# 		Dep. ID: 5
# 			Dep. Text: cup
# 			Relation Type: obl
# 		Dep. ID: 10
# 			Dep. Text: add
# 			Relation Type: conj
# 		Dep. ID: 24
# 			Dep. Text: .
# 			Relation Type: punct
# ID: 5
# 	Head ID: 1
# 	Text: cup
# 	Type: NN
# 	Dependent Words:
# 		Dep. ID: 2
# 			Dep. Text: with
# 			Relation Type: case
# 		Dep. ID: 3
# 			Dep. Text: 1
# 			Relation Type: nummod
# 		Dep. ID: 4
# 			Dep. Text: /4
# 			Relation Type: nummod
# 		Dep. ID: 7
# 			Dep. Text: sugar
# 			Relation Type: nmod
# ID: 2
# 	Head ID: 5
# 	Text: with
# 	Type: IN
# 	Dependent Words:
# ID: 3
# 	Head ID: 5
# 	Text: 1
# 	Type: CD
# 	Dependent Words:
# ID: 4
# 	Head ID: 5
# 	Text: /4
# 	Type: CD
# 	Dependent Words:
# ID: 7
# 	Head ID: 5
# 	Text: sugar
# 	Type: NN
# 	Dependent Words:
# 		Dep. ID: 6
# 			Dep. Text: of
# 			Relation Type: case
# ID: 6
# 	Head ID: 7
# 	Text: of
# 	Type: IN
# 	Dependent Words:
# ID: 10
# 	Head ID: 1
# 	Text: add
# 	Type: VB
# 	Dependent Words:
# 		Dep. ID: 8
# 			Dep. Text: and
# 			Relation Type: cc
# 		Dep. ID: 9
# 			Dep. Text: then
# 			Relation Type: advmod
# 		Dep. ID: 11
# 			Dep. Text: up
# 			Relation Type: compound:prt
# 		Dep. ID: 16
# 			Dep. Text: cup
# 			Relation Type: obl
# 		Dep. ID: 20
# 			Dep. Text: sweet
# 			Relation Type: obl
# ID: 8
# 	Head ID: 10
# 	Text: and
# 	Type: CC
# 	Dependent Words:
# ID: 9
# 	Head ID: 10
# 	Text: then
# 	Type: RB
# 	Dependent Words:
# ID: 11
# 	Head ID: 10
# 	Text: up
# 	Type: RP
# 	Dependent Words:
# ID: 16
# 	Head ID: 10
# 	Text: cup
# 	Type: NN
# 	Dependent Words:
# 		Dep. ID: 12
# 			Dep. Text: to
# 			Relation Type: case
# 		Dep. ID: 13
# 			Dep. Text: another
# 			Relation Type: det
# 		Dep. ID: 15
# 			Dep. Text: /4
# 			Relation Type: nummod
# ID: 12
# 	Head ID: 16
# 	Text: to
# 	Type: IN
# 	Dependent Words:
# ID: 13
# 	Head ID: 16
# 	Text: another
# 	Type: DT
# 	Dependent Words:
# ID: 15
# 	Head ID: 16
# 	Text: /4
# 	Type: CD
# 	Dependent Words:
# 		Dep. ID: 14
# 			Dep. Text: 1
# 			Relation Type: compound
# ID: 14
# 	Head ID: 15
# 	Text: 1
# 	Type: CD
# 	Dependent Words:
# ID: 20
# 	Head ID: 10
# 	Text: sweet
# 	Type: JJ
# 	Dependent Words:
# 		Dep. ID: 17
# 			Dep. Text: depending
# 			Relation Type: case
# 		Dep. ID: 19
# 			Dep. Text: how
# 			Relation Type: mark
# 		Dep. ID: 23
# 			Dep. Text: are
# 			Relation Type: cop
# ID: 17
# 	Head ID: 20
# 	Text: depending
# 	Type: VBG
# 	Dependent Words:
# 		Dep. ID: 18
# 			Dep. Text: on
# 			Relation Type: fixed
# ID: 18
# 	Head ID: 17
# 	Text: on
# 	Type: IN
# 	Dependent Words:
# ID: 19
# 	Head ID: 20
# 	Text: how
# 	Type: WRB
# 	Dependent Words:
# ID: 22
# 	Head ID: 23
# 	Text: strawberries
# 	Type: NNS
# 	Dependent Words:
# 		Dep. ID: 21
# 			Dep. Text: your
# 			Relation Type: nmod:poss
# ID: 21
# 	Head ID: 22
# 	Text: your
# 	Type: PRP$
# 	Dependent Words:
# ID: 23
# 	Head ID: 20
# 	Text: are
# 	Type: VBP
# 	Dependent Words:
# 		Dep. ID: 22
# 			Dep. Text: strawberries
# 			Relation Type: nsubj
# ID: 24
# 	Head ID: 1
# 	Text: .
# 	Type: .
# 	Dependent Words:
# (S (VP (VP (VB Start) (PP (IN with) (NP (NP (QP (CD 1) (CD /4)) (NN cup)) (PP (IN of) (NP (NN sugar)))))) (CC and) (ADVP (RB then)) (VP (VB add) (PRT (RP up)) (PP (IN to) (NP (DT another) (QP (CD 1) (CD /4)) (NN cup))) (S (PP (VBG depending) (PP (IN on) (SBAR (WHADJP (WRB how) (JJ sweet)) (S (NP (PRP$ your) (NNS strawberries)) (VP (VBP are))))))))) (. .))
# Start with 1/4 cup of sugar and then add up to another 1/4 cup depending on how sweet your strawberries are.
# 11
# 8
# 9
# 11
# 16
# 20
# verb phrases: {0: ('Start', 'Start with 1 /4 cup of sugar'), 1: ('add', 'add up to another 1 /4 cup depending on how sweet your strawberries are')}
# prep phrases: {0: ('with', 'with 1 /4 cup of sugar', 'start'), 1: ('then', 'then', 'add'), 2: ('to', 'to another 1 /4 cup', 'add'), 3: ('on', 'depending on how sweet your strawberries are', 'add')}
# noun lists: {}
# nouns: [('1 /4 cup of sugar', 'start'), ('another 1 /4 cup', 'add'), ('your strawberries', 'are')]
# STARTING ZERO SHOT
# END OF ZERO SHOT
# {'1 /4 cup of sugar': {'sequence': '1 /4 cup of sugar', 'labels': ['ingredient', 'quantity', 'measuring tool', 'container', 'colinder', 'pan', 'bowl', 'strainer', 'appliance', 'chunks', 'board', 'cooking utensil', 'time', 'spatula', 'slices', 'knife'], 'scores': [0.5052347183227539, 0.37363147735595703, 0.03799983859062195, 0.022157873958349228, 0.011483879759907722, 0.009359273128211498, 0.00764906732365489, 0.005847632884979248, 0.004947553854435682, 0.0046166181564331055, 0.0045244814828038216, 0.003994966857135296, 0.00310851214453578, 0.0024058795534074306, 0.0017195885302498937, 0.0013186156284064054]}, 'another 1 /4 cup': {'sequence': 'another 1 /4 cup', 'labels': ['quantity', 'container', 'ingredient', 'measuring tool', 'chunks', 'colinder', 'time', 'strainer', 'cooking utensil', 'appliance', 'bowl', 'pan', 'spatula', 'slices', 'board', 'knife'], 'scores': [0.4777281582355499, 0.2665955424308777, 0.06409134715795517, 0.05257886275649071, 0.028880376368761063, 0.023882463574409485, 0.016436045989394188, 0.014675886370241642, 0.014536235481500626, 0.010576892644166946, 0.010219802148640156, 0.007707030978053808, 0.0036756687331944704, 0.003471726318821311, 0.003087101737037301, 0.0018568435916677117]}, 'your strawberries': {'sequence': 'your strawberries', 'labels': ['ingredient', 'quantity', 'measuring tool', 'container', 'chunks', 'time', 'pan', 'appliance', 'slices', 'strainer', 'bowl', 'board', 'cooking utensil', 'spatula', 'knife', 'colinder'], 'scores': [0.68111652135849, 0.09566860646009445, 0.05325959250330925, 0.02529670111835003, 0.023906951770186424, 0.017850641161203384, 0.015233861282467842, 0.012848141603171825, 0.012744619511067867, 0.012635588645935059, 0.011573605239391327, 0.010530644096434116, 0.010076184757053852, 0.006777879782021046, 0.005735741928219795, 0.004744743928313255]}}
# ID: 0
# 	Head ID: -1
# 	Text: ROOT
# 	Type: N/A
# 	Dependent Words:
# 		Dep. ID: 2
# 			Dep. Text: stir
# 			Relation Type: root
# ID: 2
# 	Head ID: 0
# 	Text: stir
# 	Type: VB
# 	Dependent Words:
# 		Dep. ID: 1
# 			Dep. Text: gently
# 			Relation Type: advmod
# 		Dep. ID: 4
# 			Dep. Text: strawberries
# 			Relation Type: obj
# 		Dep. ID: 9
# 			Dep. Text: coated
# 			Relation Type: advcl
# 		Dep. ID: 13
# 			Dep. Text: .
# 			Relation Type: punct
# ID: 1
# 	Head ID: 2
# 	Text: gently
# 	Type: RB
# 	Dependent Words:
# ID: 4
# 	Head ID: 2
# 	Text: strawberries
# 	Type: NNS
# 	Dependent Words:
# 		Dep. ID: 3
# 			Dep. Text: the
# 			Relation Type: det
# ID: 3
# 	Head ID: 4
# 	Text: the
# 	Type: DT
# 	Dependent Words:
# ID: 9
# 	Head ID: 2
# 	Text: coated
# 	Type: VBN
# 	Dependent Words:
# 		Dep. ID: 5
# 			Dep. Text: until
# 			Relation Type: mark
# 		Dep. ID: 6
# 			Dep. Text: they
# 			Relation Type: nsubj:pass
# 		Dep. ID: 7
# 			Dep. Text: are
# 			Relation Type: aux:pass
# 		Dep. ID: 8
# 			Dep. Text: all
# 			Relation Type: advmod
# 		Dep. ID: 12
# 			Dep. Text: sugar
# 			Relation Type: obl
# ID: 5
# 	Head ID: 9
# 	Text: until
# 	Type: IN
# 	Dependent Words:
# ID: 6
# 	Head ID: 9
# 	Text: they
# 	Type: PRP
# 	Dependent Words:
# ID: 7
# 	Head ID: 9
# 	Text: are
# 	Type: VBP
# 	Dependent Words:
# ID: 8
# 	Head ID: 9
# 	Text: all
# 	Type: RB
# 	Dependent Words:
# ID: 12
# 	Head ID: 9
# 	Text: sugar
# 	Type: NN
# 	Dependent Words:
# 		Dep. ID: 10
# 			Dep. Text: with
# 			Relation Type: case
# 		Dep. ID: 11
# 			Dep. Text: some
# 			Relation Type: det
# ID: 10
# 	Head ID: 12
# 	Text: with
# 	Type: IN
# 	Dependent Words:
# ID: 11
# 	Head ID: 12
# 	Text: some
# 	Type: DT
# 	Dependent Words:
# ID: 13
# 	Head ID: 2
# 	Text: .
# 	Type: .
# 	Dependent Words:
# (S (ADVP (RB Gently)) (VP (VB stir) (NP (DT the) (NNS strawberries)) (SBAR (IN until) (S (NP (PRP they)) (VP (VBP are) (RB all) (VP (VBN coated) (PP (IN with) (NP (DT some) (NN sugar)))))))) (. .))
# Gently stir the strawberries until they are all coated with some sugar.
# verb phrases: {0: ('stir', 'stir the strawberries until they are all coated with some sugar')}
# prep phrases: {0: ('Gently', 'Gently', 'stir'), 1: ('until', 'until they are all coated with some sugar', 'coated')}
# noun lists: {}
# nouns: [('the strawberries', 'stir'), ('they', 'coated'), ('some sugar', 'coated')]
# STARTING ZERO SHOT
# END OF ZERO SHOT
# {'the strawberries': {'sequence': 'the strawberries', 'labels': ['ingredient', 'quantity', 'chunks', 'measuring tool', 'time', 'container', 'slices', 'strainer', 'pan', 'bowl', 'appliance', 'cooking utensil', 'board', 'spatula', 'knife', 'colinder'], 'scores': [0.7387148141860962, 0.07632656395435333, 0.0276961512863636, 0.022419296205043793, 0.017511693760752678, 0.016102710738778114, 0.01589713804423809, 0.013840129598975182, 0.012496796436607838, 0.010766137391328812, 0.010694287717342377, 0.010454935021698475, 0.008146790787577629, 0.0073899272829294205, 0.0060728201642632484, 0.005469804629683495]}, 'they': {'sequence': 'they', 'labels': ['quantity', 'pan', 'board', 'time', 'measuring tool', 'chunks', 'appliance', 'cooking utensil', 'bowl', 'strainer', 'slices', 'container', 'ingredient', 'colinder', 'spatula', 'knife'], 'scores': [0.13549159467220306, 0.09025656431913376, 0.08467750251293182, 0.08379921317100525, 0.0701911449432373, 0.06848325580358505, 0.06601984053850174, 0.05800556018948555, 0.051866091787815094, 0.05004006251692772, 0.0499829538166523, 0.04747637361288071, 0.04221378639340401, 0.04164828732609749, 0.03129982203245163, 0.02854795940220356]}, 'some sugar': {'sequence': 'some sugar', 'labels': ['ingredient', 'quantity', 'chunks', 'measuring tool', 'pan', 'bowl', 'board', 'colinder', 'container', 'strainer', 'slices', 'appliance', 'time', 'cooking utensil', 'spatula', 'knife'], 'scores': [0.7809864282608032, 0.06200500577688217, 0.02694668062031269, 0.021417880430817604, 0.014420753344893456, 0.013402319513261318, 0.011754384264349937, 0.011169086210429668, 0.010785632766783237, 0.009707055054605007, 0.008052417077124119, 0.008025492541491985, 0.006982350721955299, 0.006300756707787514, 0.00514086801558733, 0.0029028593562543392]}}
# ID: 0
# 	Head ID: -1
# 	Text: ROOT
# 	Type: N/A
# 	Dependent Words:
# 		Dep. ID: 1
# 			Dep. Text: let
# 			Relation Type: root
# ID: 1
# 	Head ID: 0
# 	Text: let
# 	Type: VB
# 	Dependent Words:
# 		Dep. ID: 2
# 			Dep. Text: sit
# 			Relation Type: xcomp
# 		Dep. ID: 21
# 			Dep. Text: .
# 			Relation Type: punct
# ID: 2
# 	Head ID: 1
# 	Text: sit
# 	Type: VB
# 	Dependent Words:
# 		Dep. ID: 5
# 			Dep. Text: temperature
# 			Relation Type: obl
# 		Dep. ID: 9
# 			Dep. Text: minutes
# 			Relation Type: obl
# 		Dep. ID: 14
# 			Dep. Text: soften
# 			Relation Type: advcl
# ID: 5
# 	Head ID: 2
# 	Text: temperature
# 	Type: NN
# 	Dependent Words:
# 		Dep. ID: 3
# 			Dep. Text: at
# 			Relation Type: case
# 		Dep. ID: 4
# 			Dep. Text: room
# 			Relation Type: compound
# ID: 3
# 	Head ID: 5
# 	Text: at
# 	Type: IN
# 	Dependent Words:
# ID: 4
# 	Head ID: 5
# 	Text: room
# 	Type: NN
# 	Dependent Words:
# ID: 9
# 	Head ID: 2
# 	Text: minutes
# 	Type: NNS
# 	Dependent Words:
# 		Dep. ID: 6
# 			Dep. Text: for
# 			Relation Type: case
# 		Dep. ID: 8
# 			Dep. Text: 20
# 			Relation Type: nummod
# ID: 6
# 	Head ID: 9
# 	Text: for
# 	Type: IN
# 	Dependent Words:
# ID: 8
# 	Head ID: 9
# 	Text: 20
# 	Type: CD
# 	Dependent Words:
# 		Dep. ID: 7
# 			Dep. Text: about
# 			Relation Type: advmod
# ID: 7
# 	Head ID: 8
# 	Text: about
# 	Type: RB
# 	Dependent Words:
# ID: 14
# 	Head ID: 2
# 	Text: soften
# 	Type: VBP
# 	Dependent Words:
# 		Dep. ID: 10
# 			Dep. Text: ,
# 			Relation Type: punct
# 		Dep. ID: 11
# 			Dep. Text: until
# 			Relation Type: mark
# 		Dep. ID: 13
# 			Dep. Text: berries
# 			Relation Type: nsubj
# 		Dep. ID: 16
# 			Dep. Text: begin
# 			Relation Type: conj
# ID: 10
# 	Head ID: 14
# 	Text: ,
# 	Type: ,
# 	Dependent Words:
# ID: 11
# 	Head ID: 14
# 	Text: until
# 	Type: IN
# 	Dependent Words:
# ID: 13
# 	Head ID: 14
# 	Text: berries
# 	Type: NNS
# 	Dependent Words:
# 		Dep. ID: 12
# 			Dep. Text: the
# 			Relation Type: det
# ID: 12
# 	Head ID: 13
# 	Text: the
# 	Type: DT
# 	Dependent Words:
# ID: 16
# 	Head ID: 14
# 	Text: begin
# 	Type: VB
# 	Dependent Words:
# 		Dep. ID: 15
# 			Dep. Text: and
# 			Relation Type: cc
# 		Dep. ID: 18
# 			Dep. Text: release
# 			Relation Type: xcomp
# ID: 15
# 	Head ID: 16
# 	Text: and
# 	Type: CC
# 	Dependent Words:
# ID: 18
# 	Head ID: 16
# 	Text: release
# 	Type: VB
# 	Dependent Words:
# 		Dep. ID: 17
# 			Dep. Text: to
# 			Relation Type: mark
# 		Dep. ID: 20
# 			Dep. Text: juices
# 			Relation Type: obj
# ID: 17
# 	Head ID: 18
# 	Text: to
# 	Type: TO
# 	Dependent Words:
# ID: 20
# 	Head ID: 18
# 	Text: juices
# 	Type: NNS
# 	Dependent Words:
# 		Dep. ID: 19
# 			Dep. Text: their
# 			Relation Type: nmod:poss
# ID: 19
# 	Head ID: 20
# 	Text: their
# 	Type: PRP$
# 	Dependent Words:
# ID: 21
# 	Head ID: 1
# 	Text: .
# 	Type: .
# 	Dependent Words:
# (S (VP (VB Let) (S (VP (VB sit) (PP (IN at) (NP (NN room) (NN temperature))) (PP (IN for) (NP (QP (RB about) (CD 20)) (NNS minutes))))) (, ,) (SBAR (IN until) (S (NP (DT the) (NNS berries)) (VP (VP (VBP soften)) (CC and) (VP (VB begin) (S (VP (TO to) (VP (VB release) (NP (PRP$ their) (NNS juices)))))))))) (. .))
# Let sit at room temperature for about 20 minutes, until the berries soften and begin to release their juices.
# verb phrases: {0: ('sit', 'sit at room temperature for about 20 minutes'), 1: ('begin', 'begin to release their juices'), 2: ('release', 'release their juices')}
# prep phrases: {0: ('at', 'at room temperature', 'sit'), 1: ('for', 'for about 20 minutes', 'sit'), 2: ('until', 'until the berries soften and begin to release their juices', 'soften')}
# noun lists: {}
# nouns: [('room temperature', 'sit'), ('about 20 minutes', 'sit'), ('the berries', 'soften'), ('their juices', 'release')]
# STARTING ZERO SHOT
# END OF ZERO SHOT
# {'room temperature': {'sequence': 'room temperature', 'labels': ['measuring tool', 'time', 'board', 'quantity', 'pan', 'chunks', 'container', 'bowl', 'colinder', 'strainer', 'cooking utensil', 'appliance', 'ingredient', 'spatula', 'slices', 'knife'], 'scores': [0.14914411306381226, 0.1423630267381668, 0.0861055999994278, 0.08374255895614624, 0.08353273570537567, 0.07830191403627396, 0.06637854874134064, 0.04516693949699402, 0.04413679614663124, 0.04228771850466728, 0.03852628171443939, 0.035919345915317535, 0.03550191596150398, 0.027710311114788055, 0.026740431785583496, 0.014441728591918945]}, 'about 20 minutes': {'sequence': 'about 20 minutes', 'labels': ['time', 'chunks', 'quantity', 'pan', 'board', 'measuring tool', 'strainer', 'cooking utensil', 'container', 'appliance', 'bowl', 'slices', 'colinder', 'ingredient', 'spatula', 'knife'], 'scores': [0.669103741645813, 0.08645752817392349, 0.048493411391973495, 0.03391086682677269, 0.0245964378118515, 0.01941978931427002, 0.01670902781188488, 0.014193971641361713, 0.01372713316231966, 0.012720970436930656, 0.012713702395558357, 0.012347850017249584, 0.012032675556838512, 0.008913012221455574, 0.008482897654175758, 0.006177012342959642]}, 'the berries': {'sequence': 'the berries', 'labels': ['ingredient', 'quantity', 'chunks', 'strainer', 'measuring tool', 'time', 'pan', 'container', 'slices', 'appliance', 'bowl', 'board', 'cooking utensil', 'spatula', 'colinder', 'knife'], 'scores': [0.6260862350463867, 0.08947088569402695, 0.04169181361794472, 0.030145786702632904, 0.029260868206620216, 0.025378335267305374, 0.024315379559993744, 0.020390499383211136, 0.018499141559004784, 0.017169024795293808, 0.017141319811344147, 0.013891010545194149, 0.013008175417780876, 0.012486890889704227, 0.012045418843626976, 0.00901926588267088]}, 'their juices': {'sequence': 'their juices', 'labels': ['ingredient', 'quantity', 'pan', 'board', 'chunks', 'cooking utensil', 'strainer', 'container', 'measuring tool', 'appliance', 'bowl', 'slices', 'colinder', 'time', 'spatula', 'knife'], 'scores': [0.5271311402320862, 0.10429416596889496, 0.06208570674061775, 0.046032316982746124, 0.03828301280736923, 0.03603936359286308, 0.028082536533474922, 0.023866314440965652, 0.02374965324997902, 0.023478738963603973, 0.022431248798966408, 0.016711745411157608, 0.016692524775862694, 0.01477962825447321, 0.009549339301884174, 0.006792640779167414]}}
# ID: 0
# 	Head ID: -1
# 	Text: ROOT
# 	Type: N/A
# 	Dependent Words:
# 		Dep. ID: 1
# 			Dep. Text: mash
# 			Relation Type: root
# ID: 1
# 	Head ID: 0
# 	Text: mash
# 	Type: VB
# 	Dependent Words:
# 		Dep. ID: 2
# 			Dep. Text: some
# 			Relation Type: obj
# 		Dep. ID: 6
# 			Dep. Text: :
# 			Relation Type: punct
# ID: 2
# 	Head ID: 1
# 	Text: some
# 	Type: DT
# 	Dependent Words:
# 		Dep. ID: 5
# 			Dep. Text: strawberries
# 			Relation Type: nmod
# ID: 5
# 	Head ID: 2
# 	Text: strawberries
# 	Type: NNS
# 	Dependent Words:
# 		Dep. ID: 3
# 			Dep. Text: of
# 			Relation Type: case
# 		Dep. ID: 4
# 			Dep. Text: the
# 			Relation Type: det
# ID: 3
# 	Head ID: 5
# 	Text: of
# 	Type: IN
# 	Dependent Words:
# ID: 4
# 	Head ID: 5
# 	Text: the
# 	Type: DT
# 	Dependent Words:
# ID: 6
# 	Head ID: 1
# 	Text: :
# 	Type: :
# 	Dependent Words:
# (S (VP (VB Mash) (NP (NP (DT some)) (PP (IN of) (NP (DT the) (NNS strawberries))))) (: :))
# Mash some of the strawberries:
# verb phrases: {0: ('Mash', 'Mash some of the strawberries')}
# prep phrases: {0: ('of', 'of the strawberries', 'mash')}
# noun lists: {}
# nouns: [('some of the strawberries', 'mash')]
# STARTING ZERO SHOT
# END OF ZERO SHOT
# {'some of the strawberries': {'sequence': 'some of the strawberries', 'labels': ['ingredient', 'quantity', 'chunks', 'slices', 'strainer', 'container', 'pan', 'measuring tool', 'bowl', 'time', 'appliance', 'cooking utensil', 'spatula', 'board', 'colinder', 'knife'], 'scores': [0.6282117962837219, 0.08083287626504898, 0.0768372118473053, 0.03339594602584839, 0.02637399546802044, 0.024640344083309174, 0.021880388259887695, 0.02001299522817135, 0.01917828433215618, 0.017667459324002266, 0.012399142608046532, 0.010523902252316475, 0.008523287251591682, 0.007371718529611826, 0.0061755371280014515, 0.005975147243589163]}}
# ID: 0
# 	Head ID: -1
# 	Text: ROOT
# 	Type: N/A
# 	Dependent Words:
# 		Dep. ID: 7
# 			Dep. Text: mash
# 			Relation Type: root
# ID: 3
# 	Head ID: 7
# 	Text: minutes
# 	Type: NNS
# 	Dependent Words:
# 		Dep. ID: 1
# 			Dep. Text: after
# 			Relation Type: case
# 		Dep. ID: 2
# 			Dep. Text: 20
# 			Relation Type: nummod
# 		Dep. ID: 5
# 			Dep. Text: so
# 			Relation Type: conj
# 		Dep. ID: 6
# 			Dep. Text: ,
# 			Relation Type: punct
# ID: 1
# 	Head ID: 3
# 	Text: after
# 	Type: IN
# 	Dependent Words:
# ID: 2
# 	Head ID: 3
# 	Text: 20
# 	Type: CD
# 	Dependent Words:
# ID: 7
# 	Head ID: 0
# 	Text: mash
# 	Type: VB
# 	Dependent Words:
# 		Dep. ID: 3
# 			Dep. Text: minutes
# 			Relation Type: obl
# 		Dep. ID: 10
# 			Dep. Text: quarter
# 			Relation Type: obj
# 		Dep. ID: 16
# 			Dep. Text: bowl
# 			Relation Type: obl
# 		Dep. ID: 20
# 			Dep. Text: masher
# 			Relation Type: obl
# 		Dep. ID: 25
# 			Dep. Text: .
# 			Relation Type: punct
# ID: 5
# 	Head ID: 3
# 	Text: so
# 	Type: RB
# 	Dependent Words:
# 		Dep. ID: 4
# 			Dep. Text: or
# 			Relation Type: cc
# ID: 4
# 	Head ID: 5
# 	Text: or
# 	Type: CC
# 	Dependent Words:
# ID: 6
# 	Head ID: 3
# 	Text: ,
# 	Type: ,
# 	Dependent Words:
# ID: 10
# 	Head ID: 7
# 	Text: quarter
# 	Type: NN
# 	Dependent Words:
# 		Dep. ID: 8
# 			Dep. Text: about
# 			Relation Type: advmod
# 		Dep. ID: 9
# 			Dep. Text: a
# 			Relation Type: det
# 		Dep. ID: 13
# 			Dep. Text: berries
# 			Relation Type: nmod
# ID: 8
# 	Head ID: 10
# 	Text: about
# 	Type: RB
# 	Dependent Words:
# ID: 9
# 	Head ID: 10
# 	Text: a
# 	Type: DT
# 	Dependent Words:
# ID: 13
# 	Head ID: 10
# 	Text: berries
# 	Type: NNS
# 	Dependent Words:
# 		Dep. ID: 11
# 			Dep. Text: of
# 			Relation Type: case
# 		Dep. ID: 12
# 			Dep. Text: the
# 			Relation Type: det
# ID: 11
# 	Head ID: 13
# 	Text: of
# 	Type: IN
# 	Dependent Words:
# ID: 12
# 	Head ID: 13
# 	Text: the
# 	Type: DT
# 	Dependent Words:
# ID: 16
# 	Head ID: 7
# 	Text: bowl
# 	Type: NN
# 	Dependent Words:
# 		Dep. ID: 14
# 			Dep. Text: in
# 			Relation Type: case
# 		Dep. ID: 15
# 			Dep. Text: the
# 			Relation Type: det
# ID: 14
# 	Head ID: 16
# 	Text: in
# 	Type: IN
# 	Dependent Words:
# ID: 15
# 	Head ID: 16
# 	Text: the
# 	Type: DT
# 	Dependent Words:
# ID: 20
# 	Head ID: 7
# 	Text: masher
# 	Type: NN
# 	Dependent Words:
# 		Dep. ID: 17
# 			Dep. Text: with
# 			Relation Type: case
# 		Dep. ID: 18
# 			Dep. Text: a
# 			Relation Type: det
# 		Dep. ID: 19
# 			Dep. Text: potato
# 			Relation Type: compound
# 		Dep. ID: 22
# 			Dep. Text: stir
# 			Relation Type: conj
# ID: 17
# 	Head ID: 20
# 	Text: with
# 	Type: IN
# 	Dependent Words:
# ID: 18
# 	Head ID: 20
# 	Text: a
# 	Type: DT
# 	Dependent Words:
# ID: 19
# 	Head ID: 20
# 	Text: potato
# 	Type: NN
# 	Dependent Words:
# ID: 22
# 	Head ID: 20
# 	Text: stir
# 	Type: NN
# 	Dependent Words:
# 		Dep. ID: 21
# 			Dep. Text: and
# 			Relation Type: cc
# 		Dep. ID: 24
# 			Dep. Text: mix
# 			Relation Type: acl
# ID: 21
# 	Head ID: 22
# 	Text: and
# 	Type: CC
# 	Dependent Words:
# ID: 24
# 	Head ID: 22
# 	Text: mix
# 	Type: VB
# 	Dependent Words:
# 		Dep. ID: 23
# 			Dep. Text: to
# 			Relation Type: mark
# ID: 23
# 	Head ID: 24
# 	Text: to
# 	Type: TO
# 	Dependent Words:
# ID: 25
# 	Head ID: 7
# 	Text: .
# 	Type: .
# 	Dependent Words:
# (S (PP (IN After) (NP (CD 20) (NNS minutes) (QP (CC or) (RB so)))) (, ,) (VP (VB mash) (NP (NP (QP (RB about) (DT a) (NN quarter))) (PP (IN of) (NP (DT the) (NNS berries)))) (PP (IN in) (NP (DT the) (NN bowl))) (PP (IN with) (NP (NP (NP (DT a) (NN potato) (NN masher)) (CC and) (NP (NN stir))) (VP (TO to) (VP (VB mix)))))) (. .))
# After 20 minutes or so, mash about a quarter of the berries in the bowl with a potato masher and stir to mix.
# ['a potato masher', 'stir']
# minutes
# quarter
# bowl
# verb phrases: {0: ('mash', 'mash about a quarter of the berries in the bowl with a potato masher and stir to mix'), 1: ('mix', 'mix')}
# prep phrases: {0: ('After', 'After 20 minutes or so', 'mash'), 1: ('of', 'of the berries', 'mash'), 2: ('in', 'in the bowl', 'mash'), 3: ('with', 'with a potato masher and stir to mix', 'mash')}
# noun lists: {0: (<ListType.AND: 0>, ['a potato masher', 'stir'], 'mash')}
# nouns: [('20 minutes or so', 'mash'), ('about a quarter of the berries', 'mash'), ('the bowl', 'mash'), ('a potato masher', 'mash'), ('stir', 'mash')]
# STARTING ZERO SHOT
# END OF ZERO SHOT
# {'20 minutes or so': {'sequence': '20 minutes or so', 'labels': ['time', 'chunks', 'quantity', 'pan', 'board', 'measuring tool', 'strainer', 'colinder', 'appliance', 'slices', 'cooking utensil', 'container', 'bowl', 'ingredient', 'spatula', 'knife'], 'scores': [0.6338634490966797, 0.11033616960048676, 0.0725528821349144, 0.02656947448849678, 0.02548648789525032, 0.023373225703835487, 0.015650153160095215, 0.013369294814765453, 0.012666673399508, 0.012227444909512997, 0.011926720850169659, 0.011792697012424469, 0.011055588722229004, 0.007252359297126532, 0.007062384858727455, 0.004814888350665569]}, 'about a quarter of the berries': {'sequence': 'about a quarter of the berries', 'labels': ['quantity', 'chunks', 'ingredient', 'measuring tool', 'strainer', 'pan', 'time', 'slices', 'container', 'colinder', 'bowl', 'appliance', 'spatula', 'cooking utensil', 'board', 'knife'], 'scores': [0.3129779100418091, 0.1348501741886139, 0.1280505657196045, 0.08865110576152802, 0.06359442323446274, 0.049189284443855286, 0.03479180857539177, 0.03299352526664734, 0.03201105073094368, 0.02763800136744976, 0.02323986031115055, 0.016996046528220177, 0.01683635450899601, 0.014626615680754185, 0.013756879605352879, 0.009796414524316788]}, 'the bowl': {'sequence': 'the bowl', 'labels': ['bowl', 'container', 'appliance', 'cooking utensil', 'colinder', 'quantity', 'ingredient', 'measuring tool', 'board', 'chunks', 'strainer', 'time', 'pan', 'spatula', 'slices', 'knife'], 'scores': [0.5280191898345947, 0.20602160692214966, 0.10292641073465347, 0.060179196298122406, 0.0238617155700922, 0.02098092995584011, 0.02091890573501587, 0.007556202821433544, 0.006229049060493708, 0.005112409126013517, 0.004478247836232185, 0.004297900013625622, 0.0037682014517486095, 0.0021819474641233683, 0.0021220888011157513, 0.001346043311059475]}, 'a potato masher': {'sequence': 'a potato masher', 'labels': ['cooking utensil', 'appliance', 'ingredient', 'quantity', 'chunks', 'time', 'slices', 'measuring tool', 'pan', 'strainer', 'spatula', 'colinder', 'bowl', 'container', 'board', 'knife'], 'scores': [0.5380751490592957, 0.3954947292804718, 0.033660367131233215, 0.011805306188762188, 0.004556275438517332, 0.0024386276490986347, 0.0017876679776236415, 0.0017483561532571912, 0.0015421545831486583, 0.0014782523503527045, 0.001403333037160337, 0.001388156902976334, 0.0013114112662151456, 0.001253772876225412, 0.001174072502180934, 0.0008823139360174537]}, 'stir': {'sequence': 'stir', 'labels': ['ingredient', 'cooking utensil', 'strainer', 'appliance', 'quantity', 'board', 'chunks', 'measuring tool', 'time', 'colinder', 'pan', 'container', 'spatula', 'bowl', 'slices', 'knife'], 'scores': [0.26783984899520874, 0.19089123606681824, 0.09460724890232086, 0.07151396572589874, 0.06510702520608902, 0.05362106114625931, 0.04338546842336655, 0.038239605724811554, 0.03520292416214943, 0.03115948662161827, 0.030616283416748047, 0.02796092815697193, 0.01919635944068432, 0.017485029995441437, 0.008531082421541214, 0.004642332438379526]}}
# ID: 0
# 	Head ID: -1
# 	Text: ROOT
# 	Type: N/A
# 	Dependent Words:
# 		Dep. ID: 4
# 			Dep. Text: want
# 			Relation Type: root
# ID: 4
# 	Head ID: 0
# 	Text: want
# 	Type: VB
# 	Dependent Words:
# 		Dep. ID: 1
# 			Dep. Text: you
# 			Relation Type: nsubj
# 		Dep. ID: 2
# 			Dep. Text: do
# 			Relation Type: aux
# 		Dep. ID: 3
# 			Dep. Text: n't
# 			Relation Type: advmod
# 		Dep. ID: 6
# 			Dep. Text: mash
# 			Relation Type: xcomp
# 		Dep. ID: 18
# 			Dep. Text: .
# 			Relation Type: punct
# ID: 1
# 	Head ID: 4
# 	Text: you
# 	Type: PRP
# 	Dependent Words:
# ID: 2
# 	Head ID: 4
# 	Text: do
# 	Type: VBP
# 	Dependent Words:
# ID: 3
# 	Head ID: 4
# 	Text: n't
# 	Type: RB
# 	Dependent Words:
# ID: 6
# 	Head ID: 4
# 	Text: mash
# 	Type: VB
# 	Dependent Words:
# 		Dep. ID: 5
# 			Dep. Text: to
# 			Relation Type: mark
# 		Dep. ID: 9
# 			Dep. Text: berries
# 			Relation Type: obj
# 		Dep. ID: 12
# 			Dep. Text: enough
# 			Relation Type: advmod
# 		Dep. ID: 17
# 			Dep. Text: juices
# 			Relation Type: obl
# ID: 5
# 	Head ID: 6
# 	Text: to
# 	Type: TO
# 	Dependent Words:
# ID: 9
# 	Head ID: 6
# 	Text: berries
# 	Type: NNS
# 	Dependent Words:
# 		Dep. ID: 7
# 			Dep. Text: all
# 			Relation Type: det:predet
# 		Dep. ID: 8
# 			Dep. Text: the
# 			Relation Type: det
# ID: 7
# 	Head ID: 9
# 	Text: all
# 	Type: PDT
# 	Dependent Words:
# ID: 8
# 	Head ID: 9
# 	Text: the
# 	Type: DT
# 	Dependent Words:
# ID: 12
# 	Head ID: 6
# 	Text: enough
# 	Type: JJ
# 	Dependent Words:
# 		Dep. ID: 10
# 			Dep. Text: ,
# 			Relation Type: punct
# 		Dep. ID: 11
# 			Dep. Text: just
# 			Relation Type: advmod
# 		Dep. ID: 14
# 			Dep. Text: them
# 			Relation Type: obl
# ID: 10
# 	Head ID: 12
# 	Text: ,
# 	Type: ,
# 	Dependent Words:
# ID: 11
# 	Head ID: 12
# 	Text: just
# 	Type: RB
# 	Dependent Words:
# ID: 14
# 	Head ID: 12
# 	Text: them
# 	Type: PRP
# 	Dependent Words:
# 		Dep. ID: 13
# 			Dep. Text: of
# 			Relation Type: case
# ID: 13
# 	Head ID: 14
# 	Text: of
# 	Type: IN
# 	Dependent Words:
# ID: 17
# 	Head ID: 6
# 	Text: juices
# 	Type: NNS
# 	Dependent Words:
# 		Dep. ID: 15
# 			Dep. Text: for
# 			Relation Type: case
# 		Dep. ID: 16
# 			Dep. Text: their
# 			Relation Type: nmod:poss
# ID: 15
# 	Head ID: 17
# 	Text: for
# 	Type: IN
# 	Dependent Words:
# ID: 16
# 	Head ID: 17
# 	Text: their
# 	Type: PRP$
# 	Dependent Words:
# ID: 18
# 	Head ID: 4
# 	Text: .
# 	Type: .
# 	Dependent Words:
# (S (NP (PRP You)) (VP (VBP do) (RB n't) (VP (VB want) (S (VP (VP (TO to) (VP (VB mash) (NP (PDT all) (DT the) (NNS berries)))) (, ,) (NP (NP (RB just) (JJ enough)) (PP (IN of) (NP (PRP them)))) (PP (IN for) (NP (PRP$ their) (NNS juices))))))) (. .))
# You don't want to mash all the berries, just enough of them for their juices.
# verb phrases: {0: ('want', 'want to mash all the berries, just enough of them for their juices'), 1: ('mash', 'mash all the berries')}
# prep phrases: {0: ('of', 'of them', 'mash'), 1: ('for', 'for their juices', 'mash')}
# noun lists: {}
# nouns: [('You', 'want'), ('all the berries', 'mash'), ('just enough of them', 'mash'), ('their juices', 'mash')]
# STARTING ZERO SHOT
# END OF ZERO SHOT
# {'you': {'sequence': 'you', 'labels': ['board', 'pan', 'measuring tool', 'chunks', 'time', 'quantity', 'appliance', 'cooking utensil', 'strainer', 'container', 'ingredient', 'bowl', 'slices', 'colinder', 'spatula', 'knife'], 'scores': [0.10519267618656158, 0.1026376262307167, 0.08529464900493622, 0.07979760318994522, 0.07550199329853058, 0.06758060306310654, 0.06528504937887192, 0.06145976111292839, 0.05499739572405815, 0.053570039570331573, 0.05042514577507973, 0.047789640724658966, 0.044116295874118805, 0.04007493704557419, 0.034688059240579605, 0.031588517129421234]}, 'all the berries': {'sequence': 'all the berries', 'labels': ['quantity', 'ingredient', 'chunks', 'measuring tool', 'strainer', 'pan', 'container', 'bowl', 'time', 'slices', 'board', 'appliance', 'colinder', 'cooking utensil', 'spatula', 'knife'], 'scores': [0.41672730445861816, 0.2983137369155884, 0.08796007931232452, 0.0442814864218235, 0.02779960073530674, 0.02117288112640381, 0.015966016799211502, 0.014911873266100883, 0.013855787925422192, 0.012007398530840874, 0.009950405918061733, 0.009232539683580399, 0.008376510813832283, 0.007456028833985329, 0.007236800156533718, 0.004751549102365971]}, 'just enough of them': {'sequence': 'just enough of them', 'labels': ['quantity', 'chunks', 'time', 'ingredient', 'slices', 'measuring tool', 'pan', 'board', 'strainer', 'bowl', 'appliance', 'container', 'cooking utensil', 'colinder', 'spatula', 'knife'], 'scores': [0.517307460308075, 0.11596104502677917, 0.051698848605155945, 0.040102269500494, 0.04008536785840988, 0.03676636517047882, 0.031248977407813072, 0.030056815594434738, 0.024918559938669205, 0.019985714927315712, 0.01943678967654705, 0.018561577424407005, 0.017459388822317123, 0.016821471974253654, 0.010491725988686085, 0.009097622707486153]}, 'their juices': {'sequence': 'their juices', 'labels': ['ingredient', 'quantity', 'pan', 'board', 'chunks', 'cooking utensil', 'strainer', 'container', 'measuring tool', 'appliance', 'bowl', 'slices', 'colinder', 'time', 'spatula', 'knife'], 'scores': [0.5271311402320862, 0.10429416596889496, 0.06208570674061775, 0.046032316982746124, 0.03828301280736923, 0.03603936359286308, 0.028082536533474922, 0.023866314440965652, 0.02374965324997902, 0.023478738963603973, 0.022431248798966408, 0.016711745411157608, 0.016692524775862694, 0.01477962825447321, 0.009549339301884174, 0.006792640779167414]}}
# ID: 0
# 	Head ID: -1
# 	Text: ROOT
# 	Type: N/A
# 	Dependent Words:
# 		Dep. ID: 1
# 			Dep. Text: let
# 			Relation Type: root
# ID: 1
# 	Head ID: 0
# 	Text: let
# 	Type: VB
# 	Dependent Words:
# 		Dep. ID: 2
# 			Dep. Text: sit
# 			Relation Type: xcomp
# 		Dep. ID: 8
# 			Dep. Text: .
# 			Relation Type: punct
# ID: 2
# 	Head ID: 1
# 	Text: sit
# 	Type: VB
# 	Dependent Words:
# 		Dep. ID: 5
# 			Dep. Text: bake
# 			Relation Type: advcl
# ID: 5
# 	Head ID: 2
# 	Text: bake
# 	Type: VBP
# 	Dependent Words:
# 		Dep. ID: 3
# 			Dep. Text: while
# 			Relation Type: mark
# 		Dep. ID: 4
# 			Dep. Text: you
# 			Relation Type: nsubj
# 		Dep. ID: 7
# 			Dep. Text: biscuits
# 			Relation Type: obj
# ID: 3
# 	Head ID: 5
# 	Text: while
# 	Type: IN
# 	Dependent Words:
# ID: 4
# 	Head ID: 5
# 	Text: you
# 	Type: PRP
# 	Dependent Words:
# ID: 7
# 	Head ID: 5
# 	Text: biscuits
# 	Type: NNS
# 	Dependent Words:
# 		Dep. ID: 6
# 			Dep. Text: the
# 			Relation Type: det
# ID: 6
# 	Head ID: 7
# 	Text: the
# 	Type: DT
# 	Dependent Words:
# ID: 8
# 	Head ID: 1
# 	Text: .
# 	Type: .
# 	Dependent Words:
# (S (VP (VB Let) (S (VP (VB sit))) (SBAR (IN while) (S (NP (PRP you)) (VP (VBP bake) (NP (DT the) (NNS biscuits)))))) (. .))
# Let sit while you bake the biscuits.
# verb phrases: {0: ('sit', 'sit')}
# prep phrases: {0: ('while', 'while you bake the biscuits', 'bake')}
# noun lists: {}
# nouns: [('you', 'bake'), ('the biscuits', 'bake')]
# STARTING ZERO SHOT
# END OF ZERO SHOT
# {'you': {'sequence': 'you', 'labels': ['board', 'pan', 'measuring tool', 'chunks', 'time', 'quantity', 'appliance', 'cooking utensil', 'strainer', 'container', 'ingredient', 'bowl', 'slices', 'colinder', 'spatula', 'knife'], 'scores': [0.10519267618656158, 0.1026376262307167, 0.08529464900493622, 0.07979760318994522, 0.07550199329853058, 0.06758060306310654, 0.06528504937887192, 0.06145976111292839, 0.05499739572405815, 0.053570039570331573, 0.05042514577507973, 0.047789640724658966, 0.044116295874118805, 0.04007493704557419, 0.034688059240579605, 0.031588517129421234]}, 'the biscuits': {'sequence': 'the biscuits', 'labels': ['ingredient', 'quantity', 'cooking utensil', 'chunks', 'colinder', 'bowl', 'time', 'strainer', 'measuring tool', 'container', 'slices', 'pan', 'appliance', 'board', 'spatula', 'knife'], 'scores': [0.7777602672576904, 0.04796900972723961, 0.03847881779074669, 0.026484105736017227, 0.017659060657024384, 0.011194447986781597, 0.011072703637182713, 0.010827735997736454, 0.010824869386851788, 0.00975791085511446, 0.0092771602794528, 0.007328901905566454, 0.007282761856913567, 0.006394119933247566, 0.004302275832742453, 0.0033858667593449354]}}
# ID: 0
# 	Head ID: -1
# 	Text: ROOT
# 	Type: N/A
# 	Dependent Words:
# 		Dep. ID: 1
# 			Dep. Text: bake
# 			Relation Type: root
# ID: 1
# 	Head ID: 0
# 	Text: bake
# 	Type: VB
# 	Dependent Words:
# 		Dep. ID: 3
# 			Dep. Text: biscuits
# 			Relation Type: obj
# 		Dep. ID: 4
# 			Dep. Text: :
# 			Relation Type: punct
# ID: 3
# 	Head ID: 1
# 	Text: biscuits
# 	Type: NNS
# 	Dependent Words:
# 		Dep. ID: 2
# 			Dep. Text: the
# 			Relation Type: det
# ID: 2
# 	Head ID: 3
# 	Text: the
# 	Type: DT
# ...
# While the biscuits are baking, whip the cream using an electric mixer, adding a drop or two of vanilla and 2 teaspoons of powdered sugar.
# ['a drop or two of vanilla', '2 teaspoons of powdered sugar']
# verb phrases: {0: ('whip', 'whip the cream using an electric mixer')}
# prep phrases: {0: ('While', 'While the biscuits are baking, whip the cream using an electric mixer, adding a drop or two of vanilla and 2 teaspoons of powdered sugar.', 'baking')}
# noun lists: {0: (<ListType.AND: 0>, ['a drop or two of vanilla', '2 teaspoons of powdered sugar'], 'adding')}
# nouns: [('the biscuits', 'baking'), ('the cream', 'whip'), ('an electric mixer', 'using'), ('a drop or two of vanilla', 'adding'), ('2 teaspoons of powdered sugar', 'adding')]
# STARTING ZERO SHOT
# END OF ZERO SHOT
# {'the biscuits': {'sequence': 'the biscuits', 'labels': ['ingredient', 'quantity', 'cooking utensil', 'chunks', 'colinder', 'bowl', 'time', 'strainer', 'measuring tool', 'container', 'slices', 'pan', 'appliance', 'board', 'spatula', 'knife'], 'scores': [0.7777602672576904, 0.04796900972723961, 0.03847881779074669, 0.026484105736017227, 0.017659060657024384, 0.011194447986781597, 0.011072703637182713, 0.010827735997736454, 0.010824869386851788, 0.00975791085511446, 0.0092771602794528, 0.007328901905566454, 0.007282761856913567, 0.006394119933247566, 0.004302275832742453, 0.0033858667593449354]}, 'the cream': {'sequence': 'the cream', 'labels': ['ingredient', 'quantity', 'pan', 'cooking utensil', 'measuring tool', 'time', 'appliance', 'container', 'bowl', 'chunks', 'strainer', 'board', 'colinder', 'spatula', 'slices', 'knife'], 'scores': [0.7369295358657837, 0.0769231915473938, 0.02080865204334259, 0.018806828185915947, 0.017833823338150978, 0.016793856397271156, 0.016757719218730927, 0.01607951894402504, 0.014323757030069828, 0.01327693834900856, 0.011434193700551987, 0.009707776829600334, 0.009515145793557167, 0.008695673197507858, 0.007771684788167477, 0.004341755528002977]}, 'an electric mixer': {'sequence': 'an electric mixer', 'labels': ['appliance', 'ingredient', 'quantity', 'cooking utensil', 'chunks', 'time', 'bowl', 'container', 'measuring tool', 'board', 'pan', 'strainer', 'colinder', 'slices', 'spatula', 'knife'], 'scores': [0.9012203812599182, 0.024646950885653496, 0.01471906341612339, 0.011604581959545612, 0.008547911420464516, 0.005821977276355028, 0.005036144983023405, 0.004649040754884481, 0.004199916496872902, 0.003915721550583839, 0.0034914910793304443, 0.0028673848137259483, 0.0027420949190855026, 0.0024167741648852825, 0.002295775804668665, 0.0018247768748551607]}, 'a drop or two of vanilla': {'sequence': 'a drop or two of vanilla', 'labels': ['ingredient', 'quantity', 'chunks', 'container', 'pan', 'bowl', 'measuring tool', 'strainer', 'colinder', 'time', 'appliance', 'board', 'slices', 'cooking utensil', 'spatula', 'knife'], 'scores': [0.7117868065834045, 0.08119932562112808, 0.03403765708208084, 0.030976923182606697, 0.026089034974575043, 0.02342495322227478, 0.022252537310123444, 0.017403407022356987, 0.010212698951363564, 0.009368033148348331, 0.00845733005553484, 0.008436407893896103, 0.006525688339024782, 0.004204124677926302, 0.00385132129304111, 0.001773771713487804]}, '2 teaspoons of powdered sugar': {'sequence': '2 teaspoons of powdered sugar', 'labels': ['quantity', 'ingredient', 'measuring tool', 'container', 'pan', 'colinder', 'bowl', 'board', 'time', 'strainer', 'appliance', 'chunks', 'cooking utensil', 'spatula', 'slices', 'knife'], 'scores': [0.42639532685279846, 0.39662858843803406, 0.06879767775535583, 0.021956784650683403, 0.016990987583994865, 0.011429444886744022, 0.011094574816524982, 0.01015202235430479, 0.007828074507415295, 0.007591724395751953, 0.006347503047436476, 0.0049947346560657024, 0.0037913366686552763, 0.002630250994116068, 0.0019251875346526504, 0.0014458118239417672]}}
# ID: 0
# 	Head ID: -1
# 	Text: ROOT
# 	Type: N/A
# 	Dependent Words:
# 		Dep. ID: 1
# 			Dep. Text: cover
# 			Relation Type: root
# ID: 1
# 	Head ID: 0
# 	Text: cover
# 	Type: VB
# 	Dependent Words:
# 		Dep. ID: 3
# 			Dep. Text: plastic
# 			Relation Type: obl
# 		Dep. ID: 8
# 			Dep. Text: refrigerator
# 			Relation Type: obl
# 		Dep. ID: 10
# 			Dep. Text: chill
# 			Relation Type: advcl
# 		Dep. ID: 15
# 			Dep. Text: .
# 			Relation Type: punct
# ID: 3
# 	Head ID: 1
# 	Text: plastic
# 	Type: NN
# 	Dependent Words:
# 		Dep. ID: 2
# 			Dep. Text: with
# 			Relation Type: case
# 		Dep. ID: 5
# 			Dep. Text: place
# 			Relation Type: conj
# ID: 2
# 	Head ID: 3
# 	Text: with
# 	Type: IN
# 	Dependent Words:
# ID: 5
# 	Head ID: 3
# 	Text: place
# 	Type: NN
# 	Dependent Words:
# 		Dep. ID: 4
# 			Dep. Text: and
# 			Relation Type: cc
# ID: 4
# 	Head ID: 5
# 	Text: and
# 	Type: CC
# 	Dependent Words:
# ID: 8
# 	Head ID: 1
# 	Text: refrigerator
# 	Type: NN
# 	Dependent Words:
# 		Dep. ID: 6
# 			Dep. Text: in
# 			Relation Type: case
# 		Dep. ID: 7
# 			Dep. Text: the
# 			Relation Type: det
# ID: 6
# 	Head ID: 8
# 	Text: in
# 	Type: IN
# 	Dependent Words:
# ID: 7
# 	Head ID: 8
# 	Text: the
# 	Type: DT
# 	Dependent Words:
# ID: 10
# 	Head ID: 1
# 	Text: chill
# 	Type: VB
# 	Dependent Words:
# 		Dep. ID: 9
# 			Dep. Text: to
# 			Relation Type: mark
# 		Dep. ID: 12
# 			Dep. Text: ready
# 			Relation Type: advcl
# ID: 9
# 	Head ID: 10
# 	Text: to
# 	Type: TO
# 	Dependent Words:
# ID: 12
# 	Head ID: 10
# 	Text: ready
# 	Type: JJ
# 	Dependent Words:
# 		Dep. ID: 11
# 			Dep. Text: until
# 			Relation Type: mark
# 		Dep. ID: 14
# 			Dep. Text: serve
# 			Relation Type: xcomp
# ID: 11
# 	Head ID: 12
# 	Text: until
# 	Type: IN
# 	Dependent Words:
# ID: 14
# 	Head ID: 12
# 	Text: serve
# 	Type: VB
# 	Dependent Words:
# 		Dep. ID: 13
# 			Dep. Text: to
# 			Relation Type: mark
# ID: 13
# 	Head ID: 14
# 	Text: to
# 	Type: TO
# 	Dependent Words:
# ID: 15
# 	Head ID: 1
# 	Text: .
# 	Type: .
# 	Dependent Words:
# (S (VP (VB Cover) (PP (IN with) (NP (NP (NN plastic) (CC and) (NN place)) (PP (IN in) (NP (DT the) (NN refrigerator))))) (S (VP (TO to) (VP (VB chill)))) (SBAR (IN until) (S (ADJP (JJ ready) (S (VP (TO to) (VP (VB serve)))))))) (. .))
# Cover with plastic and place in the refrigerator to chill until ready to serve.
# ['plastic', 'place']
# refrigerator
# verb phrases: {0: ('Cover', 'Cover with plastic and place in the refrigerator to chill until ready to serve'), 1: ('chill', 'chill'), 2: ('serve', 'serve')}
# prep phrases: {0: ('with', 'with plastic and place in the refrigerator', 'cover'), 1: ('until', 'until ready to serve', 'chill')}
# noun lists: {0: (<ListType.AND: 0>, ['plastic', 'place'], 'cover')}
# nouns: [('plastic and place in the refrigerator', 'cover')]
# STARTING ZERO SHOT
# END OF ZERO SHOT
# {'plastic and place in the refrigerator': {'sequence': 'plastic and place in the refrigerator', 'labels': ['appliance', 'container', 'quantity', 'ingredient', 'colinder', 'chunks', 'time', 'pan', 'strainer', 'board', 'bowl', 'slices', 'spatula', 'measuring tool', 'cooking utensil', 'knife'], 'scores': [0.6122224926948547, 0.08266787230968475, 0.07409506291151047, 0.052178043872117996, 0.030134370550513268, 0.029449395835399628, 0.02575167641043663, 0.016605263575911522, 0.015717092901468277, 0.013622346334159374, 0.012585564516484737, 0.009134192951023579, 0.008206622675061226, 0.006642316002398729, 0.006492312997579575, 0.004495423752814531]}}
# ID: 0
# 	Head ID: -1
# 	Text: ROOT
# 	Type: N/A
# 	Dependent Words:
# 		Dep. ID: 4
# 			Dep. Text: break
# 			Relation Type: root
# ID: 2
# 	Head ID: 4
# 	Text: serve
# 	Type: VB
# 	Dependent Words:
# 		Dep. ID: 1
# 			Dep. Text: to
# 			Relation Type: mark
# 		Dep. ID: 3
# 			Dep. Text: ,
# 			Relation Type: punct
# ID: 1
# 	Head ID: 2
# 	Text: to
# 	Type: TO
# 	Dependent Words:
# ID: 4
# 	Head ID: 0
# 	Text: break
# 	Type: VB
# 	Dependent Words:
# 		Dep. ID: 2
# 			Dep. Text: serve
# 			Relation Type: advcl
# 		Dep. ID: 5
# 			Dep. Text: up
# 			Relation Type: compound:prt
# 		Dep. ID: 7
# 			Dep. Text: biscuit
# 			Relation Type: obj
# 		Dep. ID: 12
# 			Dep. Text: pieces
# 			Relation Type: obl
# 		Dep. ID: 15
# 			Dep. Text: bowl
# 			Relation Type: obl
# 		Dep. ID: 16
# 			Dep. Text: .
# 			Relation Type: punct
# ID: 3
# 	Head ID: 2
# 	Text: ,
# 	Type: ,
# 	Dependent Words:
# ID: 5
# 	Head ID: 4
# 	Text: up
# 	Type: RP
# 	Dependent Words:
# ID: 7
# 	Head ID: 4
# 	Text: biscuit
# 	Type: NN
# 	Dependent Words:
# 		Dep. ID: 6
# 			Dep. Text: one
# 			Relation Type: nummod
# 		Dep. ID: 9
# 			Dep. Text: person
# 			Relation Type: nmod
# ID: 6
# 	Head ID: 7
# 	Text: one
# 	Type: CD
# 	Dependent Words:
# ID: 9
# 	Head ID: 7
# 	Text: person
# 	Type: NN
# 	Dependent Words:
# 		Dep. ID: 8
# 			Dep. Text: per
# 			Relation Type: case
# ID: 8
# 	Head ID: 9
# 	Text: per
# 	Type: IN
# 	Dependent Words:
# ID: 12
# 	Head ID: 4
# 	Text: pieces
# 	Type: NNS
# 	Dependent Words:
# 		Dep. ID: 10
# 			Dep. Text: into
# 			Relation Type: case
# 		Dep. ID: 11
# 			Dep. Text: big
# 			Relation Type: amod
# ID: 10
# 	Head ID: 12
# 	Text: into
# 	Type: IN
# 	Dependent Words:
# ID: 11
# 	Head ID: 12
# 	Text: big
# 	Type: JJ
# 	Dependent Words:
# ID: 15
# 	Head ID: 4
# 	Text: bowl
# 	Type: NN
# 	Dependent Words:
# 		Dep. ID: 13
# 			Dep. Text: into
# 			Relation Type: case
# 		Dep. ID: 14
# 			Dep. Text: a
# 			Relation Type: det
# ID: 13
# 	Head ID: 15
# 	Text: into
# 	Type: IN
# 	Dependent Words:
# ID: 14
# 	Head ID: 15
# 	Text: a
# 	Type: DT
# 	Dependent Words:
# ID: 16
# 	Head ID: 4
# 	Text: .
# 	Type: .
# 	Dependent Words:
# (S (S (VP (TO To) (VP (VB serve)))) (, ,) (VP (VB break) (PRT (RP up)) (NP (NP (CD one) (NN biscuit)) (PP (IN per) (NP (NN person)))) (PP (IN into) (NP (JJ big) (NNS pieces))) (PP (IN into) (NP (DT a) (NN bowl)))) (. .))
# To serve, break up one biscuit per person into big pieces into a bowl.
# 5
# 2
# 5
# 7
# 12
# 15
# 16
# verb phrases: {0: ('serve', 'serve'), 1: ('break', 'break up one biscuit per person into big pieces into a bowl')}
# prep phrases: {0: ('up', 'up one biscuit per person', 'break'), 1: ('into', 'into big pieces', 'break'), 2: ('into', 'into a bowl', 'break')}
# noun lists: {}
# nouns: [('one biscuit per person', 'break'), ('big pieces', 'break'), ('a bowl', 'break')]
# STARTING ZERO SHOT
# END OF ZERO SHOT
# {'one biscuit per person': {'sequence': 'one biscuit per person', 'labels': ['quantity', 'ingredient', 'measuring tool', 'colinder', 'chunks', 'cooking utensil', 'container', 'strainer', 'bowl', 'time', 'slices', 'board', 'pan', 'appliance', 'spatula', 'knife'], 'scores': [0.4699128568172455, 0.16698122024536133, 0.10894527286291122, 0.04343504458665848, 0.03971371799707413, 0.030296465381979942, 0.029493000358343124, 0.018721116706728935, 0.015798289328813553, 0.015069739893078804, 0.014523769728839397, 0.014083264395594597, 0.013912520371377468, 0.012624358758330345, 0.0038248864002525806, 0.0026645695324987173]}, 'big pieces': {'sequence': 'big pieces', 'labels': ['quantity', 'chunks', 'pan', 'board', 'slices', 'colinder', 'appliance', 'time', 'strainer', 'bowl', 'cooking utensil', 'ingredient', 'measuring tool', 'container', 'knife', 'spatula'], 'scores': [0.42888084053993225, 0.3957955539226532, 0.022730890661478043, 0.019345594570040703, 0.01645263284444809, 0.013674536719918251, 0.013116003945469856, 0.012156913988292217, 0.011773467995226383, 0.01135103590786457, 0.011153829284012318, 0.009980318136513233, 0.00994404498487711, 0.009467795491218567, 0.007144671864807606, 0.007031893823295832]}, 'a bowl': {'sequence': 'a bowl', 'labels': ['bowl', 'container', 'appliance', 'cooking utensil', 'quantity', 'ingredient', 'colinder', 'board', 'chunks', 'strainer', 'measuring tool', 'pan', 'time', 'spatula', 'slices', 'knife'], 'scores': [0.5448422431945801, 0.16479147970676422, 0.11858982592821121, 0.05441448092460632, 0.03233256936073303, 0.026385189965367317, 0.01975465752184391, 0.006694895680993795, 0.006142984144389629, 0.005668929778039455, 0.00495191803202033, 0.004642457701265812, 0.004349770024418831, 0.0025282143615186214, 0.002523821545764804, 0.0013866256922483444]}}
# ID: 0
# 	Head ID: -1
# 	Text: ROOT
# 	Type: N/A
# 	Dependent Words:
# 		Dep. ID: 2
# 			Dep. Text: strawberries
# 			Relation Type: root
# ID: 2
# 	Head ID: 0
# 	Text: strawberries
# 	Type: NNS
# 	Dependent Words:
# 		Dep. ID: 1
# 			Dep. Text: ladle
# 			Relation Type: compound
# 		Dep. ID: 5
# 			Dep. Text: biscuit
# 			Relation Type: nmod
# 		Dep. ID: 6
# 			Dep. Text: .
# 			Relation Type: punct
# ID: 1
# 	Head ID: 2
# 	Text: ladle
# 	Type: NN
# 	Dependent Words:
# ID: 5
# 	Head ID: 2
# 	Text: biscuit
# 	Type: NN
# 	Dependent Words:
# 		Dep. ID: 3
# 			Dep. Text: over
# 			Relation Type: case
# 		Dep. ID: 4
# 			Dep. Text: the
# 			Relation Type: det
# ID: 3
# 	Head ID: 5
# 	Text: over
# 	Type: IN
# 	Dependent Words:
# ID: 4
# 	Head ID: 5
# 	Text: the
# 	Type: DT
# 	Dependent Words:
# ID: 6
# 	Head ID: 2
# 	Text: .
# 	Type: .
# 	Dependent Words:
# (NP (NP (NN Ladle) (NNS strawberries)) (PP (IN over) (NP (DT the) (NN biscuit))) (. .))
# Ladle strawberries over the biscuit.
# verb phrases: {}
# prep phrases: {0: ('over', 'over the biscuit', None)}
# noun lists: {}
# nouns: [('Ladle strawberries', None), ('the biscuit', None)]
# STARTING ZERO SHOT
# END OF ZERO SHOT
# {'ladle strawberries': {'sequence': 'ladle strawberries', 'labels': ['ingredient', 'quantity', 'chunks', 'measuring tool', 'appliance', 'container', 'time', 'slices', 'cooking utensil', 'bowl', 'pan', 'board', 'strainer', 'spatula', 'knife', 'colinder'], 'scores': [0.5907068252563477, 0.12264629453420639, 0.03826967626810074, 0.0363871268928051, 0.026351654902100563, 0.025823447853326797, 0.022781120613217354, 0.021561790257692337, 0.020645437762141228, 0.020245550200343132, 0.01900445483624935, 0.017747849225997925, 0.014081683941185474, 0.008615226484835148, 0.007617983967065811, 0.007513845805078745]}, 'the biscuit': {'sequence': 'the biscuit', 'labels': ['ingredient', 'quantity', 'colinder', 'chunks', 'cooking utensil', 'measuring tool', 'bowl', 'time', 'strainer', 'board', 'slices', 'appliance', 'container', 'pan', 'spatula', 'knife'], 'scores': [0.8054404854774475, 0.03479958698153496, 0.03455314040184021, 0.02703976072371006, 0.01973903365433216, 0.011465879157185555, 0.009129200130701065, 0.008645787835121155, 0.008242947980761528, 0.008126556873321533, 0.006764346268028021, 0.006667787209153175, 0.006515748333185911, 0.006410844158381224, 0.0034841487649828196, 0.002974709030240774]}}
# ID: 0
# 	Head ID: -1
# 	Text: ROOT
# 	Type: N/A
# 	Dependent Words:
# 		Dep. ID: 1
# 			Dep. Text: add
# 			Relation Type: root
# ID: 1
# 	Head ID: 0
# 	Text: add
# 	Type: VB
# 	Dependent Words:
# 		Dep. ID: 3
# 			Dep. Text: dollop
# 			Relation Type: obj
# 		Dep. ID: 7
# 			Dep. Text: .
# 			Relation Type: punct
# ID: 3
# 	Head ID: 1
# 	Text: dollop
# 	Type: NN
# 	Dependent Words:
# 		Dep. ID: 2
# 			Dep. Text: a
# 			Relation Type: det
# 		Dep. ID: 6
# 			Dep. Text: cream
# 			Relation Type: nmod
# ID: 2
# 	Head ID: 3
# 	Text: a
# 	Type: DT
# 	Dependent Words:
# ID: 6
# 	Head ID: 3
# 	Text: cream
# 	Type: NN
# 	Dependent Words:
# 		Dep. ID: 4
# 			Dep. Text: of
# 			Relation Type: case
# 		Dep. ID: 5
# 			Dep. Text: whipped
# 			Relation Type: amod
# ID: 4
# 	Head ID: 6
# 	Text: of
# 	Type: IN
# 	Dependent Words:
# ID: 5
# 	Head ID: 6
# 	Text: whipped
# 	Type: VBN
# 	Dependent Words:
# ID: 7
# 	Head ID: 1
# 	Text: .
# 	Type: .
# 	Dependent Words:
# (S (VP (VB Add) (NP (NP (DT a) (NN dollop)) (PP (IN of) (NP (VBN whipped) (NN cream))))) (. .))
# Add a dollop of whipped cream.
# verb phrases: {0: ('Add', 'Add a dollop of whipped cream')}
# prep phrases: {0: ('of', 'of whipped cream', 'add')}
# noun lists: {}
# nouns: [('a dollop of whipped cream', 'add')]
# STARTING ZERO SHOT
# END OF ZERO SHOT
# {'a dollop of whipped cream': {'sequence': 'a dollop of whipped cream', 'labels': ['ingredient', 'quantity', 'container', 'chunks', 'pan', 'bowl', 'appliance', 'time', 'slices', 'measuring tool', 'strainer', 'spatula', 'colinder', 'cooking utensil', 'board', 'knife'], 'scores': [0.6499859690666199, 0.15951542556285858, 0.024672824889421463, 0.02356758341193199, 0.019578516483306885, 0.018628042191267014, 0.016711952164769173, 0.014719697646796703, 0.011749910190701485, 0.01162633765488863, 0.01114177331328392, 0.009991426020860672, 0.009033924899995327, 0.0071786814369261265, 0.0061348807066679, 0.005763054825365543]}}

# %%
def goal6(step_num:int, question: str, canon_ingredients:list,  step:Step):
    quantity_Q_list = ["How many do I need?",
                       "How much do I need?",
                       "What amount of this do I need?",
                       "Around how much of this ingredient do I need for this step?",
                       "Do I use a lot of this ingredient?",
                       "Do I use a little of this ingredient?",
                       "How many cups do I need?",
                       "What should I fill my measuring cup up to?"] # add 6 more
    temperature_Q_list = ["How hot should it be?",
                          "How many degrees should it be set to?",
                          "How high do I set the oven?",
                          "What temperature should it be at?",
                          "What is the best temperature for this step?",
                          "How cold should it be?",
                          "How many degrees should I set it to?"] # add 7 more
    time_Q_list = [ "How long should I do this?",
                    "How much time should this take?",
                    "How long do I wait?",
                    "How long will this take?",
                    "How many minutes do I do this?",
                    "How much time until I do this?",
                    "For how long?",
                    "What should I set my timer to?",
                    "When will this be done?",
                    "What should I check to see if it is done?",
                    "What should it look like when I'm done?",
                    "When is it done?",
                    "When should I stop?",
                    "How long should I microwave it for?"]
    
    parsed_input = depgram(question)
    (input_deps, _) = getDependency(parsed_input.sentences[0].dependencies)
    for ii in input_deps:
        print(input_deps[ii])

    object_of_question = ""
    print(list(input_deps[0].deps.keys())[0])
    # find the direct object of the root verb, it will be what the question is about
    for dd in input_deps[list(input_deps[0].deps.keys())[0]].deps:
        if input_deps[list(input_deps[0].deps.keys())[0]].deps[dd][2] == "obj" or input_deps[list(input_deps[0].deps.keys())[0]].deps[dd][2] == "nsubj":
            object_of_question = input_deps[dd].text
            break
    print(object_of_question)
    if (object_of_question == "" or object_of_question == None) and "NN" in input_deps[list(input_deps[0].deps.keys())[0]].typ:
        object_of_question = input_deps[list(input_deps[0].deps.keys())[0]].text
    if object_of_question == "" or object_of_question == None:
        return "Sorry, could you rephrase that?"

    
    quantity_score = 0
    for q in quantity_Q_list:
        quantity_score += pipe2(question, q)['scores'][0]
    temperature_score = 0
    for q in temperature_Q_list:
        temperature_score += pipe2(question, q)['scores'][0]
    time_score = 0
    for q in time_Q_list:
        time_score += pipe2(question, q)['scores'][0]

    # print(pipe2(question, candidate_labels=["how much", "what temperature", "for how long", "when"]))
    print("quantity score: " + str(quantity_score))
    print("temperature score: " + str(temperature_score))
    print("time score: " + str(time_score))

    print(step)
    max_score = max(quantity_score, temperature_score, time_score)
    if max_score < 1:
        return "I'm sorry, I am not sure what you mean. Could you please try rephrasing that?"

    answer = ""

    # for quantity
    if max_score == quantity_score:
        ingredient_ranking = []
        for ingr in step.ingredients:
            pipe_res = pipe2(step.ingredients[ingr][0], object_of_question)
            ingredient_ranking.append((step.ingredients[ingr][0], pipe_res['scores'][0]))
        ingredient_ranking.sort(key=lambda x: x[1], reverse=True)
        max_ingredient_score = ingredient_ranking[0]
        print(max_ingredient_score)
        is_quantity = pipe2(max_ingredient_score[0], "amount")['scores'][0]
        print(is_quantity)

        if max_ingredient_score[1] < 0.4 or is_quantity < 0.4:
            ingredient_ranking = []
            if type(canon_ingredients[0]) != list:
                canon_ingredients = [canon_ingredients]
            for canon_ingr in canon_ingredients[0]:
                pipe_res = pipe2(canon_ingr, object_of_question)
                print(canon_ingr)
                print(pipe_res)
                ingredient_ranking.append((canon_ingr, pipe_res['scores'][0]))
            ingredient_ranking.sort(key=lambda x: x[1], reverse=True)
            
            while reg.search("\d", ingredient_ranking[0][0]) == None:
                ingredient_ranking = ingredient_ranking[1:]

            max_ingredient_score = ingredient_ranking[0]
        answer = max_ingredient_score[0]
    # for temperature
    elif max_score == temperature_score:
        detail_ranking = []
        for detail_id in step.details.keys():
            detail = step.details[detail_id]
            pipe_res = pipe2(detail[1], "temperature")
            detail_ranking.append((detail[1], pipe_res['scores'][0]))
        detail_ranking.sort(key=lambda x: x[1], reverse=True)
        print(detail_ranking)
        if len(detail_ranking) > 0 and detail_ranking[0][1] > 0.6: answer = detail_ranking[0][0]
        elif len(detail_ranking) < 1 or detail_ranking[0][1] < 0.6:
            regex_minute_search = reg.search("(\d+)\s+degrees", step.original_text)
            if regex_minute_search != None:
                answer = str(regex_minute_search.group(1)) + " degrees"
        
    # for time
    elif max_score == time_score:
        detail_ranking = []
        for detail_id in step.details.keys():
            detail = step.details[detail_id]
            # print(detail[1])
            pipe_res = pipe2(detail[1], "time")
            bonus = 0
            if "until" in detail[1]:
                bonus += 0.9
            if "minute" in detail[1]:
                bonus += 1
            if "second" in detail[1]:
                bonus += 1
            if detail[1] == "then":
                bonus -= 1
            detail_ranking.append((detail[1], pipe_res['scores'][0] + bonus))
        detail_ranking.sort(key=lambda x: x[1], reverse=True)
        print(detail_ranking)
        if len(detail_ranking) > 0 and detail_ranking[0][1] > 0.6: answer = detail_ranking[0][0]
        elif len(detail_ranking) < 1 or detail_ranking[0][1] < 0.6:
            regex_minute_search = reg.search("(\d+)\s+minute", step.original_text)
            if regex_minute_search != None:
                answer = str(regex_minute_search.group(1)) + " minutes"
        
    if answer == "":
        return "I'm sorry, I couldn't figure that out."

    return answer
    

# print(allsteps[10])
print(allsteps2[1])
print(goal6(1, "How much salt?", 
      #[['Strawberries:', '3 pint baskets fresh strawberries (about 6 cups)', '1/2 cup (100 g) white granulated sugar for the strawberries', 'Whipped Cream:', '1 cup (236 ml) heavy whipping cream', '2 teaspoons powdered sugar', '2 drops vanilla extract', 'Biscuits:', '3 1/4 cups (455g) all purpose flour, divided ( 3 cups and 1/4 cup)', '3 tablespoons sugar', '1 1/2 tablespoons baking powder', '3/4 teaspoon salt', '12 tablespoons (168g) unsalted butter, cut into small cubes', '1 cup (236 ml) milk', '1/4 (60 ml) cup heavy cream', '1 1/2 teaspoons vanilla extract']], 
      #['all-purpose flour, for dusting', '12 oz prepared pizza dough', '2 tablespoons olive oil, divided', '6 large eggs, separated', '½ cup prepared pizza sauce', '½ cup frozen spinach, thawed and squeezed dry', '½ cup shredded whole-milk mozzarella cheese', '½ teaspoon dried oregano', '¼ teaspoon crushed red pepper flake', '¼ teaspoon kosher salt', '¼ teaspoon ground black pepper', '2 tablespoons grated parmesan cheese']
      ['Kosher salt', '12 ounces linguine', '1 1/4 pounds large shrimp, peeled and deveined', '1/3 cup extra-virgin olive oil\xa0', '5 cloves garlic, minced', '1/4 to 1/2 teaspoon red pepper flakes', '1/3 cup dry white wine', 'Juice of 1/2 lemon, plus wedges for serving', '4 tablespoons unsalted butter, cut into pieces', '1/4 cup finely chopped fresh parsley']
      ,
      allsteps2[4]))

# print(pipe2("hello", "greeting"))
# Out:
# id: 1
# Original text: Bring a large pot of salted water to a boil.
# 	Root action: Bring
# 	All actions: {0: ('Bring', 'Bring a large pot of salted water to a boil')}
# 	Ingredients: {('a large pot of salted water', 'bring', 'quantity'): ('a large pot of salted water', 'bring')}
# 	Tools: {'a boil': ('a boil', 'bring', 'appliance')}
# 	Details: {0: ('of', 'of salted water', 'bring'), 1: ('to', 'to a boil', 'bring')}
# ID: 0
# 	Head ID: -1
# 	Text: ROOT
# 	Type: N/A
# 	Dependent Words:
# 		Dep. ID: 3
# 			Dep. Text: salt
# 			Relation Type: root
# ID: 2
# 	Head ID: 3
# 	Text: much
# 	Type: JJ
# 	Dependent Words:
# 		Dep. ID: 1
# 			Dep. Text: how
# 			Relation Type: advmod
# ID: 1
# 	Head ID: 2
# 	Text: how
# 	Type: WRB
# 	Dependent Words:
# ID: 3
# 	Head ID: 0
# 	Text: salt
# 	Type: NN
# 	Dependent Words:
# 		Dep. ID: 2
# 			Dep. Text: much
# 			Relation Type: amod
# 		Dep. ID: 4
# 			Dep. Text: ?
# 			Relation Type: punct
# ID: 4
# 	Head ID: 3
# 	Text: ?
# 	Type: .
# 	Dependent Words:
# 3
#
# quantity score: 5.602894056588411
# temperature score: 0.00656042288755998
# time score: 0.021817838482093066
# id: 4
# Original text: Meanwhile, season the shrimp with salt.
# 	Root action: season
# 	All actions: {}
# 	Ingredients: {('season the shrimp with salt', None, 'ingredient'): ('season the shrimp with salt', None)}
# 	Tools: {}
# 	Details: {0: ('Meanwhile', 'Meanwhile', None), 1: ('with', 'with salt', None)}
# ('season the shrimp with salt', 0.9895164370536804)
# 0.916042685508728
# season the shrimp with salt

# %%
for step in allsteps3:
    print(allsteps3[step])
# Out:
# id: 1
# Original text: Prep the strawberries:
# 	Root action: Prep
# 	All actions: {0: ('Prep', 'Prep the strawberries')}
# 	Ingredients: {'the strawberries': ('the strawberries', 'prep', 'ingredient')}
# 	Tools: {}
# 	Details: {}
# id: 2
# Original text: Cut the stems away from the strawberries and discard.
# 	Root action: Cut
# 	All actions: {0: ('Cut', 'Cut the stems away from the strawberries'), 1: ('discard', 'discard')}
# 	Ingredients: {'the stems': ('the stems', 'cut', 'ingredient'), 'the strawberries': ('the strawberries', 'cut', 'ingredient')}
# 	Tools: {}
# 	Details: {0: ('away', 'away from the strawberries', 'cut')}
# id: 3
# Original text: Cut the strawberries in half, and then in either quarters or thick slices.
# 	Root action: Cut
# 	All actions: {0: ('Cut', 'Cut the strawberries in half, and then in either quarters or thick slices')}
# 	Ingredients: {'the strawberries': ('the strawberries', 'cut', 'ingredient'), 'half': ('half', 'cut', 'chunks'), 'quarters': ('quarters', 'cut', 'quantity'), 'thick slices': ('thick slices', 'cut', 'slices')}
# 	Tools: {}
# 	Details: {0: ('in', 'in half, and then in either quarters or thick slices', 'cut'), 1: ('then', 'then', 'cut')}
# id: 4
# Original text: Macerate the strawberries with sugar:
# 	Root action: Macerate
# 	All actions: {0: ('Macerate', 'Macerate the strawberries with sugar')}
# 	Ingredients: {'the strawberries': ('the strawberries', 'macerate', 'ingredient'), 'sugar': ('sugar', 'macerate', 'ingredient')}
# 	Tools: {}
# 	Details: {0: ('with', 'with sugar', 'macerate')}
# id: 5
# Original text: Put the cut strawberries into a large bowl and sprinkle with sugar.
# 	Root action: Put
# 	All actions: {0: ('Put', 'Put the cut strawberries into a large bowl'), 1: ('sprinkle', 'sprinkle with sugar')}
# 	Ingredients: {'the cut strawberries': ('the cut strawberries', 'put', 'slices'), 'sugar': ('sugar', 'sprinkle', 'ingredient')}
# 	Tools: {'a large bowl': ('a large bowl', 'put', 'bowl')}
# 	Details: {0: ('into', 'into a large bowl', 'put'), 1: ('with', 'with sugar', 'sprinkle')}
# id: 6
# Original text: Start with 1/4 cup of sugar and then add up to another 1/4 cup depending on how sweet your strawberries are.
# 	Root action: Start
# 	All actions: {0: ('Start', 'Start with 1 /4 cup of sugar'), 1: ('add', 'add up to another 1 /4 cup depending on how sweet your strawberries are')}
# 	Ingredients: {'1 /4 cup of sugar': ('1 /4 cup of sugar', 'start', 'ingredient'), 'another 1 /4 cup': ('another 1 /4 cup', 'add', 'quantity'), 'your strawberries': ('your strawberries', 'are', 'ingredient')}
# 	Tools: {}
# 	Details: {0: ('with', 'with 1 /4 cup of sugar', 'start'), 1: ('then', 'then', 'add'), 2: ('to', 'to another 1 /4 cup', 'add'), 3: ('on', 'depending on how sweet your strawberries are', 'add')}
# id: 7
# Original text: Gently stir the strawberries until they are all coated with some sugar.
# 	Root action: stir
# 	All actions: {0: ('stir', 'stir the strawberries until they are all coated with some sugar')}
# 	Ingredients: {'the strawberries': ('the strawberries', 'stir', 'ingredient'), 'they': ('they', 'coated', 'quantity'), 'some sugar': ('some sugar', 'coated', 'ingredient')}
# 	Tools: {}
# 	Details: {0: ('Gently', 'Gently', 'stir'), 1: ('until', 'until they are all coated with some sugar', 'coated')}
# id: 8
# Original text: Let sit at room temperature for about 20 minutes, until the berries soften and begin to release their juices.
# 	Root action: Let
# 	All actions: {0: ('sit', 'sit at room temperature for about 20 minutes'), 1: ('begin', 'begin to release their juices'), 2: ('release', 'release their juices')}
# 	Ingredients: {'the berries': ('the berries', 'soften', 'ingredient'), 'their juices': ('their juices', 'release', 'ingredient')}
# 	Tools: {'room temperature': ('room temperature', 'sit', 'measuring tool')}
# 	Details: {0: ('at', 'at room temperature', 'sit'), 1: ('for', 'for about 20 minutes', 'sit'), 2: ('until', 'until the berries soften and begin to release their juices', 'soften')}
# id: 9
# Original text: Mash some of the strawberries:
# 	Root action: Mash
# 	All actions: {0: ('Mash', 'Mash some of the strawberries')}
# 	Ingredients: {'some of the strawberries': ('some of the strawberries', 'mash', 'ingredient')}
# 	Tools: {}
# 	Details: {0: ('of', 'of the strawberries', 'mash')}
# id: 10
# Original text: After 20 minutes or so, mash about a quarter of the berries in the bowl with a potato masher and stir to mix.
# 	Root action: mash
# 	All actions: {0: ('mash', 'mash about a quarter of the berries in the bowl with a potato masher and stir to mix'), 1: ('mix', 'mix')}
# 	Ingredients: {'about a quarter of the berries': ('about a quarter of the berries', 'mash', 'quantity'), 'stir': ('stir', 'mash', 'ingredient')}
# 	Tools: {'the bowl': ('the bowl', 'mash', 'bowl'), 'a potato masher': ('a potato masher', 'mash', 'cooking utensil')}
# 	Details: {0: ('After', 'After 20 minutes or so', 'mash'), 1: ('of', 'of the berries', 'mash'), 2: ('in', 'in the bowl', 'mash'), 3: ('with', 'with a potato masher and stir to mix', 'mash')}
# id: 11
# Original text: You don't want to mash all the berries, just enough of them for their juices.
# 	Root action: want
# 	All actions: {0: ('want', 'want to mash all the berries, just enough of them for their juices'), 1: ('mash', 'mash all the berries')}
# 	Ingredients: {'all the berries': ('all the berries', 'mash', 'quantity'), 'just enough of them': ('just enough of them', 'mash', 'quantity'), 'their juices': ('their juices', 'mash', 'ingredient')}
# 	Tools: {'You': ('You', 'want', 'board')}
# 	Details: {0: ('of', 'of them', 'mash'), 1: ('for', 'for their juices', 'mash')}
# id: 12
# Original text: Let sit while you bake the biscuits.
# 	Root action: Let
# 	All actions: {0: ('sit', 'sit')}
# 	Ingredients: {'the biscuits': ('the biscuits', 'bake', 'ingredient')}
# 	Tools: {'you': ('you', 'bake', 'board')}
# 	Details: {0: ('while', 'while you bake the biscuits', 'bake')}
# id: 13
# Original text: Bake the biscuits:
# 	Root action: Bake
# 	All actions: {0: ('Bake', 'Bake the biscuits')}
# 	Ingredients: {'the biscuits': ('the biscuits', 'bake', 'ingredient')}
# 	Tools: {}
# 	Details: {}
# id: 14
# Original text: Use the recipe below to bake the biscuits.
# 	Root action: Use
# 	All actions: {0: ('Use', 'Use the recipe below to bake the biscuits'), 1: ('bake', 'bake the biscuits')}
# 	Ingredients: {'the recipe': ('the recipe', 'use', 'ingredient'), 'the biscuits': ('the biscuits', 'bake', 'ingredient')}
# 	Tools: {}
# 	Details: {0: ('below', 'below', 'use')}
# id: 15
# Original text: Make the whipped cream:
# 	Root action: Make
# 	All actions: {0: ('Make', 'Make the whipped cream')}
# 	Ingredients: {'the whipped cream': ('the whipped cream', 'make', 'ingredient')}
# 	Tools: {}
# 	Details: {}
# id: 16
# Original text: While the biscuits are baking, whip the cream using an electric mixer, adding a drop or two of vanilla and 2 teaspoons of powdered sugar.
# 	Root action: whip
# 	All actions: {0: ('whip', 'whip the cream using an electric mixer')}
# 	Ingredients: {'the biscuits': ('the biscuits', 'baking', 'ingredient'), 'the cream': ('the cream', 'whip', 'ingredient'), 'a drop or two of vanilla': ('a drop or two of vanilla', 'adding', 'ingredient'), '2 teaspoons of powdered sugar': ('2 teaspoons of powdered sugar', 'adding', 'quantity')}
# 	Tools: {'an electric mixer': ('an electric mixer', 'using', 'appliance')}
# 	Details: {0: ('While', 'While the biscuits are baking, whip the cream using an electric mixer, adding a drop or two of vanilla and 2 teaspoons of powdered sugar.', 'baking')}
# id: 17
# Original text: Cover with plastic and place in the refrigerator to chill until ready to serve.
# 	Root action: Cover
# 	All actions: {0: ('Cover', 'Cover with plastic and place in the refrigerator to chill until ready to serve'), 1: ('chill', 'chill'), 2: ('serve', 'serve')}
# 	Ingredients: {}
# 	Tools: {'plastic and place in the refrigerator': ('plastic and place in the refrigerator', 'cover', 'appliance')}
# 	Details: {0: ('with', 'with plastic and place in the refrigerator', 'cover'), 1: ('until', 'until ready to serve', 'chill')}
# id: 18
# Original text: To serve, break up one biscuit per person into big pieces into a bowl.
# 	Root action: break
# 	All actions: {0: ('serve', 'serve'), 1: ('break', 'break up one biscuit per person into big pieces into a bowl')}
# 	Ingredients: {'one biscuit per person': ('one biscuit per person', 'break', 'quantity'), 'big pieces': ('big pieces', 'break', 'quantity')}
# 	Tools: {'a bowl': ('a bowl', 'break', 'bowl')}
# 	Details: {0: ('up', 'up one biscuit per person', 'break'), 1: ('into', 'into big pieces', 'break'), 2: ('into', 'into a bowl', 'break')}
# id: 19
# Original text: Ladle strawberries over the biscuit.
# 	Root action: strawberries
# 	All actions: {}
# 	Ingredients: {'Ladle strawberries': ('Ladle strawberries', None, 'ingredient'), 'the biscuit': ('the biscuit', None, 'ingredient')}
# 	Tools: {}
# 	Details: {0: ('over', 'over the biscuit', None)}
# id: 20
# Original text: Add a dollop of whipped cream.
# 	Root action: Add
# 	All actions: {0: ('Add', 'Add a dollop of whipped cream')}
# 	Ingredients: {'a dollop of whipped cream': ('a dollop of whipped cream', 'add', 'ingredient')}
# 	Tools: {}
# 	Details: {0: ('of', 'of whipped cream', 'add')}

# %%
for step in allsteps2:
    print(allsteps2[step])
# Out:
# id: 1
# Original text: Bring a large pot of salted water to a boil.
# 	Root action: Bring
# 	All actions: {0: ('Bring', 'Bring a large pot of salted water to a boil')}
# 	Ingredients: {('a large pot of salted water', 'bring', 'quantity'): ('a large pot of salted water', 'bring')}
# 	Tools: {'a boil': ('a boil', 'bring', 'appliance')}
# 	Details: {0: ('of', 'of salted water', 'bring'), 1: ('to', 'to a boil', 'bring')}
# id: 2
# Original text: Add the linguine and cook as the label directs.
# 	Root action: Add
# 	All actions: {0: ('Add', 'Add the linguine and cook as the label directs')}
# 	Ingredients: {('linguine', 'add', 'ingredient'): ('linguine', 'add', 3)}
# 	Tools: {'the label': ('the label', 'directs', 'pan')}
# 	Details: {0: ('as', 'as the label directs', 'directs')}
# id: 3
# Original text: Reserve 1 cup cooking water, then drain.
# 	Root action: water
# 	All actions: {0: ('drain', 'drain')}
# 	Ingredients: {('Reserve 1 cup cooking water', None, 'quantity'): ('Reserve 1 cup cooking water', None)}
# 	Tools: {}
# 	Details: {0: ('then', 'then', 'drain')}
# id: 4
# Original text: Meanwhile, season the shrimp with salt.
# 	Root action: season
# 	All actions: {}
# 	Ingredients: {('season the shrimp with salt', None, 'ingredient'): ('season the shrimp with salt', None)}
# 	Tools: {}
# 	Details: {0: ('Meanwhile', 'Meanwhile', None), 1: ('with', 'with salt', None)}
# id: 5
# Original text: Heat the olive oil in a large skillet over medium-high heat.
# 	Root action: Heat
# 	All actions: {0: ('Heat', 'Heat the olive oil in a large skillet over medium- high heat')}
# 	Ingredients: {('the olive oil', 'heat', 'ingredient'): ('the olive oil', 'heat')}
# 	Tools: {'a large skillet over medium- high heat': ('a large skillet over medium- high heat', 'heat', 'pan')}
# 	Details: {0: ('in', 'in a large skillet over medium- high heat', 'heat')}
# id: 6
# Original text: Add the garlic and red pepper flakes and cook until the garlic is just golden, 30 seconds to 1 minute.
# 	Root action: Add
# 	All actions: {0: ('Add', 'Add the garlic and red pepper flakes'), 1: ('cook', 'cook until the garlic is just golden')}
# 	Ingredients: {('the garlic and red pepper flakes', 'add', 'ingredient'): ('the garlic and red pepper flakes', 'add')}
# 	Tools: {}
# 	Details: {0: ('until', 'until the garlic is just golden', 'cook'), 1: ('to', 'to 1 minute', 'cook')}
# id: 7
# Original text: Add the shrimp and cook, stirring occasionally, until pink and just cooked through, 1 to 2 minutes per side.
# 	Root action: Add
# 	All actions: {0: ('Add', 'Add the shrimp'), 1: ('cook', 'cook')}
# 	Ingredients: {('the shrimp', 'add', 'ingredient'): ('the shrimp', 'add')}
# 	Tools: {}
# 	Details: {0: ('occasionally', 'occasionally', 'stirring'), 1: ('until', 'until pink', 'stirring'), 2: ('just', 'just', 'cooked'), 3: ('through', 'through', 'cooked'), 4: ('per', 'per side', 'cooked')}
# id: 8
# Original text: Remove the shrimp to a plate.
# 	Root action: Remove
# 	All actions: {0: ('Remove', 'Remove the shrimp to a plate')}
# 	Ingredients: {('the shrimp', 'remove', 'ingredient'): ('the shrimp', 'remove')}
# 	Tools: {'a plate': ('a plate', 'remove', 'cooking utensil')}
# 	Details: {0: ('to', 'to a plate', 'remove')}
# id: 9
# Original text: Add the wine and lemon juice to the skillet and simmer until slightly reduced, 2 minutes.
# 	Root action: Add
# 	All actions: {0: ('Add', 'Add the wine and lemon juice to the skillet'), 1: ('simmer', 'simmer until slightly reduced')}
# 	Ingredients: {('the wine and lemon juice', 'add', 'ingredient'): ('the wine and lemon juice', 'add')}
# 	Tools: {'the skillet': ('the skillet', 'add', 'cooking utensil')}
# 	Details: {0: ('to', 'to the skillet', 'add'), 1: ('until', 'until slightly reduced', 'reduced')}
# id: 10
# Original text: Return the shrimp and any juices from the plate to the skillet along with the linguine, butter and 1/2 cup of the reserved cooking water.
# 	Root action: Return
# 	All actions: {0: ('Return', 'Return the shrimp and any juices from the plate to the skillet along with the linguine, butter and 1/2 cup of the reserved cooking water')}
# 	Ingredients: {('the shrimp', 'return', 'ingredient'): ('the shrimp', 'return'), ('any juices from the plate', 'return', 'ingredient'): ('any juices from the plate', 'return')}
# 	Tools: {'the skillet along with the linguine, butter and 1/2 cup of the reserved cooking water': ('the skillet along with the linguine, butter and 1/2 cup of the reserved cooking water', 'return', 'cooking utensil')}
# 	Details: {0: ('from', 'from the plate', 'return'), 1: ('to', 'to the skillet along with the linguine, butter and 1/2 cup of the reserved cooking water', 'return')}
# id: 11
# Original text: Continue to cook, tossing, until the butter is melted and the shrimp is hot, about 2 minutes, adding more of the reserved cooking water as needed.
# 	Root action: Continue
# 	All actions: {0: ('Continue', 'Continue to cook, tossing, until the butter is melted and the shrimp is hot'), 1: ('cook', 'cook, tossing, until the butter is melted and the shrimp is hot')}
# 	Ingredients: {('the butter', 'melted', 'ingredient'): ('the butter', 'melted'), ('the shrimp', 'continue', 'ingredient'): ('the shrimp', 'continue'), ('more of the reserved cooking water', 'adding', 'quantity'): ('more of the reserved cooking water', 'adding')}
# 	Tools: {}
# 	Details: {0: ('until', 'until the butter is melted and the shrimp is hot', 'melted'), 1: ('of', 'of the reserved cooking water', 'adding'), 2: ('as', 'as needed', 'needed')}
# id: 12
# Original text: Season with salt; stir in the parsley.
# 	Root action: Season
# 	All actions: {0: ('stir', 'stir in the parsley')}
# 	Ingredients: {('Season with salt', None, 'ingredient'): ('Season with salt', None), ('the parsley', 'stir', 'ingredient'): ('the parsley', 'stir')}
# 	Tools: {}
# 	Details: {0: ('with', 'with salt', None), 1: ('in', 'in the parsley', 'stir')}
# id: 13
# Original text: Serve with lemon wedges.
# 	Root action: Serve
# 	All actions: {0: ('Serve', 'Serve with lemon wedges')}
# 	Ingredients: {('lemon wedges', 'serve', 'slices'): ('lemon wedges', 'serve')}
# 	Tools: {}
# 	Details: {0: ('with', 'with lemon wedges', 'serve')}

# %%
import stanza as st
import numpy as np
import re as reg
from typing import Optional
import transformers as tra
from enum import Enum
from difflib import SequenceMatcher as sm

pipe2 = tra.pipeline(task="zero-shot-classification", model="facebook/bart-large-mnli")
st.download('en')
depgram = st.Pipeline('en')#, processors='tokenize,mwt,pos,lemma,depparse,ner')
# Out:
# Downloading https://raw.githubusercontent.com/stanfordnlp/stanza-resources/main/resources_1.4.1.json: 193kB [00:00, 63.8MB/s]
# 2023-03-05 16:20:48 INFO: Downloading default packages for language: en (English) ...
# 2023-03-05 16:20:50 INFO: File exists: C:\Users\Typic\stanza_resources\en\default.zip
# 2023-03-05 16:20:54 INFO: Finished downloading models and saved to C:\Users\Typic\stanza_resources.
# 2023-03-05 16:20:54 INFO: Checking for updates to resources.json in case models have been updated.  Note: this behavior can be turned off with download_method=None or download_method=DownloadMethod.REUSE_RESOURCES
# Downloading https://raw.githubusercontent.com/stanfordnlp/stanza-resources/main/resources_1.4.1.json: 193kB [00:00, 64.4MB/s]
# 2023-03-05 16:20:56 INFO: Loading these models for language: en (English):
# ============================
# | Processor    | Package   |
# ----------------------------
# | tokenize     | combined  |
# | pos          | combined  |
# | lemma        | combined  |
# | depparse     | combined  |
# | sentiment    | sstplus   |
# | constituency | wsj       |
# | ner          | ontonotes |
# ============================
#
# 2023-03-05 16:20:56 INFO: Use device: cpu
# 2023-03-05 16:20:56 INFO: Loading: tokenize
# 2023-03-05 16:20:56 INFO: Loading: pos
# 2023-03-05 16:20:56 INFO: Loading: lemma
# 2023-03-05 16:20:57 INFO: Loading: depparse
# 2023-03-05 16:20:57 INFO: Loading: sentiment
# 2023-03-05 16:20:57 INFO: Loading: constituency
# 2023-03-05 16:20:58 INFO: Loading: ner
# 2023-03-05 16:20:59 INFO: Done loading processors!
